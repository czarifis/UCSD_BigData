# %%
import sys
home_dir='/home/ubuntu/UCSD_BigData'
sys.path.append(home_dir+'/utils')
from find_waiting_flow import *
from AWS_keypair_management import *

import pickle

Creds= pickle.load(open('/home/ubuntu/Vault/Creds.pkl','rb'))
pair=Creds['mrjob']
key_id=pair['key_id']
secret_key=pair['secret_key']
ID=pair['ID']
print 'ID: %s, key_id: %s' % (ID, key_id)

job_flow_id=find_waiting_flow(key_id,secret_key)
print job_flow_id
# Out:
# ID: kozarifi, key_id: AKIAIXCNAVZPV64ER67Q
# <boto.emr.emrobject.JobFlow object at 0x3615850>
#  no_script.yoavfreund.20140610.012426.319987 j-QEERH05KMYTO WAITING
# <boto.emr.emrobject.JobFlow object at 0x361a8d0> no_script.yoavfreund.20140610.012507.678804 j-NIGXU2E6YEU3 WAITING
# <boto.emr.emrobject.JobFlow object at 0x3626350> no_script.yoavfreund.20140610.012515.693483 j-3SOQM885E1GLH WAITING
# <boto.emr.emrobject.JobFlow object at 0x37f0650> no_script.yoavfreund.20140610.012523.713192 j-34Q4HR41T9BWU WAITING
# <boto.emr.emrobject.JobFlow object at 0x3807ed0> no_script.yoavfreund.20140610.012531.672863 j-31PKW9W4C2YQK WAITING
# <boto.emr.emrobject.JobFlow object at 0x38c47d0> no_script.yoavfreund.20140611.181703.600873 j-2N4U1USC54EM6 WAITING
# <boto.emr.emrobject.JobFlow object at 0x38db810> no_script.yoavfreund.20140611.181722.314318 j-3MR2RR5OEXRQ7 WAITING
# <boto.emr.emrobject.JobFlow object at 0x3b03110> no_script.yoavfreund.20140611.181730.511103 j-2S5LTMBIWD2WB WAITING
# <boto.emr.emrobject.JobFlow object at 0x3b14c50> no_script.yoavfreund.20140611.181738.864430 j-3TFYHEIHI9VOY WAITING
# j-3TFYHEIHI9VOY

# %%
import gzip
import pandas as pd

statfile = '/home/ubuntu/UCSD_BigData/notebooks/weather.mapreduce/stations.pkl.gz'
statinfo = pickle.load(gzip.open(statfile,'rb'))
# del statinfo['state']
# del statinfo['name']
del statinfo['GSNFLAG']
del statinfo['HCNFLAG']
del statinfo['WMOID']
statinfo.head()
# Out:
#              latitude  longitude  elevation state                   name
# ACW00011604   17.1167   -61.7833       10.1   NaN  ST JOHNS COOLIDGE FLD
# ACW00011647   17.1333   -61.7833       19.2   NaN               ST JOHNS
# AE000041196   25.3330    55.5170       34.0   NaN    SHARJAH INTER. AIRP
# AF000040930   35.3170    69.0170     3366.0   NaN           NORTH-SALANG
# AG000060390   36.7167     3.2500       24.0   NaN     ALGER-DAR EL BEIDA
#
# [5 rows x 5 columns]

# %%
# %%writefile count_TMIN_TMAX.py
#!/usr/bin/python
"""
count the number of measurements of each type
"""
import sys
sys.path.append('/usr/lib/python2.6/dist-packages')
from mrjob.job import MRJob
import re
from sys import stderr

class count_TMIN_TMAX(MRJob):

    def mapper(self, _, line):
        try:
            self.increment_counter('MrJob Counters','mapper',1)
            # Parse the line
            elements=line.split(',')
            station = elements[0]
            measure_type = elements[1]
            year = int(elements[2])
            measurements = elements[3:]
            nomeas = 0
            AllNum=True
            for ss in measurements:
                if ss!="":
                    try:
                        ii=float(ss)
                        nomeas+=1
                    except:
                        AllNum=False
            #filter out the unwanted measurements and the header line
            #yield (station, elements[1:])
            if (measure_type == 'TMIN' or measure_type == 'TMAX') and station != 'station' and len(measurements)==365 and AllNum: 
                self.increment_counter('MrJob Counters','usefull lines',1)
                yield (station, nomeas)
                
        except Exception, e:
            stderr.write('Error in line:\n'+line)
            stderr.write(e.message)
            self.increment_counter('MrJob Counters','mapper-error',1)
            yield (('error','mapper', str(e)), 1)
            
    def reducer(self, station, counts):
#         try:
#             if station[0] == 'error':
#                 yield(station,sum(data))
#                 return
            self.increment_counter('MrJob Counters','reducer',1)
            yield (station, sum(counts))
#         except Exception, e:
#             stderr.write('Error in reducer')
        
if __name__ == '__main__':
    count_TMIN_TMAX.run()
# Out:
# Overwriting count_TMIN_TMAX.py

# %%
# !python count_TMIN_TMAX.py /home/ubuntu/data/weather/ALL.head.csv > station_TMIN_TMAX_count_head.txt
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/count_TMIN_TMAX.ubuntu.20140611.225643.607992
# writing to /tmp/count_TMIN_TMAX.ubuntu.20140611.225643.607992/step-0-mapper_part-00000
# Counters from step 1:
#   MrJob Counters:
#     mapper: 999
#     usefull lines: 229
# writing to /tmp/count_TMIN_TMAX.ubuntu.20140611.225643.607992/step-0-mapper-sorted
# > sort /tmp/count_TMIN_TMAX.ubuntu.20140611.225643.607992/step-0-mapper_part-00000
# writing to /tmp/count_TMIN_TMAX.ubuntu.20140611.225643.607992/step-0-reducer_part-00000
# Counters from step 1:
#   MrJob Counters:
#     mapper: 999
#     reducer: 4
#     usefull lines: 229
# Moving /tmp/count_TMIN_TMAX.ubuntu.20140611.225643.607992/step-0-reducer_part-00000 -> /tmp/count_TMIN_TMAX.ubuntu.20140611.225643.607992/output/part-00000
# Streaming final output from /tmp/count_TMIN_TMAX.ubuntu.20140611.225643.607992/output
# removing tmp directory /tmp/count_TMIN_TMAX.ubuntu.20140611.225643.607992

# %%
# !head station_TMIN_TMAX_count_head.txt
# Out:
# "MX000008172"	30027
# "RSM00024933"	5540
# "USC00211063"	27984
# "USC00500433"	9631

# %%
# !python count_TMIN_TMAX.py -r emr --emr-job-flow-id $job_flow_id hdfs:/weather.raw_data/ALL.csv > station_TMIN_TMAX_count.txt
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/count_TMIN_TMAX.ubuntu.20140611.225724.361360
# Copying non-input files into s3://costaszarifisbucket/scratch/count_TMIN_TMAX.ubuntu.20140611.225724.361360/files/
# Adding our job to existing job flow j-3MR2RR5OEXRQ7
# Job launched 30.2s ago, status RUNNING: Running step (count_TMIN_TMAX.ubuntu.20140611.225724.361360: Step 1 of 1)
# Job launched 60.3s ago, status RUNNING: Running step (count_TMIN_TMAX.ubuntu.20140611.225724.361360: Step 1 of 1)
# Job launched 90.5s ago, status RUNNING: Running step (count_TMIN_TMAX.ubuntu.20140611.225724.361360: Step 1 of 1)
# Job launched 120.7s ago, status RUNNING: Running step (count_TMIN_TMAX.ubuntu.20140611.225724.361360: Step 1 of 1)
# Job launched 150.8s ago, status RUNNING: Running step (count_TMIN_TMAX.ubuntu.20140611.225724.361360: Step 1 of 1)
# Job launched 181.0s ago, status RUNNING: Running step (count_TMIN_TMAX.ubuntu.20140611.225724.361360: Step 1 of 1)
# Job completed.
# Running time was 178.0s (not counting time spent waiting for the EC2 instances)
# ec2_key_pair_file not specified, going to S3
# Fetching counters from S3...
# Waiting 5.0s for S3 eventual consistency
# Counters may not have been uploaded to S3 yet. Try again in 5 minutes with: mrjob fetch-logs --counters j-3MR2RR5OEXRQ7
# Counters from step 1:
#   (no counters found)
# Streaming final output from s3://costaszarifisbucket/scratch/count_TMIN_TMAX.ubuntu.20140611.225724.361360/output/
# removing tmp directory /tmp/count_TMIN_TMAX.ubuntu.20140611.225724.361360
# Removing all files in s3://costaszarifisbucket/scratch/count_TMIN_TMAX.ubuntu.20140611.225724.361360/

# %%
# !head -10 station_TMIN_TMAX_count.txt
# Out:
# "AJ000037756"	2984
# "AJ000037844"	1988
# "AJ000037866"	2318
# "AJ000037899"	508
# "AJ000037907"	14366
# "AM000037627"	26
# "AM000037704"	1608
# "AQC00914873"	5162
# "AR000087270"	34603
# "AR000087344"	37464

# %%
meascount = pd.read_csv('station_TMIN_TMAX_count.txt', sep='\t', names=['station', 'measurement_count'])
merged = meascount.join(statinfo,on='station')
merged.head(5)
# Out:
#        station  measurement_count  latitude  longitude  elevation state  \
# 0  AJ000037756               2984    40.533     48.933        755   NaN
# 1  AJ000037844               1988    40.333     48.167          4   NaN
# 2  AJ000037866               2318    40.467     50.317        -24   NaN
# 3  AJ000037899                508    39.767     46.750       1355   NaN
# 4  AJ000037907              14366    39.600     47.150        439   NaN
#
#         name
# 0     MARAZA
# 1   KURDAMIR
# 2  PIRALLAHI
# 3     SHUSHA
# 4     FIZULY
#
# [5 rows x 7 columns]

# %%
from mpl_toolkits.basemap import Basemap
lonmin=-180;lonmax=180;latsmin=-80;latsmax=80;
    
plt.figure(figsize=(15,10),dpi=300)
m = Basemap(projection='merc',llcrnrlat=latsmin,urcrnrlat=latsmax,llcrnrlon=lonmin,urcrnrlon=lonmax,lat_ts=20,resolution='c')
#m.drawcoastlines(color='lightgrey')
#m.drawmapboundary()
m.drawcoastlines()
x,y = m(np.array(merged['longitude']), np.array(merged['latitude']))
color_map = m.scatter(x,y,c=np.array(merged['measurement_count']),marker='.', lw=0, alpha=1)
#m.colorbar(color_map,pad="5%")
m.colorbar(color_map)
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x87d03b0>

# %%
merged['measurement_count'].hist(bins=500)

# %%
merged['distanceFromSea'] = 'None'

# %%
#%%writefile mydb.py
#!/usr/bin/python
# -*- coding: utf-8 -*-

# You need to install postgres and psycopg2 in order to run this cell
import psycopg2
import sys


con = None

try:
    # globe db has every single country (geometry) with the highest resolution 
    conn = psycopg2.connect(database='globedb', user='gis', password="gis") 
    cur = conn.cursor()
    #cur.execute(
    #"prepare myplan as "
    #"SELECT Name_0, Name_1, Name_2  FROM gadm2 WHERE st_contains(the_geom, GeomFromText('SRID=4326;POINT($1 $2)', 4326))='t';")
    #for x,y in bsCoords:
    for indx, row in merged.iterrows():
        x = row['latitude']
        y = row['longitude']
  
        # prepared statements are not supported in psycopg2 :(
        #print "SELECT dist FROM distfromcoast WHERE long="+str(round(y,1))+" AND lat="+str(round(x,1))+" ;"
        cur.execute("SELECT dist FROM distfromcoast WHERE long="+str(round(y,1))+" AND lat="+str(round(x,1))+" ;")
                    
                    
                   ## WHERE st_contains(the_geom, GeomFromText('SRID=4326;POINT("+str(y)+" "+str(x)+")', 4326))='t';")

        qurres = cur.fetchone()
        #print res
        if qurres!=None:
            #(general, morespecific, mostspecific) = qurres

            merged.ix[indx, 'distanceFromSea'] = qurres
#             tempdf.ix[indx, 'morespecific'] = morespecific
#             tempdf.ix[indx, 'mostspecific'] = mostspecific

except psycopg2.DatabaseError, e:
    print 'Error %s' % e    
    sys.exit(1)
    
    
finally:
    
    if con:
        con.close()

# %%
store = HDFStore('store.h5')
store['merged'] = merged  # save it as HDF5 pytable (supposedly it's faster)
df.save("dataframeWithDistanceFromSea")

# %%
# %%writefile getDistFromSea.py
#!/usr/bin/python
"""
count the number of measurements of each type
"""
import sys
sys.path.append('/usr/lib/python2.6/dist-packages')
from mrjob.job import MRJob
import re
from sys import stderr

class count_validyear(MRJob):

    def mapper(self, _, line):
        try:
            self.increment_counter('MrJob Counters','mapper',1)
            # Parse the line
            elements=line.split(',')
            station = elements[0]
            measure_type = elements[1]
            year = int(elements[2])
            measurements = elements[3:]
            nomeas = 0
            #
            AllNum=True
            for ss in measurements:
                if ss!="":
                    try:
                        ii=float(ss)
                        nomeas+=1
                    except:
                        AllNum=False
            #filter out the unwanted measurements and the header line
            if (measure_type == 'TMIN' or measure_type == 'TMAX' or measure_type=='PRCP') \
                and station != 'station' and len(measurements)==365 and nomeas>=300 and AllNum: 
                self.increment_counter('MrJob Counters','usefull lines',1)
                yield (station, [year,measure_type,nomeas])
                
        except Exception, e:
            stderr.write('Error in line:\n'+line)
            stderr.write(e.message)
            self.increment_counter('MrJob Counters','mapper-error',1)
            yield (('error','mapper', str(e)), 1)
            
    def reducer(self, station, counts):
        try:
            if station[0] == 'error':
                yield(station,sum(data))
                return
            self.increment_counter('MrJob Counters','reducer',1)
            dic_TMIN={}
            dic_TMAX={}
            dic_PRCP={}
            for vec in counts:
                if vec[1]=='TMIN':
                    dic_TMIN[vec[0]]=vec[2]
                elif vec[1]=='TMAX':
                    dic_TMAX[vec[0]]=vec[2]
                else:
                    dic_PRCP[vec[0]]=vec[2]
            validyear=[]
            for key in dic_TMIN:
                if dic_TMAX.has_key(key) and dic_PRCP.has_key(key):
                    validyear.append(key)
            yield (station, len(validyear))
        except Exception, e:
            #yield (('error','reducer', str(e)), 1)
            stderr.write('Error in reducer')
        
if __name__ == '__main__':
    count_validyear.run()
# Out:
# Writing getDistFromSea.py

# %%
# !python count_validyear.py -r emr --emr-job-flow-id $job_flow_id hdfs:/weather.raw_data/ALL.csv > station_validyear_count.txt
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/count_validyear.ubuntu.20140610.071528.833741
# Copying non-input files into s3://j2wen/scratch/count_validyear.ubuntu.20140610.071528.833741/files/
# Adding our job to existing job flow j-31PKW9W4C2YQK
# Job launched 30.2s ago, status RUNNING: Running step (count_validyear.ubuntu.20140610.071528.833741: Step 1 of 1)
# Job launched 60.5s ago, status RUNNING: Running step (count_validyear.ubuntu.20140610.071528.833741: Step 1 of 1)
# Job launched 90.7s ago, status RUNNING: Running step (count_validyear.ubuntu.20140610.071528.833741: Step 1 of 1)
# Job launched 121.0s ago, status RUNNING: Running step (count_validyear.ubuntu.20140610.071528.833741: Step 1 of 1)
# Job launched 151.2s ago, status RUNNING: Running step (count_validyear.ubuntu.20140610.071528.833741: Step 1 of 1)
# Job launched 181.4s ago, status RUNNING: Running step (count_validyear.ubuntu.20140610.071528.833741: Step 1 of 1)
# Job launched 211.6s ago, status RUNNING: Running step (count_validyear.ubuntu.20140610.071528.833741: Step 1 of 1)
# Job completed.
# Running time was 203.0s (not counting time spent waiting for the EC2 instances)
# ec2_key_pair_file not specified, going to S3
# Fetching counters from S3...
# Waiting 5.0s for S3 eventual consistency
# Counters may not have been uploaded to S3 yet. Try again in 5 minutes with: mrjob fetch-logs --counters j-31PKW9W4C2YQK
# Counters from step 1:
#   (no counters found)
# Streaming final output from s3://j2wen/scratch/count_validyear.ubuntu.20140610.071528.833741/output/
# removing tmp directory /tmp/count_validyear.ubuntu.20140610.071528.833741
# Removing all files in s3://j2wen/scratch/count_validyear.ubuntu.20140610.071528.833741/

# %%
# !head -3 station_validyear_count.txt
# Out:
# "AJ000037668"	0
# "AJ000037679"	0
# "AJ000037734"	0

# %%
measyearcount = pd.read_csv('station_validyear_count.txt', sep='\t', names=['station', 'valid_year'])
merged_year = measyearcount.join(statinfo,on='station')
merged_year.head(5)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-15-fd0809d267a1> in <module>()
# ----> 1 measyearcount = pd.read_csv('station_validyear_count.txt', sep='\t', names=['station', 'valid_year'])
#       2 merged_year = measyearcount.join(statinfo,on='station')
#       3 merged_year.head(5)
#
# /home/ubuntu/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format)
#     418                     infer_datetime_format=infer_datetime_format)
#     419
# --> 420         return _read(filepath_or_buffer, kwds)
#     421
#     422     parser_f.__name__ = name
#
# /home/ubuntu/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     216
#     217     # Create the parser.
# --> 218     parser = TextFileReader(filepath_or_buffer, **kwds)
#     219
#     220     if nrows is not None:
#
# /home/ubuntu/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     500             self.options['has_index_names'] = kwds['has_index_names']
#     501
# --> 502         self._make_engine(self.engine)
#     503
#     504     def _get_options_with_defaults(self, engine):
#
# /home/ubuntu/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     608     def _make_engine(self, engine='c'):
#     609         if engine == 'c':
# --> 610             self._engine = CParserWrapper(self.f, **self.options)
#     611         else:
#     612             if engine == 'python':
#
# /home/ubuntu/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#     970         kwds['allow_leading_cols'] = self.index_col is not False
#     971
# --> 972         self._reader = _parser.TextReader(src, **kwds)
#     973
#     974         # XXX
#
# /home/ubuntu/anaconda/lib/python2.7/site-packages/pandas/parser.so in pandas.parser.TextReader.__cinit__ (pandas/parser.c:3200)()
#
# /home/ubuntu/anaconda/lib/python2.7/site-packages/pandas/parser.so in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:5559)()
#
# IOError: File station_validyear_count.txt does not exist

# %%
from mpl_toolkits.basemap import Basemap
lonmin=-180;lonmax=180;latsmin=-80;latsmax=80;
    
plt.figure(figsize=(15,10),dpi=300)
m = Basemap(projection='merc',llcrnrlat=latsmin,urcrnrlat=latsmax,llcrnrlon=lonmin,urcrnrlon=lonmax,lat_ts=20,resolution='c')
#m.drawcoastlines(color='lightgrey')
#m.drawmapboundary()
m.drawcoastlines()
x,y = m(np.array(merged_year['longitude']), np.array(merged_year['latitude']))
color_map = m.scatter(x,y,c=np.array(merged_year['valid_year']),marker='.', lw=0, alpha=1)
m.colorbar(color_map,pad="5%")

# import matplotlib.colors as mc
# import matplotlib.pyplot as plt
# plt.imshow(X, norm=mc.Normalize(vmin=100))
# plt.colorbar(ticks=[0,2,4,6], format='%0.2f')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-8ebab8d056e3> in <module>()
#       7 #m.drawmapboundary()
#       8 m.drawcoastlines()
# ----> 9 x,y = m(np.array(merged_year['longitude']), np.array(merged_year['latitude']))
#      10 color_map = m.scatter(x,y,c=np.array(merged_year['valid_year']),marker='.', lw=0, alpha=1)
#      11 m.colorbar(ticks=[0,2,4,6], format='%0.2f')
#
# NameError: name 'merged_year' is not defined

# %%
# %%writefile get_mean_diff_std.py
#!/usr/bin/python
"""
count the number of measurements of each type
"""
import sys
import numpy as np
sys.path.append('/usr/lib/python2.6/dist-packages')
from mrjob.job import MRJob
import re
from sys import stderr

class get_mean_diff_std(MRJob):

    def mapper(self, _, line):
        try:
            self.increment_counter('MrJob Counters','mapper',1)
            # Parse the line
            elements=line.split(',')
            station = elements[0]
            measure_type = elements[1]
            year = int(elements[2])
            measurements = elements[3:]
            nomeas = 0
            #
            AllNum=True
            usefulmeas=[]
            for ss in measurements:
                if ss!="":
                    try:
                        ii=float(ss)
                        usefulmeas.append(ii)
                        nomeas+=1
                    except:
                        AllNum=False
            #filter out the unwanted measurements and the header line
            if (measure_type == 'TMIN' or measure_type == 'TMAX' or measure_type=='PRCP') \
                and station != 'station' and len(measurements)==365 and nomeas>=300 and AllNum: 
                self.increment_counter('MrJob Counters','usefull lines',1)
                yield (station, [year,measure_type,usefulmeas])
                
        except Exception, e:
            stderr.write('Error in line:\n'+line)
            stderr.write(e.message)
            self.increment_counter('MrJob Counters','mapper-error',1)
            yield (('error','mapper', str(e)), 1)
            
    def reducer(self, station, counts):
        try:
            if station[0] == 'error':
                yield(station,sum(data))
                return
            self.increment_counter('MrJob Counters','reducer',1)
            dic_TMIN={}
            dic_TMAX={}
            dic_PRCP={}
            for vec in counts:
                if vec[1]=='TMIN':
                    dic_TMIN[vec[0]]=vec[2]
                elif vec[1]=='TMAX':
                    dic_TMAX[vec[0]]=vec[2]
                else:
                    dic_PRCP[vec[0]]=vec[2]
            validyear=[]
            mean_TMIN=[]
            mean_TMAX=[]
            mean_PRCP=[]
            std_TMIN=[]
            std_TMAX=[]
            std_PRCP=[]
            for key in dic_TMIN:
                if dic_TMAX.has_key(key) and dic_PRCP.has_key(key):
                    validyear.append(key)
                    mean_TMIN.append(np.mean(np.array(dic_TMIN[key])))
                    mean_TMAX.append(np.mean(np.array(dic_TMAX[key])))
                    mean_PRCP.append(np.mean(np.array(dic_PRCP[key])))
                    std_TMIN.append(np.std(np.array(dic_TMIN[key])))
                    std_TMAX.append(np.std(np.array(dic_TMAX[key])))
                    std_PRCP.append(np.std(np.array(dic_PRCP[key])))
            if len(validyear)>0:
                out=[np.mean(np.array(mean_TMIN)), np.mean(np.array(mean_TMAX)), \
                     np.mean(np.array(mean_TMAX))-np.mean(np.array(mean_TMIN)), np.mean(np.array(mean_PRCP)),\
                     np.mean(np.array(std_TMIN)),np.mean(np.array(std_TMAX)),np.mean(np.array(std_PRCP))]
                yield (station, out)
            else:
                yield (station, [9999,9999,9999,9999,9999,9999,9999])
        except Exception, e:
            #yield (('error','reducer', str(e)), 1)
            stderr.write('Error in reducer')
        
if __name__ == '__main__':
    get_mean_diff_std.run()
# Out:
# Overwriting get_mean_diff_std.py

# %%
# !python get_mean_diff_std.py -r emr --emr-job-flow-id $job_flow_id hdfs:/weather.raw_data/ALL.csv > mean_diff_std.txt
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/get_mean_diff_std.ubuntu.20140611.061129.625052
# Copying non-input files into s3://j2wen/scratch/get_mean_diff_std.ubuntu.20140611.061129.625052/files/
# Adding our job to existing job flow j-31PKW9W4C2YQK
# Job launched 30.4s ago, status RUNNING: Running step (get_mean_diff_std.ubuntu.20140611.061129.625052: Step 1 of 1)
# Job launched 60.8s ago, status RUNNING: Running step (get_mean_diff_std.ubuntu.20140611.061129.625052: Step 1 of 1)
# Job launched 91.1s ago, status RUNNING: Running step (get_mean_diff_std.ubuntu.20140611.061129.625052: Step 1 of 1)
# Job launched 121.4s ago, status RUNNING: Running step (get_mean_diff_std.ubuntu.20140611.061129.625052: Step 1 of 1)
# Job launched 151.8s ago, status RUNNING: Running step (get_mean_diff_std.ubuntu.20140611.061129.625052: Step 1 of 1)
# Job launched 182.2s ago, status RUNNING: Running step (get_mean_diff_std.ubuntu.20140611.061129.625052: Step 1 of 1)
# Job launched 212.6s ago, status RUNNING: Running step (get_mean_diff_std.ubuntu.20140611.061129.625052: Step 1 of 1)
# Job launched 242.9s ago, status RUNNING: Running step (get_mean_diff_std.ubuntu.20140611.061129.625052: Step 1 of 1)
# Job launched 273.3s ago, status RUNNING: Running step (get_mean_diff_std.ubuntu.20140611.061129.625052: Step 1 of 1)
# Job launched 303.7s ago, status RUNNING: Running step (get_mean_diff_std.ubuntu.20140611.061129.625052: Step 1 of 1)
# Job launched 334.0s ago, status RUNNING: Running step (get_mean_diff_std.ubuntu.20140611.061129.625052: Step 1 of 1)
# Job launched 364.4s ago, status RUNNING: Running step (get_mean_diff_std.ubuntu.20140611.061129.625052: Step 1 of 1)
# Job launched 394.8s ago, status RUNNING: Running step (get_mean_diff_std.ubuntu.20140611.061129.625052: Step 1 of 1)
# Job launched 425.2s ago, status RUNNING: Running step (get_mean_diff_std.ubuntu.20140611.061129.625052: Step 1 of 1)
# Job launched 455.5s ago, status RUNNING: Running step (get_mean_diff_std.ubuntu.20140611.061129.625052: Step 1 of 1)
# Job completed.
# Running time was 450.0s (not counting time spent waiting for the EC2 instances)
# ec2_key_pair_file not specified, going to S3
# Fetching counters from S3...
# Waiting 5.0s for S3 eventual consistency
# Counters from step 1:
#   File Input Format Counters :
#     Bytes Read: 7670788923
#   File Output Format Counters :
#     Bytes Written: 6415728
#   FileSystemCounters:
#     FILE_BYTES_READ: 2088718946
#     FILE_BYTES_WRITTEN: 4179932182
#     HDFS_BYTES_READ: 7670795163
#     S3_BYTES_WRITTEN: 6415728
#   Job Counters :
#     Data-local map tasks: 59
#     Launched map tasks: 60
#     Launched reduce tasks: 10
#     Rack-local map tasks: 1
#     SLOTS_MILLIS_MAPS: 6177650
#     SLOTS_MILLIS_REDUCES: 1339492
#     Total time spent by all maps waiting after reserving slots (ms): 0
#     Total time spent by all reduces waiting after reserving slots (ms): 0
#   Map-Reduce Framework:
#     CPU time spent (ms): 4472510
#     Combine input records: 0
#     Combine output records: 0
#     Map input bytes: 7668890105
#     Map input records: 9358395
#     Map output bytes: 8104142899
#     Map output materialized bytes: 2089343445
#     Map output records: 3757214
#     Physical memory (bytes) snapshot: 35733929984
#     Reduce input groups: 72771
#     Reduce input records: 3757214
#     Reduce output records: 72770
#     Reduce shuffle bytes: 2089343445
#     SPLIT_RAW_BYTES: 6240
#     Spilled Records: 7514428
#     Total committed heap usage (bytes): 32257867776
#     Virtual memory (bytes) snapshot: 126635749376
#   MrJob Counters:
#     mapper: 9358395
#     reducer: 72770
#     usefull lines: 3757213
# Streaming final output from s3://j2wen/scratch/get_mean_diff_std.ubuntu.20140611.061129.625052/output/
# removing tmp directory /tmp/get_mean_diff_std.ubuntu.20140611.061129.625052
# Removing all files in s3://j2wen/scratch/get_mean_diff_std.ubuntu.20140611.061129.625052/

# %%
# !head -5 mean_diff_std.txt
# Out:
# "AJ000037668"	[9999, 9999, 9999, 9999, 9999, 9999, 9999]
# "AJ000037679"	[9999, 9999, 9999, 9999, 9999, 9999, 9999]
# "AJ000037734"	[9999, 9999, 9999, 9999, 9999, 9999, 9999]
# "AJ000037756"	[9999, 9999, 9999, 9999, 9999, 9999, 9999]
# "AJ000037844"	[9999, 9999, 9999, 9999, 9999, 9999, 9999]

# %%
# %%writefile get_mean_diff_std_year.py
#!/usr/bin/python
"""
count the number of measurements of each type
"""
import sys
import numpy as np
sys.path.append('/usr/lib/python2.6/dist-packages')
from mrjob.job import MRJob
import re
from sys import stderr

class get_mean_diff_std_year(MRJob):

    def mapper(self, _, line):
        try:
            self.increment_counter('MrJob Counters','mapper',1)
            # Parse the line
            elements=line.split(',')
            station = elements[0]
            measure_type = elements[1]
            year = int(elements[2])
            measurements = elements[3:]
            nomeas = 0
            #
            AllNum=True
            usefulmeas=[]
            for ss in measurements:
                if ss!="":
                    try:
                        ii=float(ss)
                        usefulmeas.append(ii)
                        nomeas+=1
                    except:
                        AllNum=False
            #filter out the unwanted measurements and the header line
            if (measure_type == 'TMIN' or measure_type == 'TMAX' or measure_type=='PRCP') \
                and station != 'station' and len(measurements)==365 and nomeas>=300 and AllNum: 
                self.increment_counter('MrJob Counters','usefull lines',1)
                yield (station, [year,measure_type,usefulmeas])
                
        except Exception, e:
            stderr.write('Error in line:\n'+line)
            stderr.write(e.message)
            self.increment_counter('MrJob Counters','mapper-error',1)
            yield (('error','mapper', str(e)), 1)
            
    def reducer(self, station, counts):
        try:
            if station[0] == 'error':
                yield(station,sum(data))
                return
            self.increment_counter('MrJob Counters','reducer',1)
            dic_TMIN={}
            dic_TMAX={}
            dic_PRCP={}
            for vec in counts:
                if vec[1]=='TMIN':
                    dic_TMIN[vec[0]]=vec[2]
                elif vec[1]=='TMAX':
                    dic_TMAX[vec[0]]=vec[2]
                else:
                    dic_PRCP[vec[0]]=vec[2]
            validyear=[]
            mean_TMIN=[]
            mean_TMAX=[]
            mean_PRCP=[]
            std_TMIN=[]
            std_TMAX=[]
            std_PRCP=[]
            for key in dic_TMIN:
                if dic_TMAX.has_key(key) and dic_PRCP.has_key(key):
                    validyear.append(key)
                    mean_TMIN.append(np.mean(np.array(dic_TMIN[key])))
                    mean_TMAX.append(np.mean(np.array(dic_TMAX[key])))
                    mean_PRCP.append(np.mean(np.array(dic_PRCP[key])))
                    std_TMIN.append(np.std(np.array(dic_TMIN[key])))
                    std_TMAX.append(np.std(np.array(dic_TMAX[key])))
                    std_PRCP.append(np.std(np.array(dic_PRCP[key])))
            if len(validyear)>100:
                yield (station, [validyear,mean_TMIN,mean_TMAX])
            #else:
            #    yield (station, _)
        except Exception, e:
            #yield (('error','reducer', str(e)), 1)
            stderr.write('Error in reducer')
        
if __name__ == '__main__':
    get_mean_diff_std_year.run()
# Out:
# Overwriting get_mean_diff_std_year.py

# %%
# !python get_mean_diff_std_year.py -r emr --emr-job-flow-id $job_flow_id hdfs:/weather.raw_data/ALL.csv > mean_diff_std_year.txt
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/get_mean_diff_std_year.ubuntu.20140611.205411.903899
# Copying non-input files into s3://j2wen/scratch/get_mean_diff_std_year.ubuntu.20140611.205411.903899/files/
# Adding our job to existing job flow j-34Q4HR41T9BWU
# Job launched 30.3s ago, status RUNNING: Running step (get_mean_diff_std_year.ubuntu.20140611.205411.903899: Step 1 of 1)
# Job launched 60.6s ago, status RUNNING: Running step (get_mean_diff_std_year.ubuntu.20140611.205411.903899: Step 1 of 1)
# Job launched 90.9s ago, status RUNNING: Running step (get_mean_diff_std_year.ubuntu.20140611.205411.903899: Step 1 of 1)
# Job launched 121.2s ago, status RUNNING: Running step (get_mean_diff_std_year.ubuntu.20140611.205411.903899: Step 1 of 1)
# Job launched 151.5s ago, status RUNNING: Running step (get_mean_diff_std_year.ubuntu.20140611.205411.903899: Step 1 of 1)
# Job launched 181.8s ago, status RUNNING: Running step (get_mean_diff_std_year.ubuntu.20140611.205411.903899: Step 1 of 1)
# Job launched 212.1s ago, status RUNNING: Running step (get_mean_diff_std_year.ubuntu.20140611.205411.903899: Step 1 of 1)
# Job launched 242.4s ago, status RUNNING: Running step (get_mean_diff_std_year.ubuntu.20140611.205411.903899: Step 1 of 1)
# Job launched 272.7s ago, status RUNNING: Running step (get_mean_diff_std_year.ubuntu.20140611.205411.903899: Step 1 of 1)
# Job launched 303.0s ago, status RUNNING: Running step (get_mean_diff_std_year.ubuntu.20140611.205411.903899: Step 1 of 1)
# Job launched 333.3s ago, status RUNNING: Running step (get_mean_diff_std_year.ubuntu.20140611.205411.903899: Step 1 of 1)
# Job launched 363.7s ago, status RUNNING: Running step (get_mean_diff_std_year.ubuntu.20140611.205411.903899: Step 1 of 1)
# Job launched 394.0s ago, status RUNNING: Running step (get_mean_diff_std_year.ubuntu.20140611.205411.903899: Step 1 of 1)
# Job launched 424.3s ago, status RUNNING: Running step (get_mean_diff_std_year.ubuntu.20140611.205411.903899: Step 1 of 1)
# Job launched 454.6s ago, status RUNNING: Running step (get_mean_diff_std_year.ubuntu.20140611.205411.903899: Step 1 of 1)
# Job launched 484.9s ago, status RUNNING: Running step (get_mean_diff_std_year.ubuntu.20140611.205411.903899: Step 1 of 1)
# Job completed.
# Running time was 447.0s (not counting time spent waiting for the EC2 instances)
# ec2_key_pair_file not specified, going to S3
# Fetching counters from S3...
# Waiting 5.0s for S3 eventual consistency
# Counters from step 1:
#   File Input Format Counters :
#     Bytes Read: 7670788923
#   File Output Format Counters :
#     Bytes Written: 4126831
#   FileSystemCounters:
#     FILE_BYTES_READ: 2088737530
#     FILE_BYTES_WRITTEN: 4179954004
#     HDFS_BYTES_READ: 7670795163
#     S3_BYTES_WRITTEN: 4126831
#   Job Counters :
#     Data-local map tasks: 57
#     Launched map tasks: 60
#     Launched reduce tasks: 10
#     Rack-local map tasks: 3
#     SLOTS_MILLIS_MAPS: 6170174
#     SLOTS_MILLIS_REDUCES: 1515069
#     Total time spent by all maps waiting after reserving slots (ms): 0
#     Total time spent by all reduces waiting after reserving slots (ms): 0
#   Map-Reduce Framework:
#     CPU time spent (ms): 4482050
#     Combine input records: 0
#     Combine output records: 0
#     Map input bytes: 7668890105
#     Map input records: 9358395
#     Map output bytes: 8104142899
#     Map output materialized bytes: 2089343445
#     Map output records: 3757214
#     Physical memory (bytes) snapshot: 36818366464
#     Reduce input groups: 72771
#     Reduce input records: 3757214
#     Reduce output records: 817
#     Reduce shuffle bytes: 2089343445
#     SPLIT_RAW_BYTES: 6240
#     Spilled Records: 7514428
#     Total committed heap usage (bytes): 33237762048
#     Virtual memory (bytes) snapshot: 126693085184
#   MrJob Counters:
#     mapper: 9358395
#     reducer: 72770
#     usefull lines: 3757213
# Streaming final output from s3://j2wen/scratch/get_mean_diff_std_year.ubuntu.20140611.205411.903899/output/
# removing tmp directory /tmp/get_mean_diff_std_year.ubuntu.20140611.205411.903899
# Removing all files in s3://j2wen/scratch/get_mean_diff_std_year.ubuntu.20140611.205411.903899/

# %%
# !head -10 mean_diff_std_year.txt
# Out:
# "ASN00052026"	[[1879, 1880, 1883, 1884, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1