# %%
import sys
home_dir='/home/ubuntu/UCSD_BigData'
sys.path.append(home_dir+'/utils')
from find_waiting_flow import *
from AWS_keypair_management import *

import pickle

Creds= pickle.load(open('/home/ubuntu/Vault/Creds.pkl','rb'))
pair=Creds['mrjob']
key_id=pair['key_id']
secret_key=pair['secret_key']
ID=pair['ID']
print 'ID: %s, key_id: %s' % (ID, key_id)

job_flow_id=find_waiting_flow(key_id,secret_key)
print job_flow_id
# Out:
# ID: kozarifi, key_id: AKIAIXCNAVZPV64ER67Q
# <boto.emr.emrobject.JobFlow object at 0x54ebc10>
#  no_script.yoavfreund.20140611.181713.270989 j-3QZOHADZF9KY1 WAITING
# <boto.emr.emrobject.JobFlow object at 0x5ae1ed0> no_script.yoavfreund.20140611.181730.511103 j-2S5LTMBIWD2WB WAITING
# <boto.emr.emrobject.JobFlow object at 0x5e42b10> no_script.yoavfreund.20140611.181738.864430 j-3TFYHEIHI9VOY WAITING
# <boto.emr.emrobject.JobFlow object at 0x74a16d0> no_script.yoavfreund.20140613.042333.580519 j-27Y940LIXXNSZ WAITING
# <boto.emr.emrobject.JobFlow object at 0x74aa110> no_script.yoavfreund.20140613.042344.097071 j-3LP88IFUHBOHO WAITING
# <boto.emr.emrobject.JobFlow object at 0x74ba510> no_script.yoavfreund.20140613.042353.469396 j-2YMCM4F2XO00B WAITING
# <boto.emr.emrobject.JobFlow object at 0x7598710> no_script.yoavfreund.20140613.042403.179810 j-2DMPRXAW49U58 WAITING
# <boto.emr.emrobject.JobFlow object at 0x75bdc10> no_script.yoavfreund.20140613.154922.328252 j-1XMJYZ35TFPY8 WAITING
# j-1XMJYZ35TFPY8

# %%
import gzip
import pandas as pd

statfile = '/home/ubuntu/UCSD_BigData/notebooks/weather.mapreduce/stations.pkl.gz'
statinfo = pickle.load(gzip.open(statfile,'rb'))
# del statinfo['state']
# del statinfo['name']
del statinfo['GSNFLAG']
del statinfo['HCNFLAG']
del statinfo['WMOID']
statinfo.head()
# Out:
#              latitude  longitude  elevation state                   name
# ACW00011604   17.1167   -61.7833       10.1   NaN  ST JOHNS COOLIDGE FLD
# ACW00011647   17.1333   -61.7833       19.2   NaN               ST JOHNS
# AE000041196   25.3330    55.5170       34.0   NaN    SHARJAH INTER. AIRP
# AF000040930   35.3170    69.0170     3366.0   NaN           NORTH-SALANG
# AG000060390   36.7167     3.2500       24.0   NaN     ALGER-DAR EL BEIDA
#
# [5 rows x 5 columns]

# %%
# %%writefile PCA_EZE00100082.py
#!/usr/bin/python
"""
count the number of measurements of each type
"""
import sys
sys.path.append('/usr/lib/python2.6/dist-packages')
from mrjob.job import MRJob
import re
import numpy as np
from sys import stderr

class PCA_EZE00100082(MRJob):

    def mapper(self, _, line):
        try:
            self.increment_counter('MrJob Counters','mapper',1)
            # Parse the line
            elements=line.split(',')
            station = elements[0]
            measure_type = elements[1]
            year = int(elements[2])
            measurements = elements[2:]
            nomeas = 0
            #
            AllNum=True
            for ss in measurements:
                if ss!="":
                    try:
                        ii=float(ss)
                        nomeas+=1
                    except:
                        AllNum=False
            #filter out the unwanted measurements and the header line
            if (measure_type == 'TMAX')\
                and "EZE001" in station and len(measurements)==366 and nomeas>=366 and AllNum: 
                self.increment_counter('MrJob Counters','usefull lines',1)
                yield (station, measurements)
                
        except Exception, e:
            stderr.write('Error in line:\n'+line)
            stderr.write(e.message)
            self.increment_counter('MrJob Counters','mapper-error',1)
            yield (('error','mapper', str(e)), 1)
            
    def reducer(self, station, measurements):
        try:
            if station[0] == 'error':
                yield(station,sum(data))
                return
            self.increment_counter('MrJob Counters','reducer',1)
            
            sumvec=np.zeros(365)
            matr=np.zeros((365,365))
            
            number_Year=0
            data={}
            year={}

            for vector in measurements:
                strvec=vector[1:]
                numvec=[int(ss) for ss in strvec]
                data[number_Year]=numvec
                year[number_Year]=int(vector[0])
                number_Year = number_Year + 1
            
            for t in range(0,number_Year):
                sumvec=sumvec+np.array(data[t])
                
            sumlis=sumvec.tolist()
            meanlis=[float(n)/number_Year for n in sumlis]
            
            for t in range(0,number_Year):
                subtarr=np.array(data[t])-np.array(meanlis)
                matr+=np.outer(subtarr,subtarr)
                
            matr=np.divide(matr,number_Year)
            U,D,V=np.linalg.svd(matr)
            varexp=[]
            ptvar=0
            ttvar=sum(D)
            for n in range(0,365):
                ptvar+=D[n]
                if ptvar/ttvar>0.90:
                    break
                    
            k=50
#Eigenvalues:    
            Eig=np.matrix(U[:,:k])
            for t in range(0,number_Year):
                if 1890 <= year[t] and year[t] <= 1900:                    
                    subtarr=np.array(data[t])-np.array(meanlis)  
                    nbs = np.inner(subtarr,subtarr)
                    for i in range(0,k):
                        eigvec =np.array(Eig)[:,i]
                        subtarr = subtarr - np.inner(eigvec,subtarr)*eigvec
                        yield(i, np.inner(subtarr,subtarr)/nbs)
           # matr+=np.outer(subtarr,subtarr)
           # matrix=np.matrix(measurements.ix[:,1:365])#-Mean
           # Prod=matrix*Eig;
                        
            yield(station,n)
        except Exception, e:
            #yield (('error','reducer', str(e)), 1)
            stderr.write('Error in reducer')
        
if __name__ == '__main__':
    PCA_EZE00100082.run()
# Out:
# Overwriting PCA_EZE00100082.py

# %%
# !python PCA_EZE00100082.py -r emr --emr-job-flow-id $job_flow_id hdfs:/weather.raw_data/ALL.csv > PCA_EZE00100082.txt
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/PCA_EZE00100082.ubuntu.20140613.183920.077214
# Copying non-input files into s3://costaszarifisbucket/scratch/PCA_EZE00100082.ubuntu.20140613.183920.077214/files/
# Adding our job to existing job flow j-1XMJYZ35TFPY8
# Job launched 30.2s ago, status RUNNING: Running step (PCA_EZE00100082.ubuntu.20140613.183920.077214: Step 1 of 1)
# Job launched 60.4s ago, status RUNNING: Running step (PCA_EZE00100082.ubuntu.20140613.183920.077214: Step 1 of 1)
# Job launched 90.6s ago, status RUNNING: Running step (PCA_EZE00100082.ubuntu.20140613.183920.077214: Step 1 of 1)
# Job launched 120.8s ago, status RUNNING: Running step (PCA_EZE00100082.ubuntu.20140613.183920.077214: Step 1 of 1)
# Job launched 151.0s ago, status RUNNING: Running step (PCA_EZE00100082.ubuntu.20140613.183920.077214: Step 1 of 1)
# Job launched 181.2s ago, status RUNNING: Running step (PCA_EZE00100082.ubuntu.20140613.183920.077214: Step 1 of 1)
# Job launched 211.4s ago, status RUNNING: Running step (PCA_EZE00100082.ubuntu.20140613.183920.077214: Step 1 of 1)
# Job completed.
# Running time was 168.0s (not counting time spent waiting for the EC2 instances)
# ec2_key_pair_file not specified, going to S3
# Fetching counters from S3...
# Waiting 5.0s for S3 eventual consistency
# Counters from step 1:
#   File Input Format Counters :
#     Bytes Read: 7670788923
#   File Output Format Counters :
#     Bytes Written: 12504
#   FileSystemCounters:
#     FILE_BYTES_READ: 213238
#     FILE_BYTES_WRITTEN: 2303816
#     HDFS_BYTES_READ: 7670795103
#     S3_BYTES_WRITTEN: 12504
#   Job Counters :
#     Data-local map tasks: 58
#     Launched map tasks: 60
#     Launched reduce tasks: 12
#     Rack-local map tasks: 2
#     SLOTS_MILLIS_MAPS: 3496526
#     SLOTS_MILLIS_REDUCES: 375338
#     Total time spent by all maps waiting after reserving slots (ms): 0
#     Total time spent by all reduces waiting after reserving slots (ms): 0
#   Map-Reduce Framework:
#     CPU time spent (ms): 1990690
#     Combine input records: 0
#     Combine output records: 0
#     Map input bytes: 7668890105
#     Map input records: 9358395
#     Map output bytes: 563035
#     Map output materialized bytes: 220758
#     Map output records: 231
#     Physical memory (bytes) snapshot: 29112328192
#     Reduce input groups: 2
#     Reduce input records: 231
#     Reduce output records: 551
#     Reduce shuffle bytes: 220758
#     SPLIT_RAW_BYTES: 6180
#     Spilled Records: 462
#     Total committed heap usage (bytes): 27659337728
#     Virtual memory (bytes) snapshot: 126140248064
#   MrJob Counters:
#     mapper: 9358395
#     reducer: 1
#     usefull lines: 230
# Streaming final output from s3://costaszarifisbucket/scratch/PCA_EZE00100082.ubuntu.20140613.183920.077214/output/
# removing tmp directory /tmp/PCA_EZE00100082.ubuntu.20140613.183920.077214
# Removing all files in s3://costaszarifisbucket/scratch/PCA_EZE00100082.ubuntu.20140613.183920.077214/

# %%
measyearcount = pd.read_csv('PCA_EZE00100082.txt', sep='\t', names=['station', 'valid_year'])
measyearcount.head(1000)
# Out:
#    station  valid_year
# 0        0    0.998156
# 1        1    0.955808
# 2        2    0.920362
# 3        3    0.913134
# 4        4    0.905290
# 5        5    0.904233
# 6        6    0.793765
# 7        7    0.793501
# 8        8    0.752430
# 9        9    0.750072
# 10      10    0.749862
# 11      11    0.724829
# 12      12    0.708410
# 13      13    0.708185
# 14      14    0.707653
# 15      15    0.706837
# 16      16    0.692214
# 17      17    0.688418
# 18      18    0.594347
# 19      19    0.549261
# 20      20    0.544924
# 21      21    0.518538
# 22      22    0.458820
# 23      23    0.455866
# 24      24    0.429572
# 25      25    0.429387
# 26      26    0.425332
# 27      27    0.406699
# 28      28    0.406407
# 29      29    0.404925
# 30      30    0.394937
# 31      31    0.380528
# 32      32    0.352704
# 33      33    0.352080
# 34      34    0.344874
# 35      35    0.343219
# 36      36    0.340283
# 37      37    0.336444
# 38      38    0.336366
# 39      39    0.331300
# 40      40    0.326211
# 41      41    0.326209
# 42      42    0.322325
# 43      43    0.313267
# 44      44    0.309553
# 45      45    0.309231
# 46      46    0.308986
# 47      47    0.286116
# 48      48    0.281917
# 49      49    0.272872
# 50       0    0.927224
# 51       1    0.919166
# 52       2    0.895847
# 53       3    0.886926
# 54       4    0.868657
# 55       5    0.855041
# 56       6    0.853103
# 57       7    0.736872
# 58       8    0.733594
# 59       9    0.727930
#        ...         ...
#
# [551 rows x 2 columns]

# %%
# %%writefile PCA_EZE00100082.py
#!/usr/bin/python
"""
count the number of measurements of each type
"""
import sys
sys.path.append('/usr/lib/python2.6/dist-packages')
from mrjob.job import MRJob
import re
import numpy as np
from sys import stderr

class PCA_EZE00100082(MRJob):

    def mapper(self, _, line):
        try:
            self.increment_counter('MrJob Counters','mapper',1)
            # Parse the line
            elements=line.split(',')
            station = elements[0]
            measure_type = elements[1]
            year = int(elements[2])
            measurements = elements[2:]
            nomeas = 0
            #
            AllNum=True
            for ss in measurements:
                if ss!="":
                    try:
                        ii=float(ss)
                        nomeas+=1
                    except:
                        AllNum=False
            #filter out the unwanted measurements and the header line
            if (measure_type == 'TMAX')\
                and "EZE001" in station and len(measurements)==366 and nomeas>=366 and AllNum: 
                self.increment_counter('MrJob Counters','usefull lines',1)
                yield (station, measurements)
                
        except Exception, e:
            stderr.write('Error in line:\n'+line)
            stderr.write(e.message)
            self.increment_counter('MrJob Counters','mapper-error',1)
            yield (('error','mapper', str(e)), 1)
            
    def reducer(self, station, measurements):
        try:
            if station[0] == 'error':
                yield(station,sum(data))
                return
            self.increment_counter('MrJob Counters','reducer',1)
            
            sumvec=np.zeros(365)
            matr=np.zeros((365,365))
            
            number_Year=0
            data={}
            year={}

            for vector in measurements:
                strvec=vector[1:]
                numvec=[int(ss) for ss in strvec]
                data[number_Year]=numvec
                year[number_Year]=int(vector[0])
                number_Year = number_Year + 1
            
            for t in range(0,number_Year):
                sumvec=sumvec+np.array(data[t])
                
            sumlis=sumvec.tolist()
            meanlis=[float(n)/number_Year for n in sumlis]
            
            for t in range(0,number_Year):
                subtarr=np.array(data[t])-np.array(meanlis)
                matr+=np.outer(subtarr,subtarr)
                
            matr=np.divide(matr,number_Year)
            U,D,V=np.linalg.svd(matr)
            varexp=[]
            ptvar=0
            ttvar=sum(D)
            for n in range(0,365):
                ptvar+=D[n]
                if ptvar/ttvar>0.90:
                    break
                    
            k=50
#Eigenvalues:    
            Eig=np.matrix(U[:,:k])
            for t in range(0,number_Year):
                if 1995 <= year[t] and year[t] <= 2013:                    
                    subtarr=np.array(data[t])-np.array(meanlis)  
                    nbs = np.inner(subtarr,subtarr)
                    for i in range(0,k):
                        eigvec =np.array(Eig)[:,i]
                        subtarr = subtarr - np.inner(eigvec,subtarr)*eigvec
                        yield(i, np.inner(subtarr,subtarr)/nbs)
           # matr+=np.outer(subtarr,subtarr)
           # matrix=np.matrix(measurements.ix[:,1:365])#-Mean
           # Prod=matrix*Eig;
                        
            yield(station,n)
        except Exception, e:
            #yield (('error','reducer', str(e)), 1)
            stderr.write('Error in reducer')
        
if __name__ == '__main__':
    PCA_EZE00100082.run()
# Out:
# Overwriting PCA_EZE00100082.py

# %%
# !python PCA_EZE00100082.py -r emr --emr-job-flow-id $job_flow_id hdfs:/weather.raw_data/ALL.csv > PCA_EZE00100082_recent.txt
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/PCA_EZE00100082.ubuntu.20140613.184540.358364
# Copying non-input files into s3://costaszarifisbucket/scratch/PCA_EZE00100082.ubuntu.20140613.184540.358364/files/
# Adding our job to existing job flow j-1XMJYZ35TFPY8
# Job launched 30.2s ago, status RUNNING: Running step (PCA_EZE00100082.ubuntu.20140613.184540.358364: Step 1 of 1)
# Job launched 60.4s ago, status RUNNING: Running step (PCA_EZE00100082.ubuntu.20140613.184540.358364: Step 1 of 1)
# Job launched 90.6s ago, status RUNNING: Running step (PCA_EZE00100082.ubuntu.20140613.184540.358364: Step 1 of 1)
# Job launched 120.9s ago, status RUNNING: Running step (PCA_EZE00100082.ubuntu.20140613.184540.358364: Step 1 of 1)
# Job launched 151.1s ago, status RUNNING: Running step (PCA_EZE00100082.ubuntu.20140613.184540.358364: Step 1 of 1)
# Job launched 181.3s ago, status RUNNING: Running step (PCA_EZE00100082.ubuntu.20140613.184540.358364: Step 1 of 1)
# Job launched 211.5s ago, status RUNNING: Running step (PCA_EZE00100082.ubuntu.20140613.184540.358364: Step 1 of 1)
# Job completed.
# Running time was 172.0s (not counting time spent waiting for the EC2 instances)
# ec2_key_pair_file not specified, going to S3
# Fetching counters from S3...
# Waiting 5.0s for S3 eventual consistency
# Counters from step 1:
#   File Input Format Counters :
#     Bytes Read: 7670788923
#   File Output Format Counters :
#     Bytes Written: 11367
#   FileSystemCounters:
#     FILE_BYTES_READ: 213238
#     FILE_BYTES_WRITTEN: 2303829
#     HDFS_BYTES_READ: 7670795103
#     S3_BYTES_WRITTEN: 11367
#   Job Counters :
#     Data-local map tasks: 58
#     Launched map tasks: 61
#     Launched reduce tasks: 12
#     Rack-local map tasks: 3
#     SLOTS_MILLIS_MAPS: 3492459
#     SLOTS_MILLIS_REDUCES: 380418
#     Total time spent by all maps waiting after reserving slots (ms): 0
#     Total time spent by all reduces waiting after reserving slots (ms): 0
#   Map-Reduce Framework:
#     CPU time spent (ms): 1983220
#     Combine input records: 0
#     Combine output records: 0
#     Map input bytes: 7668890105
#     Map input records: 9358395
#     Map output bytes: 563035
#     Map output materialized bytes: 220758
#     Map output records: 231
#     Physical memory (bytes) snapshot: 28826173440
#     Reduce input groups: 2
#     Reduce input records: 231
#     Reduce output records: 501
#     Reduce shuffle bytes: 220758
#     SPLIT_RAW_BYTES: 6180
#     Spilled Records: 462
#     Total committed heap usage (bytes): 27267170304
#     Virtual memory (bytes) snapshot: 126585139200
#   MrJob Counters:
#     mapper: 9358395
#     reducer: 1
#     usefull lines: 230
# Streaming final output from s3://costaszarifisbucket/scratch/PCA_EZE00100082.ubuntu.20140613.184540.358364/output/
# removing tmp directory /tmp/PCA_EZE00100082.ubuntu.20140613.184540.358364
# Removing all files in s3://costaszarifisbucket/scratch/PCA_EZE00100082.ubuntu.20140613.184540.358364/

# %%
measyearcount = pd.read_csv('PCA_EZE00100082_recent.txt', sep='\t', names=['station', 'valid_year'])
measyearcount.head(1000)
# Out:
#    station  valid_year
# 0        0    0.871450
# 1        1    0.848125
# 2        2    0.845722
# 3        3    0.811814
# 4        4    0.795764
# 5        5    0.795490
# 6        6    0.779564
# 7        7    0.766711
# 8        8    0.750830
# 9        9    0.704495
# 10      10    0.687659
# 11      11    0.611293
# 12      12    0.609739
# 13      13    0.593776
# 14      14    0.593406
# 15      15    0.587710
# 16      16    0.579632
# 17      17    0.564144
# 18      18    0.540118
# 19      19    0.539975
# 20      20    0.522104
# 21      21    0.491441
# 22      22    0.489390
# 23      23    0.458078
# 24      24    0.455420
# 25      25    0.437439
# 26      26    0.427411
# 27      27    0.408379
# 28      28    0.401543
# 29      29    0.401383
# 30      30    0.398985
# 31      31    0.393239
# 32      32    0.393231
# 33      33    0.392070
# 34      34    0.381184
# 35      35    0.349489
# 36      36    0.348910
# 37      37    0.341457
# 38      38    0.332817
# 39      39    0.332679
# 40      40    0.330017
# 41      41    0.329906
# 42      42    0.329109
# 43      43    0.326744
# 44      44    0.325237
# 45      45    0.274518
# 46      46    0.265354
# 47      47    0.262757
# 48      48    0.259697
# 49      49    0.257652
# 50       0    0.953422
# 51       1    0.951638
# 52       2    0.944876
# 53       3    0.937158
# 54       4    0.935650
# 55       5    0.776918
# 56       6    0.775950
# 57       7    0.745068
# 58       8    0.742737
# 59       9    0.725742
#        ...         ...
#
# [501 rows x 2 columns]
