# %%
import pandas as pd
import numpy as np
import sklearn as sk
print 'pandas version: ',pd.__version__
print 'numpy version:',np.__version__
print 'sklearn version:',sk.__version__
# Out:
# pandas version:  0.13.1
# numpy version: 1.8.1
# sklearn version: 0.14.1

# %%
# %%writefile maxminprcp.py
#!/usr/bin/python
"""
count the number of measurements for each base-station
"""
import sys
import pandas as pd
import numpy as np
import sklearn as sk
sys.path.append('/usr/lib/python2.6/dist-packages')
from mrjob.job import MRJob
from mrjob.step import MRStep
import re
from sys import stderr
import json

class maxminprcp(MRJob):
    
    def __init__(self, *args, **kwargs):
        super(maxminprcp, self).__init__(*args, **kwargs)
        self.data = {}
        
    

    def configure_options(self):
        super(maxminprcp, self).configure_options()

        

    def mapper(self, _, line):

        self.increment_counter('MrJob Counters','mapper-all',1)
        elements=line.split(',')
        if elements[0]=='station':
            out=('header','0~0')
        else:
            
            if elements[1]=='PRCP' or elements[1]=='TMAX' or elements[1]=='TMIN':
                x = elements[3:]                
                #sys.stderr.write(str(x))
                floats = [float(strr) if strr else 0 for strr in x]

                #sys.stderr.write('mean is:\n')

            
                aa = [item for item in floats if item != 0]
                mmean = np.mean(aa)


                out=((elements[0]),(elements[1],elements[2], mmean))#+'~'+str(0))
                #sys.stderr.write('printing\n')
                #sys.stderr.write(str(out))
                
                    #sys.stderr.write(str(out))
                yield out

        self.increment_counter('MrJob Counters','mapper-error',1)
            
            # Again... This would be pruned when we would do the inner join later so let's ommit it right away...
            
            
            ################################################################################################################
            # NOTE! Since I could not run the HWPART1 step on the cluster I run it locally and used a smaller dataset      #
            # with TMAX measurements instead. So the basestations included in the ALL.head and the SAMPLE_TMAX are not     #
            # the same... Just use the same file for both Part1 and Part 2                                                 #
            ################################################################################################################
        #   out=('error','0~0')
            #yield out

        
#     def combiner(self, station, vals):
#         yield (0,0)
        
    def reducer(self, station, vals):

        self.increment_counter('MrJob Counters','reducer',1)
        #sys.stderr.write('base-station name is: '+str(station)+'\n')
        valArr = []
       
        #from collections import defaultdict
        d = {}#defaultdict(list)
        for val in vals: 

            a = val[0]
            b = val[1]
            c = val[2]

            if b in d:
                d[b][a] = c
            else:
                d[b] = {}
                d[b][a] = c
        #sys.stderr.write(str(d))

        for k,v in d.iteritems():               # will become d.items() in py3k
          
#             sys.stderr.write('\n')
#             sys.stderr.write('len: ')
#             sys.stderr.write(str(len(v)))
            if len(v)==3:
#                 sys.stderr.write('\n')
#                 sys.stderr.write((str(k)+'-'+str(v)))
#                 sys.stderr.write('\n')
                out = ((station,k,v['TMAX'],v['TMIN'],v['PRCP']), None)
                
#                 sys.stderr.write(str(out))
                yield out
                


if __name__ == '__main__':
    maxminprcp.run()
# Out:
# Overwriting maxminprcp.py

# %%
#local_data='/home/ubuntu/UCSD_BigData/data/weather/ALL.head.csv'
local_data='/home/ubuntu/UCSD_BigData/data/weather/ALL.head.csv'
# !python maxminprcp.py -r local $local_data > counts.out
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/maxminprcp.ubuntu.20140613.122338.646668
# writing to /tmp/maxminprcp.ubuntu.20140613.122338.646668/step-0-mapper_part-00000
# > /home/ubuntu/anaconda/bin/python maxminprcp.py --step-num=0 --mapper /tmp/maxminprcp.ubuntu.20140613.122338.646668/input_part-00000 > /tmp/maxminprcp.ubuntu.20140613.122338.646668/step-0-mapper_part-00000
# writing to /tmp/maxminprcp.ubuntu.20140613.122338.646668/step-0-mapper_part-00001
# > /home/ubuntu/anaconda/bin/python maxminprcp.py --step-num=0 --mapper /tmp/maxminprcp.ubuntu.20140613.122338.646668/input_part-00001 > /tmp/maxminprcp.ubuntu.20140613.122338.646668/step-0-mapper_part-00001
# STDERR: /usr/local/lib/python2.7/dist-packages/numpy/core/_methods.py:55: RuntimeWarning: Mean of empty slice.
# STDERR:   warnings.warn("Mean of empty slice.", RuntimeWarning)
# Counters from step 1:
#   MrJob Counters:
#     mapper-all: 999
#     mapper-error: 999
# writing to /tmp/maxminprcp.ubuntu.20140613.122338.646668/step-0-mapper-sorted
# > sort /tmp/maxminprcp.ubuntu.20140613.122338.646668/step-0-mapper_part-00000 /tmp/maxminprcp.ubuntu.20140613.122338.646668/step-0-mapper_part-00001
# writing to /tmp/maxminprcp.ubuntu.20140613.122338.646668/step-0-reducer_part-00000
# > /home/ubuntu/anaconda/bin/python maxminprcp.py --step-num=0 --reducer /tmp/maxminprcp.ubuntu.20140613.122338.646668/input_part-00000 > /tmp/maxminprcp.ubuntu.20140613.122338.646668/step-0-reducer_part-00000
# writing to /tmp/maxminprcp.ubuntu.20140613.122338.646668/step-0-reducer_part-00001
# > /home/ubuntu/anaconda/bin/python maxminprcp.py --step-num=0 --reducer /tmp/maxminprcp.ubuntu.20140613.122338.646668/input_part-00001 > /tmp/maxminprcp.ubuntu.20140613.122338.646668/step-0-reducer_part-00001
# Counters from step 1:
#   MrJob Counters:
#     mapper-all: 999
#     mapper-error: 999
#     reducer: 11
# Moving /tmp/maxminprcp.ubuntu.20140613.122338.646668/step-0-reducer_part-00000 -> /tmp/maxminprcp.ubuntu.20140613.122338.646668/output/part-00000
# Moving /tmp/maxminprcp.ubuntu.20140613.122338.646668/step-0-reducer_part-00001 -> /tmp/maxminprcp.ubuntu.20140613.122338.646668/output/part-00001
# Streaming final output from /tmp/maxminprcp.ubuntu.20140613.122338.646668/output
# removing tmp directory /tmp/maxminprcp.ubuntu.20140613.122338.646668

# %%
# !head -n 20 counts.out
# Out:
# ["USC00211063", "2003", 136.30172413793105, -5.429378531073446, 69.40322580645162]	null
# ["USC00211063", "1997", 121.77777777777777, 10.850828729281767, 79.4]	null
# ["USC00211063", "1986", 125.93370165745857, 17.701117318435752, 90.17241379310344]	null
# ["USC00211063", "1987", 156.543661971831, 33.05665722379604, 65.66666666666667]	null
# ["USC00211063", "1984", 129.08683473389357, 14.044943820224718, 85.78082191780823]	null
# ["USC00211063", "1985", 116.9475138121547, -4.513888888888889, 73.9875]	null
# ["USC00211063", "1982", 117.30446927374301, 1.6123595505617978, 72.26388888888889]	null
# ["USC00211063", "1983", 124.89531680440771, 18.612535612535613, 60.3855421686747]	null
# ["USC00211063", "1980", 134.187675070028, 15.678466076696164, 61.0655737704918]	null
# ["USC00211063", "1981", 146.05292479108635, 18.459610027855152, 72.53521126760563]	null
# ["USC00211063", "1988", 147.7950138504155, 13.614525139664805, 85.03448275862068]	null
# ["USC00211063", "1989", 123.82191780821918, 2.095505617977528, 74.28947368421052]	null
# ["USC00211063", "1996", 99.3801652892562, -6.481792717086835, 82.44736842105263]	null
# ["USC00211063", "2011", 120.6470588235294, -4.754929577464789, 74.2875]	null
# ["USC00211063", "2010", 120.88795518207283, -1.9202279202279202, 79.15053763440861]	null
# ["USC00211063", "2013", -36.166666666666664, -171.33333333333334, NaN]	null
# ["USC00211063", "2012", 145.74137931034483, 3.8892215568862274, 63.028985507246375]	null
# ["USC00211063", "2005", 138.04545454545453, 6.156976744186046, 82.17948717948718]	null
# ["USC00211063", "1991", 132.6767123287671, 11.247191011235955, 94.69333333333333]	null
# ["USC00211063", "1990", 145.38736263736263, 10.930362116991644, 68.74647887323944]	null

# %%
import pickle
try:
    Creds= pickle.load(open('/home/ubuntu/Vault/Creds.pkl','rb'))
    #print Creds.keys()
    #print Creds['mrjob'].keys()
    pair=Creds['mrjob']
    key_id=pair['key_id']
    secret_key=pair['secret_key']
    ID=pair['ID']
    if ID is not None:
        print 'done!'
    else:
        print 'hmm! Something went wrong!'
        
except:
    print 'hmm! Something went wrong!'
    print sys.exc_info()[0]
#print ID,key_id
# Out:
# done!

# %%
import sys
home_dir='/home/ubuntu/UCSD_BigData'
sys.path.append(home_dir+'/utils')
from find_waiting_flow import *
from AWS_keypair_management import *

# %%
job_flow_id=find_waiting_flow(key_id,secret_key)
job_flow_id
# Out:
# <boto.emr.emrobject.JobFlow object at 0x60ba890> no_script.yoavfreund.20140610.012515.693483 j-3SOQM885E1GLH WAITING
# <boto.emr.emrobject.JobFlow object at 0x6fa3c50> no_script.yoavfreund.20140611.181713.270989 j-3QZOHADZF9KY1 WAITING
# <boto.emr.emrobject.JobFlow object at 0x62f6150> no_script.yoavfreund.20140611.181730.511103 j-2S5LTMBIWD2WB WAITING
# <boto.emr.emrobject.JobFlow object at 0x64d1d10> no_script.yoavfreund.20140613.042333.580519 j-27Y940LIXXNSZ WAITING
# <boto.emr.emrobject.JobFlow object at 0x64dd710> no_script.yoavfreund.20140613.042344.097071 j-3LP88IFUHBOHO WAITING
# u'j-3LP88IFUHBOHO'

# %%
# !python maxminprcp.py -r emr --emr-job-flow-id $job_flow_id hdfs:/weather.raw_data/ALL.csv > countsEMR.out
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/maxminprcp.ubuntu.20140613.122425.399950
# Copying non-input files into s3://costaszarifisbucket/scratch/maxminprcp.ubuntu.20140613.122425.399950/files/
# Adding our job to existing job flow j-3LP88IFUHBOHO
# Job launched 30.2s ago, status RUNNING: Running step (maxminprcp.ubuntu.20140613.122425.399950: Step 1 of 1)
# Job launched 60.5s ago, status RUNNING: Running step (maxminprcp.ubuntu.20140613.122425.399950: Step 1 of 1)
# Job launched 90.8s ago, status RUNNING: Running step (maxminprcp.ubuntu.20140613.122425.399950: Step 1 of 1)
# Job launched 121.0s ago, status RUNNING: Running step (maxminprcp.ubuntu.20140613.122425.399950: Step 1 of 1)
# Job launched 151.3s ago, status RUNNING: Running step (maxminprcp.ubuntu.20140613.122425.399950: Step 1 of 1)
# Job launched 181.6s ago, status RUNNING: Running step (maxminprcp.ubuntu.20140613.122425.399950: Step 1 of 1)
# Job launched 211.8s ago, status RUNNING: Running step (maxminprcp.ubuntu.20140613.122425.399950: Step 1 of 1)
# Job launched 242.1s ago, status RUNNING: Running step (maxminprcp.ubuntu.20140613.122425.399950: Step 1 of 1)
# Job completed.
# Running time was 239.0s (not counting time spent waiting for the EC2 instances)
# ec2_key_pair_file not specified, going to S3
# Fetching counters from S3...
# Waiting 5.0s for S3 eventual consistency
# Counters may not have been uploaded to S3 yet. Try again in 5 minutes with: mrjob fetch-logs --counters j-3LP88IFUHBOHO
# Counters from step 1:
#   (no counters found)
# Streaming final output from s3://costaszarifisbucket/scratch/maxminprcp.ubuntu.20140613.122425.399950/output/
# removing tmp directory /tmp/maxminprcp.ubuntu.20140613.122425.399950
# Removing all files in s3://costaszarifisbucket/scratch/maxminprcp.ubuntu.20140613.122425.399950/

# %%
def parser(inp,outp ):
    import csv

    headers = ['a','b','c','d']
    with open(inp) as csvfile, open(outp,'wb') as out:
        reader = csv.reader(csvfile, delimiter=']', quotechar='|')
        writer = csv.writer(out,headers)
        for row in reader:
            rowstr = str(row)
            #print row
            elems = rowstr.split(',')
            a = elems[0].replace('[\'[', '')
            #print a
            b = elems[1]
            #print b
            c = elems[2]
            #print c
            d = elems[3].replace('\'', '')
            #print d
            e = elems[4].replace('\'', '')
            #print e
            writer.writerow([a,b,c,d,e])

# %%
parser('countsEMR.out','parsable.csv')

# %%
# !head -n 20 parsable.csv
# Out:
# """AJ000037756"""," ""1986""", 122.40625, 34.77777777777778, 36.40909090909091
# """AJ000037756"""," ""1987""", 127.4, 65.6086956521739, 40.56818181818182
# """AJ000037756"""," ""1984""", 123.23076923076923, 33.45, 41.40650406504065
# """AJ000037756"""," ""1985""", 154.95, 77.2156862745098, 32.81896551724138
# """AJ000037756"""," ""1982""", 186.22857142857143, 75.26923076923077, 39.93805309734513
# """AJ000037756"""," ""1983""", 9.0, 2.0, 34.74025974025974
# """AJ000037756"""," ""1980""", 195.1851851851852, 100.96153846153847, 36.63793103448276
# """AJ000037756"""," ""1981""", 163.67088607594937, 66.21212121212122, 47.84375
# """AJ000037756"""," ""1988""", 105.0, 24.75, 49.666666666666664
# """AJ000037756"""," ""1989""", 158.7173913043478, 67.375, 46.74324324324324
# """AJ000037756"""," ""2011""", 154.00626959247649, -42.0, 99.0
# """AJ000037756"""," ""2010""", 169.58745874587459, 81.0, 8.0
# """AJ000037756"""," ""1991""", 125.81481481481481, 50.666666666666664, 40.04950495049505
# """AJ000037756"""," ""1990""", 175.0, 76.24, 38.49382716049383
# """AJ000037756"""," ""1979""", 170.18018018018017, 66.75675675675676, 31.946902654867255
# """AJ000037756"""," ""1978""", 155.64705882352942, 71.42857142857143, 31.429906542056074
# """AJ000037756"""," ""1973""", 171.3953488372093, 26.666666666666668, 35.598214285714285
# """AJ000037756"""," ""2009""", 167.14084507042253, 28.5, 15.0
# """AJ000037844"""," ""1989""", 207.125, 125.56164383561644, 45.967213114754095
# """AJ000037844"""," ""1960""", 258.6666666666667, 142.55555555555554, 34.46153846153846

# %%
import pandas as pd
ddf = pd.read_csv('parsable.csv',names=['station', 'year', 'TMAX', 'TMIN', 'PRCP'])

# %%
ddf.head()
# Out:
#          station     year                 TMAX                TMIN  \
# 0  "AJ000037756"   "1986"            122.40625   34.77777777777778
# 1  "AJ000037756"   "1987"                127.4    65.6086956521739
# 2  "AJ000037756"   "1984"   123.23076923076923               33.45
# 3  "AJ000037756"   "1985"               154.95    77.2156862745098
# 4  "AJ000037756"   "1982"   186.22857142857143   75.26923076923077
#
#                  PRCP
# 0   36.40909090909091
# 1   40.56818181818182
# 2   41.40650406504065
# 3   32.81896551724138
# 4   39.93805309734513
#
# [5 rows x 5 columns]

# %%
shape(ddf)
# Out:
# (925658, 5)

# %%
ddf.to_pickle("minmaxprcp.pkl")

# %%
randomdf = pd.read_pickle("minmaxprcp.pkl")

# %%
shape(randomdf)
# Out:
# (925658, 5)

# %%
randomdf.head()
# Out:
#          station     year                 TMAX                TMIN  \
# 0  "AJ000037756"   "1986"            122.40625   34.77777777777778
# 1  "AJ000037756"   "1987"                127.4    65.6086956521739
# 2  "AJ000037756"   "1984"   123.23076923076923               33.45
# 3  "AJ000037756"   "1985"               154.95    77.2156862745098
# 4  "AJ000037756"   "1982"   186.22857142857143   75.26923076923077
#
#                  PRCP
# 0   36.40909090909091
# 1   40.56818181818182
# 2   41.40650406504065
# 3   32.81896551724138
# 4   39.93805309734513
#
# [5 rows x 5 columns]

# %%
gb = randomdf.groupby(['station'])

# %%
#for (i,g) in gb:
#    g
gb.count().sort(['year'], ascending=False)
# Out:
#                station  year  TMAX  TMIN  PRCP
# station
# "EZE00100082"      202   202   202   202   202
# "ITE00100550"      190   190   190   190   190
# "GM000004204"      180   180   180   180   180
# "CA006158350"      164   164   164   164   164
# "ASN00086071"      158   158   158   158   158
# "ASN00066062"      154   154   154   154   154
# "ITE00100554"      151   151   151   151   151
# "ASN00074128"      143   143   143   143   143
# "ASN00090015"      143   143   143   143   143
# "CA006149625"      143   143   143   143   143
# "GMW00035032"      143   143   143   143   143
# "USW00013724"      139   139   139   139   139
# "DA000025140"      138   138   138   138   138
# "DA000021100"      138   138   138   138   138
# "USW00094728"      138   138   138   138   138
# "AU000005010"      138   138   138   138   138
# "CA006139445"      137   137   137   137   137
# "USW00023271"      137   137   137   137   137
# "USW00024128"      137   137   137   137   137
# "GM000003319"      136   136   136   136   136
# "GM000010962"      134   134   134   134   134
# "GM000004063"      134   134   134   134   134
# "ASN00055023"      133   133   133   133   133
# "GM000002698"      133   133   133   133   133
# "USW00014936"      133   133   133   133   133
# "BE000006447"      133   133   133   133   133
# "UPM00033345"      133   133   133   133   133
# "USW00093820"      132   132   132   132   132
# "GM000004199"      132   132   132   132   132
# "RSM00026063"      132   132   132   132   132
# "USC00030936"      131   131   131   131   131
# "CA003031093"      131   131   131   131   131
# "USC00035754"      130   130   130   130   130
# "USC00035186"      130   130   130   130   130
# "DA000027080"      130   130   130   130   130
# "ASN00026026"      129   129   129   129   129
# "HR000142360"      128   128   128   128   128
# "USC00215638"      128   128   128   128   128
# "USC00200146"      127   127   127   127   127
# "USC00200032"      127   127   127   127   127
# "EI000003969"      126   126   126   126   126
# "ASN00048013"      126   126   126   126   126
# "USC00173046"      126   126   126   126   126
# "ASN00038003"      125   125   125   125   125
# "USW00024157"      125   125   125   125   125
# "RSM00030710"      125   125   125   125   125
# "CA003034480"      125   125   125   125   125
# "USC00068138"      125   125   125   125   125
# "CA006105976"      125   125   125   125   125
# "CA001100120"      125   125   125   125   125
# "USC00307633"      125   125   125   125   125
# "CA004013480"      125   125   125   125   125
# "CA001090660"      124   124   124   124   124
# "ASN00056017"      124   124   124   124   124
# "UZM00038457"      124   124   124   124   124
# "ASN00065016"      124   124   124   124   124
# "USC00031152"      124   124   124   124   124
# "RSM00034880"      124   124   124   124   124
# "USC00444876"      123   123   123   123   123
# "USC00200230"      123   123   123   123   123
#                    ...   ...   ...   ...   ...
#
# [27412 rows x 5 columns]
