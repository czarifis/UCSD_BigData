# %% [markdown]
# ## Weather processing
#
# Let's begin by loading the data we have about the stations.

# %%
## Let's remove stations.pkl file in case it exists and re-create it by unzip the corresponding .gz file
## Also let's import everything
import pandas as pd
import numpy as np
import sklearn as sk
import sys
print 'pandas version: ',pd.__version__
print 'numpy version:',np.__version__
print 'sklearn version:',sk.__version__
# !ls -al
# !rm stations.pkl
# Out:
# pandas version:  0.13.1
# numpy version: 1.8.1
# sklearn version: 0.14.1
# total 13524
# drwxrwxr-x  3 ubuntu ubuntu     4096 May 15 01:05 .
# drwxrwxr-x 14 ubuntu ubuntu     4096 May 15 00:50 ..
# -rw-rw-r--  1 ubuntu ubuntu        0 May 15 00:50 counts
# -rw-rw-r--  1 ubuntu ubuntu    55076 May 15 00:50 imgofcorrwithrowswithNaNs.png
# drwxrwxr-x  2 ubuntu ubuntu     4096 May 15 00:50 .ipynb_checkpoints
# -rw-rw-r--  1 ubuntu ubuntu    43085 May 15 01:05 MyNotebookWeather.ipynb
# -rw-rw-r--  1 ubuntu ubuntu    81044 May 15 00:50 Simple use of mrjob.ipynb
# -rw-rw-r--  1 ubuntu ubuntu        0 May 15 01:05 stations.pkl
# -rw-rw-r--  1 ubuntu ubuntu 13649186 May 15 00:50 Weather Analysis.ipynb

# %%
#!gunzip stations.pkl.gz
import pickle
# !gunzip -c stations.pkl.gz > stations.pkl  # This command also keeps the initial gz file....
# !ls -al
#stations=pickle.load(open('stations.pkl', 'rb'))
# Out:
# gzip: stations.pkl.gz: No such file or directory
# total 13524
# drwxrwxr-x  3 ubuntu ubuntu     4096 May 15 01:06 .
# drwxrwxr-x 14 ubuntu ubuntu     4096 May 15 00:50 ..
# -rw-rw-r--  1 ubuntu ubuntu        0 May 15 00:50 counts
# -rw-rw-r--  1 ubuntu ubuntu    55076 May 15 00:50 imgofcorrwithrowswithNaNs.png
# drwxrwxr-x  2 ubuntu ubuntu     4096 May 15 00:50 .ipynb_checkpoints
# -rw-rw-r--  1 ubuntu ubuntu    43085 May 15 01:05 MyNotebookWeather.ipynb
# -rw-rw-r--  1 ubuntu ubuntu    81044 May 15 00:50 Simple use of mrjob.ipynb
# -rw-rw-r--  1 ubuntu ubuntu        0 May 15 01:07 stations.pkl
# -rw-rw-r--  1 ubuntu ubuntu 13649186 May 15 00:50 Weather Analysis.ipynb

# %%
stations.head()
# Out:
#              latitude  longitude  elevation state                   name  \
# ACW00011604   17.1167   -61.7833       10.1   NaN  ST JOHNS COOLIDGE FLD
# ACW00011647   17.1333   -61.7833       19.2   NaN               ST JOHNS
# AE000041196   25.3330    55.5170       34.0   NaN    SHARJAH INTER. AIRP
# AF000040930   35.3170    69.0170     3366.0   NaN           NORTH-SALANG
# AG000060390   36.7167     3.2500       24.0   NaN     ALGER-DAR EL BEIDA
#
#             GSNFLAG HCNFLAG  WMOID
# ACW00011604     NaN     NaN    NaN
# ACW00011647     NaN     NaN    NaN
# AE000041196     GSN     NaN  41196
# AF000040930     GSN     NaN  40930
# AG000060390     GSN     NaN  60390
#
# [5 rows x 8 columns]

# %%
## Let's see if we can connect to S3
import boto
from boto.s3.connection import S3Connection
from boto.s3.connection import OrdinaryCallingFormat  # this allows us to use buckets that have uppercase letters in their names...
conn = boto.connect_s3(calling_format=OrdinaryCallingFormat())
rs = conn.get_all_buckets()
print "printing all the buckets"
rs
# Out:
# printing all the buckets
# [<Bucket: ChuanBucket>,
#  <Bucket: Weather.GHNC>,
#  <Bucket: Yoav.Freund.packages>,
#  <Bucket: costaszarifisbucket>,
#  <Bucket: dlisuk_291>,
#  <Bucket: ioperformance.bucket>,
#  <Bucket: kritika.hadoop>,
#  <Bucket: lge-bucket>,
#  <Bucket: lgetest2>,
#  <Bucket: mrjob-3b924da3e95e94bc>,
#  <Bucket: mrjob-60ab089fcfb9e4e3>,
#  <Bucket: mrjob-71c4e33417a2cde8>,
#  <Bucket: mrjob-77b7071bb473367d>,
#  <Bucket: mrjob-799ea42d680b5b63>,
#  <Bucket: mrjob-7b50eae46df5c170>,
#  <Bucket: mrjob-8761d7f3a3ce8362>,
#  <Bucket: mrjob-944cb5042b5545b1>,
#  <Bucket: mrjob-e050ab84fd82ce04>,
#  <Bucket: mrjob-e88caacacdceef71>,
#  <Bucket: mrjob-fe67233070aeafaf>,
#  <Bucket: woerns.bucket>,
#  <Bucket: xinxin.bucket>,
#  <Bucket: ye.bucket>,
#  <Bucket: yoav.hadoop>,
#  <Bucket: yoav_student>]

# %%
bucket = conn.get_bucket('Weather.GHNC')
for key in bucket.list():
    print key.name.encode('utf-8')
# Out:
# ALL.csv.gz
# data-source.txt
# ghcnd-readme.txt
# ghcnd-stations.txt
# ghcnd-stations_buffered.txt
# ghcnd-version.txt

# %%
bucket = conn.get_bucket('costaszarifisbucket')
for key in bucket.list():
    print key.name.encode('utf-8')
# Out:
# logs/>/j-1QU0XZUANXAW9/daemons/i-d18b8782/hadoop-hadoop-datanode-ip-10-91-183-114.ec2.internal.log
# logs/>/j-1QU0XZUANXAW9/daemons/i-d18b8782/hadoop-hadoop-datanode-ip-10-91-183-114.ec2.internal.out
# logs/>/j-1QU0XZUANXAW9/daemons/i-d18b8782/hadoop-hadoop-jobtracker-ip-10-91-183-114.ec2.internal.log
# logs/>/j-1QU0XZUANXAW9/daemons/i-d18b8782/hadoop-hadoop-jobtracker-ip-10-91-183-114.ec2.internal.out
# logs/>/j-1QU0XZUANXAW9/daemons/i-d18b8782/hadoop-hadoop-namenode-ip-10-91-183-114.ec2.internal.log
# logs/>/j-1QU0XZUANXAW9/daemons/i-d18b8782/hadoop-hadoop-namenode-ip-10-91-183-114.ec2.internal.out
# logs/>/j-1QU0XZUANXAW9/daemons/i-d18b8782/hadoop-hadoop-tasktracker-ip-10-91-183-114.ec2.internal.log
# logs/>/j-1QU0XZUANXAW9/daemons/i-d18b8782/hadoop-hadoop-tasktracker-ip-10-91-183-114.ec2.internal.out
# logs/>/j-1QU0XZUANXAW9/node/i-d18b8782/bootstrap-actions/1/controller
# logs/>/j-1QU0XZUANXAW9/node/i-d18b8782/bootstrap-actions/1/stderr
# logs/>/j-1QU0XZUANXAW9/node/i-d18b8782/bootstrap-actions/1/stdout
# logs/>/j-1QU0XZUANXAW9/node/i-d18b8782/bootstrap-actions/master.log
# logs/>/j-1QU0XZUANXAW9/steps/1/controller
# logs/>/j-1QU0XZUANXAW9/steps/1/stderr
# logs/>/j-1QU0XZUANXAW9/steps/1/stdout
# logs/>/j-1QU0XZUANXAW9/steps/1/syslog
# logs/>/j-2HQTB1YJKWZPS/daemons/i-ea808cb9/hadoop-hadoop-datanode-ip-10-169-15-217.ec2.internal.log
# logs/>/j-2HQTB1YJKWZPS/daemons/i-ea808cb9/hadoop-hadoop-datanode-ip-10-169-15-217.ec2.internal.out
# logs/>/j-2HQTB1YJKWZPS/daemons/i-ea808cb9/hadoop-hadoop-jobtracker-ip-10-169-15-217.ec2.internal.log
# logs/>/j-2HQTB1YJKWZPS/daemons/i-ea808cb9/hadoop-hadoop-jobtracker-ip-10-169-15-217.ec2.internal.out
# logs/>/j-2HQTB1YJKWZPS/daemons/i-ea808cb9/hadoop-hadoop-namenode-ip-10-169-15-217.ec2.internal.log
# logs/>/j-2HQTB1YJKWZPS/daemons/i-ea808cb9/hadoop-hadoop-namenode-ip-10-169-15-217.ec2.internal.out
# logs/>/j-2HQTB1YJKWZPS/daemons/i-ea808cb9/hadoop-hadoop
# logs/>/j-2JZB884TC8RDT/steps/2/stderr
# logs/>/j-2JZB884TC8RDT/steps/2/stdout
# logs/>/j-2JZB884TC8RDT/steps/2/syslog
# logs/>/j-2JZB884TC8RDT/steps/3/controller
# logs/>/j-2JZB884TC8RDT/steps/3/stderr
# logs/>/j-2JZB884TC8RDT/steps/3/stdout
# logs/>/j-2JZB884TC8RDT/steps/3/syslog
# logs/>/j-32W3HR7X1NNCP/daemons/i-e4fcf0b7/hadoop-hadoop-datanode-ip-10-157-37-41.ec2.internal.log
# logs/>/j-32W3HR7X1NNCP/daemons/i-e4fcf0b7/hadoop-hadoop-datanode-ip-10-157-37-41.ec2.internal.out
# logs/>/j-32W3HR7X1NNCP/daemons/i-e4fcf0b7/hadoop-hadoop-jobtracker-ip-10-157-37-41.ec2.internal.log
# logs/>/j-32W3HR7X1NNCP/daemons/i-e4fcf0b7/hadoop-hadoop-jobtracker-ip-10-157-37-41.ec2.internal.out
# logs/>/j-32W3HR7X1NNCP/daemons/i-e4fcf0b7/hadoop-hadoop-namenode-ip-10-157-37-41.ec2.internal.log
# logs/>/j-32W3HR7X1NNCP/daemons/i-e4fcf0b7/hadoop-hadoop-namenode-ip-10-157-37-41.ec2.internal.out
# logs/>/j-32W3HR7X1NNCP/daemons/i-e4fcf0b7/hadoop-hadoop-tasktracker-ip-10-157-37-41.ec2.internal.log
# logs/>/j-32W3HR7X1NNCP/daemons/i-e4fcf0b7/hadoop-hadoop-tasktracker-ip-10-157-37-41.ec2.internal.out
# logs/>/j-32W3HR7X1NNCP/node/i-e4fcf0b7/bootstrap-actions/1/controller
# logs/>/j-32W3HR7X1NNCP/node/i-e4fcf0b7/bootstrap-actions/1/stderr
# logs/>/j-32W3HR7X1NNCP/node/i-e4fcf0b7/bootstrap-actions/1/stdout
# logs/>/j-32W3HR7X1NNCP/node/i-e4fcf0b7/bootstrap-actions/master.log
# logs/>/j-32W3HR7X1NNCP/steps/1/controller
# logs/>/j-32W3HR7X1NNCP/steps/1/stderr
# logs/>/j-32W3HR7X1NNCP/steps/1/stdout
# logs/>/j-32W3HR7X1NNCP/steps/1/syslog
# logs/>/j-3IBWPJDQBBUSV/daemons/i-edf4f8be/hadoop-hadoop-datanode-ip-10-234-23-135.ec2.internal.log
# logs/>/j-3IBWPJDQBBUSV/daemons/i-edf4f8be/hadoop-hadoop-datanode-ip-10-234-23-135.ec2.internal.out
# logs/>/j-3IBWPJDQBBUSV/daemons/i-edf4f8be/hadoop-hadoop-jobtracker-ip-10-234-23-135.ec2.internal.log
# logs/>/j-3IBWPJDQBBUSV/daemons/i-edf4f8be/hadoop-hadoop-jobtracker-ip-10-234-23-135.ec2.internal.out
# logs/>/j-3IBWPJDQBBUSV/daemons/i-edf4f8be/hadoop-hadoop-namenode-ip-10-234-23-135.ec2.internal.log
# logs/>/j-3IBWPJDQBBUSV/daemons/i-edf4f8be/hadoop-hadoop-namenode-ip-10-234-23-135.ec2.internal.out
# logs/>/j-3IBWPJDQBBUSV/daemons/i-edf4f8be/hadoop-hadoop-tasktracker-ip-10-234-23-135.ec2.internal.log
# logs/>/j-3IBWPJDQBBUSV/daemons/i-edf4f8be/hadoop-hadoop-tasktracker-ip-10-234-23-135.ec2.internal.out
# logs/>/j-3IBWPJDQBBUSV/node/i-edf4f8be/bootstrap-actions/1/controller
# logs/>/j-3IBWPJDQBBUSV/node/i-edf4f8be/bootstrap-actions/1/stderr
# logs/>/j-3IBWPJDQBBUSV/node/i-edf4f8be/bootstrap-actions/1/stdout
# logs/>/j-3IBWPJDQBBUSV/node/i-edf4f8be/bootstrap-actions/master.log
# logs/>/j-3IBWPJDQBBUSV/steps/1/controller
# logs/>/j-3IBWPJDQBBUSV/steps/1/stderr
# logs/>/j-3IBWPJDQBBUSV/steps/1/stdout
# logs/>/j-3IBWPJDQBBUSV/steps/1/syslog
# logs/>/j-3QS5NVR6BNCSI/daemons/i-49f9f51a/hadoop-hadoop-datanode-ip-10-65-139-160.ec2.internal.log
# logs/>/j-3QS5NVR6BNCSI/daemons/i-49f9f51a/hadoop-hadoop-datanode-ip-10-65-139-160.ec2.internal.out
# logs/>/j-3QS5NVR6BNCSI/daemons/i-49f9f51a/hadoop-hadoop-jobtracker-ip-10-65-139-160.ec2.internal.log
# logs/>/j-3QS5NVR6BNCSI/daemons/i-49f9f51a/hadoop-hadoop-jobtracker-ip-10-65-139-160.ec2.internal.out
# logs/>/j-3QS5NVR6BNCSI/daemons/i-49f9f51a/hadoop-hadoop-namenode-ip-10-65-139-160.ec2.internal.log
# logs/>/j-3QS5NVR6BNCSI/daemons/i-49f9f51a/hadoop-hadoop-namenode-ip-10-65-139-160.ec2.internal.out
# logs/>/j-3QS5NVR6BNCSI/daemons/i-49f9f51a/hadoop-hadoop-tasktracker-ip-10-65-139-160.ec2.internal.log
# logs/>/j-3QS5NVR6BNCSI/daemons/i-49f9f51a/hadoop-hadoop-tasktracker-ip-10-65-139-160.ec2.internal.out
# logs/>/j-3QS5NVR6BNCSI/node/i-49f9f51a/bootstrap-actions/1/controller
# logs/>/j-3QS5NVR6BNCSI/node/i-49f9f51a/bootstrap-actions/1/stderr
# logs/>/j-3QS5NVR6BNCSI/node/i-49f9f51a/bootstrap-actions/1/stdout
# logs/>/j-3QS5NVR6BNCSI/node/i-49f9f51a/bootstrap-actions/master.log
# logs/>/j-3QS5NVR6BNCSI/steps/1/controller
# logs/>/j-3QS5NVR6BNCSI/steps/1/stderr
# logs/>/j-3QS5NVR6BNCSI/steps/1/stdout
# logs/>/j-3QS5NVR6BNCSI/steps/1/syslog
# scratch/>/actualWordFreqCount.ubuntu.20140511.105930.707501/files/actualWordFreqCount-1.py
# scratch/>/actualWordFreqCount.ubuntu.20140511.105930.707501/files/actualWordFreqCount.py
# scratch/>/actualWordFreqCount.ubuntu.20140511.105930.707501/files/b.py
# scratch/>/actualWordFreqCount.ubuntu.20140511.105930.707501/files/mrjob.tar.gz
# scratch/>/actualWordFreqCount.ubuntu.20140511.110645.192520/files/ALL.head.csv
# scratch/>/actualWordFreqCount.ubuntu.20140511.110645.192520/files/actualWordFreqCount.py
# scratch/>/actualWordFreqCount.ubuntu.20140511.110645.192520/files/b.py
# scratch/>/actualWordFreqCount.ubuntu.20140511.110645.192520/files/mrjob.tar.gz
# scratch/>/actualWordFreqCount.ubuntu.20140511.112349.509294/files/ALL.head.csv
# scratch/>/actualWordFreqCount.ubuntu.20140511.112349.509294/files/actualWordFreqCount.py
# scratch/>/actualWordFreqCount.ubuntu.20140511.112349.509294/files/mrjob.tar.gz
# scratch/>/actualWordFreqCount.ubuntu.20140511.112639.830999/files/actualWordFreqCount.py
# scratch/>/actualWordFreqCount.ubuntu.20140511.112639.830999/files/mrjob.tar.gz
# scratch/>/actualWordFreqCount.ubuntu.20140511.113254.132396/files/actualWordFreqCount.py
# scratch/>/actualWordFreqCount.ubuntu.20140511.113254.132396/files/mrjob.tar.gz
# scratch/>/actualWordFreqCount.ubuntu.20140511.113546.746731/files/ALL.head.csv
# scratch/>/actualWordFreqCount.ubuntu.20140511.113546.746731/files/actualWordFreqCount.py
# scratch/>/actualWordFreqCount.ubuntu.20140511.113546.746731/files/b.py
# scratch/>/actualWordFreqCount.ubuntu.20140511.113546.746731/files/mrjob.tar.gz
# scratch/>/actualWordFreqCount.ubuntu.20140511.114547.764955/files/actualWordFreqCount.py
# scratch/>/actualWordFreqCount.ubuntu.20140511.114547.764955/files/b.py
# scratch/>/actualWordFreqCount.ubuntu.20140511.114547.764955/files/mrjob.tar.gz
# scratch/>/actualWordFreqCount.ubuntu.20140511.210033.103153/files/actualWordFreqCount.py
# scratch/>/actualWordFreqCount.ubuntu.20140511.210033.103153/files/mrjob.tar.gz
# scratch/>/actualWordFreqCount.ubuntu.20140511.210425.839516/files/ALL.head.csv
# scratch/>/actualWordFreqCount.ubuntu.20140511.210425.839516/files/actualWordFreqCount.py
# scratch/>/actualWordFreqCount.ubuntu.20140511.210425.839516/files/mrjob.tar.gz
# scratch/>/mr_weather.ubuntu.20140511.103541.506743/files/mr_weather.py
# scratch/>/mr_weather.ubuntu.20140511.103541.506743/files/mrjob.tar.gz
# scratch/>/mr_weather.ubuntu.20140511.104257.789409/files/ALL.head.csv
# scratch/>/mr_weather.ubuntu.20140511.104257.789409/files/mr_weather.py
# scratch/>/mr_weather.ubuntu.20140511.104257.789409/files/mrjob.tar.gz
# scratch/>/mr_weather.ubuntu.20140511.210523.233175/files/ALL.head.csv
# scratch/>/mr_weather.ubuntu.20140511.210523.233175/files/mr_weather.py
# scratch/>/mr_weather.ubuntu.20140511.210523.233175/files/mrjob.tar.gz
# scratch/>/mr_weather.ubuntu.20140513.002535.605100/files/mr_weather.py
# scratch/>/mr_weather.ubuntu.20140513.002535.605100/files/mrjob.tar.gz
# scratch/>/mr_weather.ubuntu.20140513.004214.434001/files/mr_weather.py
# scratch/>/mr_weather.ubuntu.20140513.004214.434001/files/mrjob.tar.gz
# scratch/>/mr_word_freq_count.ubuntu.20140511.105122.491003/files/b.py
# scratch/>/mr_word_freq_count.ubuntu.20140511.105122.491003/files/mr_word_freq_count-1.py
# scratch/>/mr_word_freq_count.ubuntu.20140511.105122.491003/files/mr_word_freq_count.py
# scratch/>/mr_word_freq_count.ubuntu.20140511.105122.491003/files/mrjob.tar.gz
# scratch/>/no_script.ubuntu.20140511.113214.387090/files/b.py
# scratch/>/no_script.ubuntu.20140511.113214.387090/files/mrjob.tar.gz
# scratch/mr_weather.ubuntu.20140513.011303.556782/files/mr_weather.py
# scratch/mr_weather.ubuntu.20140513.011303.556782/files/mrjob.tar.gz

# %%
# %%writefile mr_weather.py
#!/usr/bin/python
"""
count the number of measurements of each type
"""
from mrjob.job import MRJob
import re
from sys import stderr

#logfile=open('log','w')
logfile=stderr

class MRWeather(MRJob):

    def mapper(self, _, line):
        self.increment_counter('MrJob Counters','mapper',1)
        elements=line.split(',')
        if elements[0]=='station':
            yield('header',1)
        else:
            yield(elements[1],1)
            
    def combiner(self, word, counts):
        self.increment_counter('MrJob Counters','combiner',1)
        yield (word, sum(counts))
        #l_counts=[c for c in counts]  # extract list from iterator
        #S=sum(l_counts)
        #logfile.write('combiner '+word+' ['+','.join([str(c) for c in l_counts])+']='+str(S)+'\n')
        #yield (word, S)

    def reducer(self, word, counts):
        self.increment_counter('MrJob Counters','reducer',1)
        yield (word, sum(counts))
        #l_counts=[c for c in counts]  # extract list from iterator
        #S=sum(l_counts)
        #logfile.write('reducer '+word+' ['+','.join([str(c) for c in l_counts])+']='+str(S)+'\n')
        #yield (word, S)

if __name__ == '__main__':
    MRWeather.run()
# Out:
# Overwriting mr_weather.py

# %%
# !ls -al
# Out:
# total 10000
# drwxrwxr-x  3 ubuntu ubuntu    4096 May 15 00:47 .
# drwxrwxr-x 14 ubuntu ubuntu    4096 May 10 00:34 ..
# -rwxrwxr-x  1 ubuntu ubuntu     307 May 10 00:34 coding.py
# -rw-rw-r--  1 ubuntu ubuntu    2506 May 10 00:34 Description of Assignment.ipynb
# -rwxrwxr-x  1 ubuntu ubuntu     723 May 10 00:34 Eigen-by-Station.sh
# drwxrwxr-x  2 ubuntu ubuntu    4096 May 11 23:32 .ipynb_checkpoints
# -rwxrwxr-x  1 ubuntu ubuntu    1408 May 10 00:34 map-year-temp.py
# -rw-rw-r--  1 ubuntu ubuntu  114179 May 11 22:57 mrjob and EMR.ipynb
# -rw-rw-r--  1 ubuntu ubuntu    1198 May 15 00:48 mr_weather.py
# -rw-rw-r--  1 ubuntu ubuntu    1610 May 10 00:34 mr_word_freq_count.py
# -rw-rw-r--  1 ubuntu ubuntu   39036 May 15 00:47 MyNotebookWeather.ipynb
# -rw-rw-r--  1 ubuntu ubuntu     698 May 10 00:34 README.txt
# -rwxrwxr-x  1 ubuntu ubuntu    1226 May 10 00:34 reduce-year-temp.py
# -rw-rw-r--  1 ubuntu ubuntu 8051413 May 15 00:47 stations.pkl
# -rw-rw-r--  1 ubuntu ubuntu 1833012 May 10 00:34 stations.pkl.gz
# -rwxrwxr-x  1 ubuntu ubuntu    5136 May 10 00:34 Statistics.py
# -rw-rw-r--  1 ubuntu ubuntu   77711 May 11 23:48 weather_MRjob.ipynb
# -rw-rw-r--  1 ubuntu ubuntu   63952 May 15 00:38 weather_MRjob-with-utils.ipynb

# %%
# here we choose to use the second key pair
(Creds,bad_files) =Get_Working_Credentials('/home/ubuntu/Vault')
Creds
pair=Creds['kozarifi'][0]
key_id=pair['Access_Key_Id']
secret_key=pair['Secret_Access_Key']
job_flow_id=find_waiting_flow(key_id,secret_key)
job_flow_id
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-125e864581c3> in <module>()
#       1 # here we choose to use the second key pair
# ----> 2 (Creds,bad_files) =Get_Working_Credentials('/home/ubuntu/Vault')
#       3 Creds
#       4 pair=Creds['kozarifi'][0]
#       5 key_id=pair['Access_Key_Id']
#
# NameError: name 'Get_Working_Credentials' is not defined
