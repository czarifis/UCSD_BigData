# %% [markdown]
# # **K-means Clustering**

# %% [markdown]
# ### In this notebook, we have all the process which is needed for climate classification using K-means Clustering

# %% [markdown]
# As usual, we setup the enviroment, and then load the station information (lantitude, longitude and elevation).

# %%
import sys
home_dir='/home/ubuntu/UCSD_BigData'
sys.path.append(home_dir+'/utils')
from find_waiting_flow import *
from AWS_keypair_management import *

import pickle
import gzip
import pandas as pd

Creds= pickle.load(open('/home/ubuntu/Vault/Creds.pkl','rb'))
pair=Creds['mrjob']
key_id=pair['key_id']
secret_key=pair['secret_key']
ID=pair['ID']
print 'ID: %s, key_id: %s' % (ID, key_id)

statfile = '/home/ubuntu/UCSD_BigData/notebooks/weather.mapreduce/stations.pkl.gz'
statinfo = pickle.load(gzip.open(statfile,'rb'))
del statinfo['state']
del statinfo['name']
del statinfo['GSNFLAG']
del statinfo['HCNFLAG']
del statinfo['WMOID']
statinfo.head()
# Out:
# ID: kozarifi, key_id: AKIAIXCNAVZPV64ER67Q
# ...
#  no_script.yoavfreund.20140610.012507.678804 j-NIGXU2E6YEU3 WAITING
# <boto.emr.emrobject.JobFlow object at 0x5c05a90> no_script.yoavfreund.20140610.012515.693483 j-3SOQM885E1GLH WAITING
# <boto.emr.emrobject.JobFlow object at 0x5c20b90> no_script.yoavfreund.20140610.012523.713192 j-34Q4HR41T9BWU WAITING
# <boto.emr.emrobject.JobFlow object at 0x59fa7d0> no_script.yoavfreund.20140610.012531.672863 j-31PKW9W4C2YQK WAITING
# <boto.emr.emrobject.JobFlow object at 0x5a210d0> no_script.yoavfreund.20140611.181703.600873 j-2N4U1USC54EM6 WAITING
# <boto.emr.emrobject.JobFlow object at 0x5a27890> no_script.yoavfreund.20140611.181713.270989 j-3QZOHADZF9KY1 WAITING
# <boto.emr.emrobject.JobFlow object at 0x5332c50> no_script.yoavfreund.20140611.181722.314318 j-3MR2RR5OEXRQ7 WAITING
# <boto.emr.emrobject.JobFlow object at 0x5347390> no_script.yoavfreund.20140611.181730.511103 j-2S5LTMBIWD2WB WAITING
# ...

# %% [markdown]
# Here is the code to get the informations of mean temperature of each station, if a station have multiple years of data, we still take the average of it. In the end, we want following things:
#
# 1. Mean Temperature
# 2. Average difference of temperature
# 3. Mean Precipitation

# %%
# %%writefile infoforkmeans.py
#!/usr/bin/python
"""
count the number of measurements of each type
"""
import sys
import numpy as np
sys.path.append('/usr/lib/python2.6/dist-packages')
from mrjob.job import MRJob
import re
from sys import stderr

class infoforkmeans(MRJob):

    def mapper(self, _, line):
        try:
            self.increment_counter('MrJob Counters','mapper',1)
            # Parse the line
            elements=line.split(',')
            station = elements[0]
            measure_type = elements[1]
            year = int(elements[2])
            measurements = elements[3:]
            nomeas = 0
            #
            AllNum=True
            usefulmeas=[]
            for ss in measurements:
                if ss!="":
                    try:
                        ii=float(ss)
                        usefulmeas.append(ii)
                        nomeas+=1
                    except:
                        AllNum=False
            #filter out the unwanted measurements and the header line
            if (measure_type == 'TMIN' or measure_type == 'TMAX' or measure_type=='PRCP') \
                and station != 'station' and len(measurements)==365 and nomeas>200 and AllNum: 
                self.increment_counter('MrJob Counters','usefull lines',1)
                yield (station, [year,measure_type,usefulmeas])
                
        except Exception, e:
            stderr.write('Error in line:\n'+line)
            stderr.write(e.message)
            self.increment_counter('MrJob Counters','mapper-error',1)
            yield (('error','mapper', str(e)), 1)
            
    def reducer(self, station, counts):
        try:
            if station[0] == 'error':
                yield(station,sum(data))
                return
            self.increment_counter('MrJob Counters','reducer',1)
            dic_TMIN={}
            dic_TMAX={}
            dic_PRCP={}
            for vec in counts:
                if vec[1]=='TMIN':
                    dic_TMIN[vec[0]]=vec[2]
                elif vec[1]=='TMAX':
                    dic_TMAX[vec[0]]=vec[2]
                else:
                    dic_PRCP[vec[0]]=vec[2]
            validyear=[]
            mean_MEAN=[]
            mean_PRCP=[]
            diff_MEAN=[]
            for key in dic_TMIN:
                if dic_TMAX.has_key(key) and dic_PRCP.has_key(key):
                    validyear.append(key)
                    #mm=np.mean(np.array(dic_TMAX[key]))+np.mean(np.array(dic_TMIN[key]))
                    #mean_MEAN.append(mm/2.0)
                    mean_PRCP.append(np.mean(np.array(dic_PRCP[key])))
                    #diff_MEAN.append(mm)
            if len(validyear)>0:
                yield (station, np.mean(np.array(mean_PRCP)))
        except Exception, e:
            #yield (('error','reducer', str(e)), 1)
            stderr.write('Error in reducer')
        
if __name__ == '__main__':
    infoforkmeans.run()
# Out:
# Overwriting infoforkmeans.py

# %%
job_flow_id="j-3QZOHADZF9KY1"

# %%
# !python infoforkmeans.py -r emr --emr-job-flow-id $job_flow_id hdfs:/weather.raw_data/ALL.csv > meanprcp.txt
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/infoforkmeans.ubuntu.20140613.071449.894551
# Copying non-input files into s3://costaszarifisbucket/scratch/infoforkmeans.ubuntu.20140613.071449.894551/files/
# Adding our job to existing job flow j-3QZOHADZF9KY1
# Job launched 30.3s ago, status RUNNING: Running step (infoforkmeans.ubuntu.20140613.071449.894551: Step 1 of 1)
# Job launched 60.5s ago, status RUNNING: Running step (infoforkmeans.ubuntu.20140613.071449.894551: Step 1 of 1)
# Job launched 90.8s ago, status RUNNING: Running step (infoforkmeans.ubuntu.20140613.071449.894551: Step 1 of 1)
# Job launched 121.0s ago, status RUNNING: Running step (infoforkmeans.ubuntu.20140613.071449.894551: Step 1 of 1)
# Job launched 151.3s ago, status RUNNING: Running step (infoforkmeans.ubuntu.20140613.071449.894551: Step 1 of 1)
# Job launched 181.6s ago, status RUNNING: Running step (infoforkmeans.ubuntu.20140613.071449.894551: Step 1 of 1)
# ...

# %%
# !head -10 meanprcp.txt
# Out:
# "AJ000037907"	13.909945715669627
# "AQC00914873"	93.534790161047127
# "AR000087270"	36.486717683205477
# "AR000087344"	27.773407025949094
# "AR000087418"	7.8098435679706073
# "AR000087715"	6.1300571896032299
# "AR000087803"	15.255805640087043
# "ASN00001019"	34.942918996739053
# "ASN00002012"	15.610564532667782
# "ASN00002056"	23.490521225934874

# %% [markdown]
# Here we just show an intermediate step. The process need take a while and it might be a little bit compicate if you want to repeat.

# %%
merged_2.head(3)
# Out:
#              mean_prcp   mean_temp  latitude  longitude  elevation
# station
# AJ000037907  13.909946  136.863773    39.600    47.1500      439.0
# AQC00914873  93.534790  259.403328   -14.350  -170.7667       14.9
# AR000087270  36.486718  201.690207   -29.183   -59.7000       53.0
#
# [3 rows x 5 columns]

# %% [markdown]
# Here is final table we get.

# %%
meanprcp = pd.read_csv('meandiff.txt', sep='\t', names=['station', 'mean_diff'])
meanprcp = meanprcp.set_index(['station'])
merged_3 = meanprcp.join(merged_2)
merged_3.head(3)
# Out:
#               mean_diff  mean_prcp   mean_temp  latitude  longitude  elevation
# station
# AJ000037907   95.606721  13.909946  136.863773    39.600    47.1500      439.0
# AQC00914873   78.048529  93.534790  259.403328   -14.350  -170.7667       14.9
# AR000087270  109.963599  36.486718  201.690207   -29.183   -59.7000       53.0
#
# [3 rows x 6 columns]

# %% [markdown]
# We still can get this table from the result we compute. Following code can run easily, the table is same as the one we show above.

# %%
meantemp = pd.read_csv('meantemp.txt', sep='\t', names=['station', 'mean_temp'])
meantemp = meantemp.set_index(['station'])
meandiff = pd.read_csv('meandiff.txt', sep='\t', names=['station', 'mean_diff'])
meandiff = meandiff.set_index(['station'])
meanprcp = pd.read_csv('meanprcp.txt', sep='\t', names=['station', 'mean_prcp'])
meanprcp = meanprcp.set_index(['station'])
newtable1 = meantemp.join(statinfo)
newtable2 = meanprcp.join(newtable1)
newtable3 = meandiff.join(newtable2)
newtable3.head(3)
# Out:
#               mean_diff  mean_prcp   mean_temp  latitude  longitude  elevation
# station
# AJ000037907   95.606721  13.909946  136.863773    39.600    47.1500      439.0
# AQC00914873   78.048529  93.534790  259.403328   -14.350  -170.7667       14.9
# AR000087270  109.963599  36.486718  201.690207   -29.183   -59.7000       53.0
#
# [3 rows x 6 columns]

# %% [markdown]
# Write it into a file.

# %%
newtable3.to_pickle('kmeanclusterfull.pkl')

# %% [markdown]
# Then, let's do K means, initially we classify the data into 10 clusters. Again, each station can be considered as a point in 5D space, the 5 dimentions are:
#
# 1. Mean Temperature
# 2. Average difference of temperature
# 3. Mean Precipitation
# 4. Elevation
# 5. Latitude

# %%
from sklearn.cluster import KMeans

def kmeans_climate(col,clusnum):
    table_Kmean=pd.read_pickle("kmeanclusterfull.pkl")
    mm=table_Kmean.as_matrix(columns=col)
    kmeans = KMeans(n_clusters=clusnum)
    kmeans.fit(mm)
    typelabel=kmeans.labels_.tolist()
    return typelabel

# %% [markdown]
# ### 10 Clusters, using all 5D infos

# %% [markdown]
# The result looks good, it is pretty similar with the Köppen climate classification.

# %%
from mpl_toolkits.basemap import Basemap
lonmin=-180;lonmax=180;latsmin=-80;latsmax=80;

typelabel=kmeans_climate(["mean_temp","mean_diff","mean_prcp","latitude","elevation"],10)
plt.figure(figsize=(15,10),dpi=300)
m = Basemap(projection='merc',llcrnrlat=latsmin,urcrnrlat=latsmax,llcrnrlon=lonmin,urcrnrlon=lonmax,lat_ts=20,resolution='c')
m.drawcoastlines()
x,y = m(np.array(table_Kmean['longitude']), np.array(table_Kmean['latitude']))
color_map = m.scatter(x,y,c=np.array(typelabel),marker='.', lw=0, alpha=1)
m.colorbar(color_map,pad="10%")
# Out:
# <matplotlib.colorbar.Colorbar instance at 0xf36b050>

# %%
table_Kmean['label']=typelabel
table_Kmean.to_pickle("KMEAN_PCA.pkl")

# %% [markdown]
# ### 20 Clusters, using all 5D infos

# %% [markdown]
# More clusters, not so good anymore.

# %%
from mpl_toolkits.basemap import Basemap
#lonmin=-180;lonmax=180;latsmin=-80;latsmax=80;
lonmin=-150;lonmax=-50;latsmin=20;latsmax=60
typelabel=kmeans_climate(["mean_temp","mean_diff","mean_prcp","latitude","elevation"],20)
plt.figure(figsize=(15,10),dpi=300)
m = Basemap(projection='merc',llcrnrlat=latsmin,urcrnrlat=latsmax,llcrnrlon=lonmin,urcrnrlon=lonmax,lat_ts=20,resolution='c')
m.drawcoastlines()
x,y = m(np.array(table_Kmean['longitude']), np.array(table_Kmean['latitude']))
color_map = m.scatter(x,y,c=np.array(typelabel),marker='.', lw=0, alpha=1)
m.colorbar(color_map,pad="10%")
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x150b10e0>

# %% [markdown]
# ### 10 Clusters, using all 3D infos (mean Precipitation/elevation/latitude)

# %% [markdown]
# Since the temperature is influenced by elevation and latitude, how about we remove this 2 information, and do clustering again for 10 clusters. Still good.

# %%
from mpl_toolkits.basemap import Basemap
lonmin=-180;lonmax=180;latsmin=-80;latsmax=80;
lonmin=-150;lonmax=-50;latsmin=20;latsmax=60

typelabel=kmeans_climate(["mean_prcp","latitude","elevation"],10)
plt.figure(figsize=(15,10),dpi=300)
m = Basemap(projection='merc',llcrnrlat=latsmin,urcrnrlat=latsmax,llcrnrlon=lonmin,urcrnrlon=lonmax,lat_ts=20,resolution='c')
m.drawcoastlines()
x,y = m(np.array(table_Kmean['longitude']), np.array(table_Kmean['latitude']))
color_map = m.scatter(x,y,c=np.array(typelabel),marker='.', lw=0, alpha=1)
m.colorbar(color_map,pad="10%")
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x15673fc8>

# %% [markdown]
# ### Following cells are just used for saving the results.

# %%
newtable3['label']=typelabel
newtable3.head(3)
newtable6 = newtable3.copy()
del newtable6["mean_diff"]
del newtable6["mean_temp"]
del newtable6["mean_prcp"]
newtable6.to_pickle('kmeancluster10_3.pkl')
newtable6.head(3)
# Out:
#              latitude  longitude  elevation  label
# station
# AJ000037907    39.600    47.1500      439.0      6
# AQC00914873   -14.350  -170.7667       14.9      7
# AR000087270   -29.183   -59.7000       53.0      7
#
# [3 rows x 4 columns]

# %%
newtable3['label']=typelabel
newtable3.head(3)
newtable4 = newtable3.copy()
del newtable4["mean_diff"]
del newtable4["mean_temp"]
del newtable4["mean_prcp"]
newtable4.head(3)
newtable4.to_pickle('kmeancluster10.pkl')
newtable4.head(3)
# Out:
#              latitude  longitude  elevation  label
# station
# AJ000037907    39.600    47.1500      439.0      7
# AQC00914873   -14.350  -170.7667       14.9      0
# AR000087270   -29.183   -59.7000       53.0      0
#
# [3 rows x 4 columns]

# %%
aa=pd.read_pickle('kmeancluster10.pkl')

# %%
newtable5.to_pickle('kmeancluster20.pkl')
