# %% [markdown]
# # **Global Warming**

# %% [markdown]
# Still setup the environment.

# %%
import sys
home_dir='/home/ubuntu/UCSD_BigData'
sys.path.append(home_dir+'/utils')
from find_waiting_flow import *
from AWS_keypair_management import *

import pickle

Creds= pickle.load(open('/home/ubuntu/Vault/Creds.pkl','rb'))
pair=Creds['mrjob']
key_id=pair['key_id']
secret_key=pair['secret_key']
ID=pair['ID']
print 'ID: %s, key_id: %s' % (ID, key_id)

job_flow_id="j-3LP88IFUHBOHO"
# Out:
# ID: kozarifi, key_id: AKIAIXCNAVZPV64ER67Q

# %% [markdown]
# As usual, load the station information.

# %%
import gzip
import pandas as pd

statfile = '/home/ubuntu/UCSD_BigData/notebooks/weather.mapreduce/stations.pkl.gz'
statinfo = pickle.load(gzip.open(statfile,'rb'))
del statinfo['GSNFLAG']
del statinfo['HCNFLAG']
del statinfo['WMOID']
statinfo.head()
# Out:
#              latitude  longitude  elevation state                   name
# ACW00011604   17.1167   -61.7833       10.1   NaN  ST JOHNS COOLIDGE FLD
# ACW00011647   17.1333   -61.7833       19.2   NaN               ST JOHNS
# AE000041196   25.3330    55.5170       34.0   NaN    SHARJAH INTER. AIRP
# AF000040930   35.3170    69.0170     3366.0   NaN           NORTH-SALANG
# AG000060390   36.7167     3.2500       24.0   NaN     ALGER-DAR EL BEIDA
#
# [5 rows x 5 columns]

# %% [markdown]
# ### Count valid years

# %% [markdown]
# For each station, we define the station have data of a valid year as: in this year, this staition include 300 more measurement on TMIN, TMAX and PRCP.

# %%
# %%writefile count_validyear.py
#!/usr/bin/python
"""
count the number of measurements of each type
"""
import sys
sys.path.append('/usr/lib/python2.6/dist-packages')
from mrjob.job import MRJob
import re
from sys import stderr

class count_validyear(MRJob):

    def mapper(self, _, line):
        try:
            self.increment_counter('MrJob Counters','mapper',1)
            # Parse the line
            elements=line.split(',')
            station = elements[0]
            measure_type = elements[1]
            year = int(elements[2])
            measurements = elements[3:]
            nomeas = 0
            #
            AllNum=True
            for ss in measurements:
                if ss!="":
                    try:
                        ii=float(ss)
                        nomeas+=1
                    except:
                        AllNum=False
            #filter out the unwanted measurements and the header line
            if (measure_type == 'TMIN' or measure_type == 'TMAX' or measure_type=='PRCP') \
                and station != 'station' and len(measurements)==365 and nomeas>=300 and AllNum: 
                self.increment_counter('MrJob Counters','usefull lines',1)
                yield (station, [year,measure_type,nomeas])
                
        except Exception, e:
            stderr.write('Error in line:\n'+line)
            stderr.write(e.message)
            self.increment_counter('MrJob Counters','mapper-error',1)
            yield (('error','mapper', str(e)), 1)
            
    def reducer(self, station, counts):
        try:
            if station[0] == 'error':
                yield(station,sum(data))
                return
            self.increment_counter('MrJob Counters','reducer',1)
            dic_TMIN={}
            dic_TMAX={}
            dic_PRCP={}
            for vec in counts:
                if vec[1]=='TMIN':
                    dic_TMIN[vec[0]]=vec[2]
                elif vec[1]=='TMAX':
                    dic_TMAX[vec[0]]=vec[2]
                else:
                    dic_PRCP[vec[0]]=vec[2]
            validyear=[]
            for key in dic_TMIN:
                if dic_TMAX.has_key(key) and dic_PRCP.has_key(key):
                    validyear.append(key)
            yield (station, len(validyear))
        except Exception, e:
            #yield (('error','reducer', str(e)), 1)
            stderr.write('Error in reducer')
        
if __name__ == '__main__':
    count_validyear.run()
# Out:
# Overwriting count_validyear.py

# %%
# !python count_validyear.py -r emr --emr-job-flow-id $job_flow_id hdfs:/weather.raw_data/ALL.csv > station_validyear_count.txt
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/count_validyear.ubuntu.20140613.185508.387709
# Copying non-input files into s3://costaszarifisbucket/scratch/count_validyear.ubuntu.20140613.185508.387709/files/
# Adding our job to existing job flow j-3LP88IFUHBOHO
# Job launched 30.3s ago, status RUNNING: Running step (count_validyear.ubuntu.20140613.185508.387709: Step 1 of 1)
# Job launched 60.6s ago, status RUNNING: Running step (count_validyear.ubuntu.20140613.185508.387709: Step 1 of 1)
# Job launched 90.9s ago, status RUNNING: Running step (count_validyear.ubuntu.20140613.185508.387709: Step 1 of 1)
# Job launched 121.2s ago, status RUNNING: Running step (count_validyear.ubuntu.20140613.185508.387709: Step 1 of 1)
# Job launched 151.5s ago, status RUNNING: Running step (count_validyear.ubuntu.20140613.185508.387709: Step 1 of 1)
# Job launched 181.8s ago, status RUNNING: Running step (count_validyear.ubuntu.20140613.185508.387709: Step 1 of 1)
# ...

# %% [markdown]
# Merge a table to see the result

# %%
measyearcount = pd.read_csv('station_validyear_count.txt', sep='\t', names=['station', 'valid_year'])
merged_year = measyearcount.join(statinfo,on='station')
merged_year.head(5)
# Out:
#        station  valid_year  latitude  longitude  elevation state       name
# 0  AJ000037668           0    41.100     47.500        583   NaN  VARTASHEN
# 1  AJ000037679           0    41.100     49.200        -26   NaN    SIASAN'
# 2  AJ000037734           0    40.800     46.000        404   NaN    SHAMHOR
# 3  AJ000037756           0    40.533     48.933        755   NaN     MARAZA
# 4  AJ000037844           0    40.333     48.167          4   NaN   KURDAMIR
#
# [5 rows x 7 columns]

# %% [markdown]
# Seems most of the stations have less than 50 valid years.....

# %%
from mpl_toolkits.basemap import Basemap
lonmin=-180;lonmax=180;latsmin=-80;latsmax=80;
    
plt.figure(figsize=(15,10),dpi=300)
m = Basemap(projection='merc',llcrnrlat=latsmin,urcrnrlat=latsmax,llcrnrlon=lonmin,urcrnrlon=lonmax,lat_ts=20,resolution='c')
m.drawcoastlines()
x,y = m(np.array(merged_year['longitude']), np.array(merged_year['latitude']))
color_map = m.scatter(x,y,c=np.array(merged_year['valid_year']),marker='.', lw=0, alpha=1)
m.colorbar(color_map,pad="5%")
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x42c8c20>

# %% [markdown]
# Let's compute all mean temperature, difference of temperature and mean precipitation of all valid year in each station. We are only interested in the station with more than 100 valid years and include data later than 2006.

# %%
# %%writefile get_mean_diff_prcp.py
#!/usr/bin/python
"""
count the number of measurements of each type
"""
import sys
import numpy as np
sys.path.append('/usr/lib/python2.6/dist-packages')
from mrjob.job import MRJob
import re
from sys import stderr

class get_mean_diff_prcp(MRJob):

    def mapper(self, _, line):
        try:
            self.increment_counter('MrJob Counters','mapper',1)
            # Parse the line
            elements=line.split(',')
            station = elements[0]
            measure_type = elements[1]
            year = int(elements[2])
            measurements = elements[3:]
            nomeas = 0
            #
            AllNum=True
            usefulmeas=[]
            for ss in measurements:
                if ss!="":
                    try:
                        ii=float(ss)
                        usefulmeas.append(ii)
                        nomeas+=1
                    except:
                        AllNum=False
            #filter out the unwanted measurements and the header line
            if (measure_type == 'TMIN' or measure_type == 'TMAX' or measure_type=='PRCP') \
                and station != 'station' and len(measurements)==365 and nomeas>=300 and AllNum: 
                self.increment_counter('MrJob Counters','usefull lines',1)
                yield (station, [year,measure_type,np.mean(np.array(usefulmeas))])
                
        except Exception, e:
            stderr.write('Error in line:\n'+line)
            stderr.write(e.message)
            self.increment_counter('MrJob Counters','mapper-error',1)
            yield (('error','mapper', str(e)), 1)
            
    def reducer(self, station, counts):
        try:
            if station[0] == 'error':
                yield(station,sum(data))
                return
            self.increment_counter('MrJob Counters','reducer',1)
            dic_TMIN={}
            dic_TMAX={}
            dic_PRCP={}
            for vec in counts:
                if vec[1]=='TMIN':
                    dic_TMIN[vec[0]]=vec[2]
                elif vec[1]=='TMAX':
                    dic_TMAX[vec[0]]=vec[2]
                else:
                    dic_PRCP[vec[0]]=vec[2]
            validyear=[]
            mean_temp=[]
            diff_temp=[]
            mean_PRCP=[]
            for key in dic_TMIN:
                if dic_TMAX.has_key(key) and dic_PRCP.has_key(key):
                    ma=dic_TMAX[key]
                    mi=dic_TMIN[key]
                    pr=dic_PRCP[key]
                    validyear.append(key)
                    mean_temp.append(round((ma+mi)/2.0,3))
                    diff_temp.append(round(ma-mi,3))
                    mean_PRCP.append(round(pr,3))
            if len(validyear)>=100 and max(validyear)>2006:
                yield(station, [validyear, mean_temp, diff_temp, mean_PRCP])
#                 out=[np.mean(np.array(mean_TMIN)), np.mean(np.array(mean_TMAX)), \
#                      np.mean(np.array(mean_TMAX))-np.mean(np.array(mean_TMIN)), np.mean(np.array(mean_PRCP)),\
#                      np.mean(np.array(std_TMIN)),np.mean(np.array(std_TMAX)),np.mean(np.array(std_PRCP))]
#                 yield (station, out)
#             else:
#                 yield (station, [9999,9999,9999,9999,9999,9999,9999])
        except Exception, e:
            #yield (('error','reducer', str(e)), 1)
            stderr.write('Error in reducer')
        
if __name__ == '__main__':
    get_mean_diff_prcp.run()
# Out:
# Overwriting get_mean_diff_prcp.py

# %%
# !python get_mean_diff_prcp.py -r emr --emr-job-flow-id $job_flow_id hdfs:/weather.raw_data/ALL.csv > mean_diff_prcp100.txt
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/get_mean_diff_prcp.ubuntu.20140613.200708.764416
# Copying non-input files into s3://costaszarifisbucket/scratch/get_mean_diff_prcp.ubuntu.20140613.200708.764416/files/
# Adding our job to existing job flow j-3LP88IFUHBOHO
# Job launched 30.3s ago, status RUNNING: Running step (get_mean_diff_prcp.ubuntu.20140613.200708.764416: Step 1 of 1)
# Job launched 60.6s ago, status RUNNING: Running step (get_mean_diff_prcp.ubuntu.20140613.200708.764416: Step 1 of 1)
# Job launched 90.8s ago, status RUNNING: Running step (get_mean_diff_prcp.ubuntu.20140613.200708.764416: Step 1 of 1)
# Job launched 121.1s ago, status RUNNING: Running step (get_mean_diff_prcp.ubuntu.20140613.200708.764416: Step 1 of 1)
# Job launched 151.5s ago, status RUNNING: Running step (get_mean_diff_prcp.ubuntu.20140613.200708.764416: Step 1 of 1)
# ...

# %% [markdown]
# There is only 801 stations which have long term useful datas....

# %%
# !wc -l mean_diff_prcp100.txt
# Out:
# 801 mean_diff_prcp100.txt

# %% [markdown]
# Ok, let's taste the flavor of global warming, I take the data from a station in German. First picture is the mean temperature of each year, and second picture is the 10 years mean temperature. We can clearly see an increase of the temperature.

# %%
import numpy as np
from pylab import plot,show
#Station ID: GM000004063
yy=[1879, 1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012
, 20.15068493150685, 10.624657534246575, 18.378082191780823, 18.07123287671233, 21.583561643835615, 18.06027397260274, 21.4027397260274, 13.068493150684931, 17.293150684931508, 17.136986301369863, 13.372602739726027, 15.575342465753424, 11.391780821917807, 25.04931506849315, 23.465753424657535, 16.0, 19.564383561643837, 15.736986301369862, 19.312328767123287, 16.802739726027397, 17.438356164383563, 14.534246575342467, 20.073972602739726, 14.147945205479452, 12.26027397260274, 18.84931506849315, 16.95068493150685, 17.397260273972602, 17.873972602739727, 22.002739726027396, 14.580821917808219, 16.041095890410958, 18.545205479452054, 14.183561643835617, 19.36986301369863, 19.567123287671233, 19.81095890410959, 15.802739726027397, 18.172602739726027, 11.931506849315069, 18.273972602739725, 17.008219178082193, 16.852054794520548, 21.482191780821918, 18.389041095890413, 16.427397260273974, 20.156164383561645, 18.610958904109587, 16.353424657534248, 19.71232876712329, 22.567123287671233, 12.397260273972602, 16.926027397260274, 15.178082191780822, 15.09041095890411, 21.46301369863014, 15.967123287671233, 18.183561643835617, 23.76986301369863, 16.572602739726026, 15.0625]
nn=len(yy)
A = array([ yy, ones(nn)])
w = linalg.lstsq(A.T,meantemp)[0]
line = w[0]*np.array(yy)+w[1]
plot(yy,line,'r-',yy,meantemp,'o')
show()
meantemp10=[]
for i in range(nn-10):
    meantemp10.append(sum(meantemp[i:i+10])/10)
plt.plot(meantemp10)

# %% [markdown]
# ### Organize the Data

# %%
import re

f = open('mean_diff_prcp100.txt', 'r')
dic={}
for line in f.readlines():
    matchObj = re.match(r'"(.*)"\s\[\[([^\]]*)\], \[([^\]]*)\], \[([^\]]*)\], \[([^\]]*)\]\]', line)
    a = matchObj.group(1)
    b = matchObj.group(2)
    c = matchObj.group(3)
    d = matchObj.group(4)
    e = matchObj.group(5)
    bb=[int(s) for s in b.split(',')]
    cc=[float(s) for s in c.split(',')]
    dd=[float(s) for s in d.split(',')]
    ee=[float(s) for s in e.split(',')]
    dic[a]=[bb,cc,dd,ee]

# %%
lat=[]
lon=[]
for key in dic.keys():
    lat.append(statinfo.loc[key]["latitude"])
    lon.append(statinfo.loc[key]["longitude"])

# %% [markdown]
# Let's look at where are these station with long term useful datas. They are basically located at US and Europe.

# %%
from mpl_toolkits.basemap import Basemap
lonmin=-180;lonmax=180;latsmin=-80;latsmax=80;
    
plt.figure(figsize=(15,10),dpi=300)
m = Basemap(projection='merc',llcrnrlat=latsmin,urcrnrlat=latsmax,llcrnrlon=lonmin,urcrnrlon=lonmax,lat_ts=20,resolution='c')
m.drawcoastlines()
x,y = m(lon, lat)
color_map = m.scatter(x,y,marker='.', lw=0, alpha=1)

# %%
pickle.dump( dic, open( "mean_diff_prcp100_dic.pkl", "wb" ) )

# %% [markdown]
# ### Global warming on several stations

# %% [markdown]
# We pick 5 stations and study the change of mean temperature, temperature difference and mean precipitation over 20 century. The temperature is increasing, the difference of the temperature and mean precipitation are flucuating....
#
# The 5 stations are piking from America, Australia and Europe. For each row, the pictures mean
#
# 1. Change of mean temperature over 20 century
# 2. Change of 10 years mean temperature
# 3. Change of difference of temperature
# 4. Change of mean precipitation
#
# Different row represent different station.

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(24,24))
stats=["ASN00039039","CA001100120","ITE00100554","USC00046074","GM000004063"]
loct=["Australia","Canada", "Italy", "USA", "German"]
dicc=pickle.load( open( "mean_diff_prcp100_dic.pkl", "rb" ) )
for ii in range(5):
    stat=stats[ii]
    yy=dicc[stat][0]
    meantemp=dicc[stat][1]
    difftemp=dicc[stat][2]
    meanprcp=dicc[stat][3]
    nn=len(yy)
    A = array([yy, ones(nn)])
    w = linalg.lstsq(A.T,meantemp)[0]
    line = w[0]*np.array(yy)+w[1]
    meantemp10=[]
    for i in range(nn-10):
        meantemp10.append(sum(meantemp[i:i+10])/10)
    plt.subplot(5,4,4*ii+1)
    plt.plot(yy,line,'r-',yy,meantemp,'o')
    plt.title('Mean Temperature (1 year) '+loct[ii])
    plt.xlabel('Year')
    plt.ylabel('Mean Temperature (0.1 C)')
    plt.subplot(5,4,4*ii+2)
    plt.plot(yy[:-10],meantemp10)
    plt.title('10-Year Mean Temperature '+loct[ii])
    plt.xlabel('Year')
    plt.ylabel('10-Year Mean Temperature (0.1 C) ')
    plt.subplot(5,4,4*ii+3)
    plt.plot(yy,difftemp)
    plt.title('Temperature Difference (1 year) '+loct[ii])
    plt.xlabel('Year')
    plt.ylabel('Temperature Difference (0.1 C)')
    plt.subplot(5,4,4*ii+4)
    plt.plot(yy,meanprcp)
    plt.title('Mean Precipitation (1 year) '+loct[ii])
    plt.xlabel('Year')
    plt.ylabel('Mean Precipitation (mm)')

plt.show()

# %% [markdown]
# ### Study global warming globally

# %%
gl_meantemp={}
gl_difftemp={}
gl_meanprcp={}
gl_valid={}
for key in dic:
    if statinfo.loc[key]["latitude"]>0:
        nn=len(dic[key][0])
        for i in range(nn):
            year=dic[key][0][i]
            if gl_meantemp.has_key(year):
                gl_meantemp[year]=gl_meantemp[year]+dic[key][1][i]
                gl_difftemp[year]=gl_difftemp[year]+dic[key][2][i]
                gl_meanprcp[year]=gl_meanprcp[year]+dic[key][3][i]
                gl_valid[year]=gl_valid[year]+1
            else:
                gl_meantemp[year]=dic[key][1][i]
                gl_difftemp[year]=dic[key][2][i]
                gl_meanprcp[year]=dic[key][3][i]
                gl_valid[year]=1
vy=[]
ny=[]
mt=[]
dt=[]
mp=[]
for year in gl_valid:
    if year>1895:
        vy.append(year)
        ny.append(gl_valid[year])
        mt.append(gl_meantemp[year]/gl_valid[year])
        dt.append(gl_difftemp[year]/gl_valid[year])
        mp.append(gl_meanprcp[year]/gl_valid[year])

# %% [markdown]
# We compute the average temperture of the whole north part of the earth. And we also can see the global warming.

# %%
nn=len(vy)
A = array([ vy, ones(nn)])
w = linalg.lstsq(A.T,mt)[0]
line = w[0]*np.array(vy)+w[1]
plot(vy,line,'r-',vy,mt,'o')
plt.title('Mean Temperature (1 year)')
plt.xlabel('Year')
plt.ylabel('Mean Temperature (0.1 C)')
show()
meantemp10=[]
for i in range(len(vy)-10):
    meantemp10.append(sum(mt[i:i+10])/10)
plt.plot(meantemp10)
plt.title('10-Year Mean Temperature '+loct[ii])
plt.xlabel('Year')
plt.ylabel('10-Year Mean Temperature (0.1 C) ')
