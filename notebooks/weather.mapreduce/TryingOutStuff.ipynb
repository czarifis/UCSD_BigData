# %% [markdown]
# ### Part 2.a. Group together base-stations based on geographical criteria.

# %% [markdown]
# #### Let's import the required libs

# %%
import pandas as pd
import numpy as np
import sklearn as sk
print 'pandas version: ',pd.__version__
print 'numpy version:',np.__version__
print 'sklearn version:',sk.__version__
# Out:
# pandas version:  0.13.1
# numpy version: 1.8.1
# sklearn version: 0.14.1

# %% [markdown]
# #### Let's load the data from the csv file we created on the last part... We only care about the TMAX and the TMIN values (check previous notebook for details)

# %%
header_row=['station','maxcount','mincount'] # note the header has duplicate column values
maxmindf = pd.read_csv('basestationmaxmin.csv', names=header_row)
maxmindf.head()
# Out:
#        station  maxcount  mincount
# 0  AG000060390       365         0
# 1  AG000060611       730         0
# 2  AG000060680       365         0
# 3  AGE00135039        26         0
# 4  AJ000037575       209         0
#
# [5 rows x 3 columns]

# %%
#!gunzip stations.pkl.gz
import pickle
# !gunzip -c stations.pkl.gz > stations.pkl  # This command also keeps the initial gz file....
stations=pickle.load(open('stations.pkl', 'rb'))
df = pd.read_pickle('stations.pkl')
df['station'] = df.index # let's create a column with the indexes (base-station names)
df.head()
# Out:
#              latitude  longitude  elevation state                   name  \
# ACW00011604   17.1167   -61.7833       10.1   NaN  ST JOHNS COOLIDGE FLD
# ACW00011647   17.1333   -61.7833       19.2   NaN               ST JOHNS
# AE000041196   25.3330    55.5170       34.0   NaN    SHARJAH INTER. AIRP
# AF000040930   35.3170    69.0170     3366.0   NaN           NORTH-SALANG
# AG000060390   36.7167     3.2500       24.0   NaN     ALGER-DAR EL BEIDA
#
#             GSNFLAG HCNFLAG  WMOID      station
# ACW00011604     NaN     NaN    NaN  ACW00011604
# ACW00011647     NaN     NaN    NaN  ACW00011647
# AE000041196     GSN     NaN  41196  AE000041196
# AF000040930     GSN     NaN  40930  AF000040930
# AG000060390     GSN     NaN  60390  AG000060390
#
# [5 rows x 9 columns]

# %%
stationNames = df["station"].tolist()  # keeping a list with all the names of the base-stations for future reference

# %%
## Ignore me! House keeping purposes
def isBaseStationPresent(sname,listOfStations):
    for stName in listOfStations:
        if stName==sname:
            print 'found: ', stName
            return
    print 'Nope! ',sname,' Not found!'

# %%
print 'number of base-stations',shape(df)[0]
print 'number of base-stations with measurements',shape(maxmindf)[0]
# Out:
# number of base-stations 85284
# number of base-stations with measurements 12130

# %% [markdown]
# ####Apparently there are base-stations that have no TMAX-TMIN measurements at all, since the number of base station in the two dataframes vary. We chose to do an inner join in order to prune these base-stations

# %%
res = pd.merge(df, maxmindf, on='station', how='inner')
res.head()
# Out:
#    latitude  longitude  elevation state                    name GSNFLAG  \
# 0   36.7167     3.2500         24   NaN      ALGER-DAR EL BEIDA     GSN
# 1   28.0500     9.6331        561   NaN               IN-AMENAS     GSN
# 2   22.8000     5.4331       1362   NaN             TAMANRASSET     GSN
# 3   35.7297     0.6500         50   NaN  ORAN-HOPITAL MILITAIRE     NaN
# 4   41.5500    46.6670        490   NaN                ZAKATALA     NaN
#
#   HCNFLAG  WMOID      station  maxcount  mincount
# 0     NaN  60390  AG000060390       365         0
# 1     NaN  60611  AG000060611       730         0
# 2     NaN  60680  AG000060680       365         0
# 3     NaN    NaN  AGE00135039        26         0
# 4     NaN  37575  AJ000037575       209         0
#
# [5 rows x 11 columns]

# %%
stationNames2 = res["station"].tolist()
isBaseStationPresent('USC00211063',stationNames2)
isBaseStationPresent('AG000060680',stationNames2)
# Out:
# Nope!  USC00211063  Not found!
# found:  AG000060680

# %% [markdown]
# ####Using geographical data to partition base-stations

# %%
#tempdf = res.groupby(pd.cut(res["latitude"], np.arange(-90, 90, 10)))#.head()#.sum()  #np.arange(0, 1.0+0.155, 0.155)
tempdf = res.copy()
tempdf['latgroup'] = pd.cut(res["latitude"], np.arange(-95, 95, 2))#.head()#.sum()  #np.arange(0, 1.0+0.155, 0.155)
tempdf['longroup'] = pd.cut(res["longitude"], np.arange(-185, 185, 2))#.head()#.sum()  #np.arange(0, 1.0+0.155, 0.155)
#tempdf.reset_index()

#tempdf['status'] = pd.cut(df['Days Late'], bins=[-1, 14, 35, 56, 365])

# Droping nan values
tempdf.dropna() 
tempdf.head()
# Out:
#    latitude  longitude  elevation state                    name GSNFLAG  \
# 0   36.7167     3.2500         24   NaN      ALGER-DAR EL BEIDA     GSN
# 1   28.0500     9.6331        561   NaN               IN-AMENAS     GSN
# 2   22.8000     5.4331       1362   NaN             TAMANRASSET     GSN
# 3   35.7297     0.6500         50   NaN  ORAN-HOPITAL MILITAIRE     NaN
# 4   41.5500    46.6670        490   NaN                ZAKATALA     NaN
#
#   HCNFLAG  WMOID      station  maxcount  mincount  latgroup  longroup
# 0     NaN  60390  AG000060390       365         0  (35, 37]    (3, 5]
# 1     NaN  60611  AG000060611       730         0  (27, 29]   (9, 11]
# 2     NaN  60680  AG000060680       365         0  (21, 23]    (5, 7]
# 3     NaN    NaN  AGE00135039        26         0  (35, 37]   (-1, 1]
# 4     NaN  37575  AJ000037575       209         0  (41, 43]  (45, 47]
#
# [5 rows x 13 columns]

# %%
print 'number of base-stations with measurements',shape(tempdf)[0]
# Out:
# number of base-stations with measurements 12130

# %% [markdown]
# ###Checking if every base-station is assigned to a group successfully!

# %%
# Checking if every base-station is assigned to a group successfully!

lat1z=[]
lat2z=[]
lon1z=[]
lon2z=[]
countnans=0

    
for index, row in tempdf.iterrows():
    elements=str(row['latgroup']).split(',')
    elements2=str(row['longroup']).split(',')
    if not((str(elements) == "['nan']")): 
        if not ((str(elements2) == "['nan']")):
            #print str(elements2)
            x1 = int(elements[0].translate(None, '(').translate(None, ']'))
            x2 = int(elements[1].translate(None, '(').translate(None, ']'))


            #print str(row)
            y1 = int(elements2[0].translate(None, '(').translate(None, ']'))
            y2 = int(elements2[1].translate(None, '(').translate(None, ']'))

            lat1z.append(x1)
            lat2z.append(x2)
            lon1z.append(y1)
            lon2z.append(y2)
            #print 'yolo',str(row['latgroup'])+','+str(row['longroup'])
        else:
            print 'nan found on longroup', str(row['latgroup']),(row['latitude']),str(row['longroup']),(row['longitude'])
            countnans+=1
    else:
        print 'nan found on latgroup', str(row['latgroup']),(row['latitude']),str(row['longroup']),(row['longitude'])
        countnans+=1
    #print x1,y1,x2,y2
#     for elem in elements:
#         print int(elem.translate(None, '(').translate(None, ']'))
    
    #print 'yolo',str(row['latgroup'])+','+str(row['longroup'])

if countnans==0:
    print 'Every base-station is grouped to a region. We can proceed!'
else:
    print 'Oh, there is something wrong! ', countnans, 'basestations haven\'t been assigned to a group'
# Out:
# Every base-station is grouped to a region. We can proceed!

# %%
len(lat1z)
# Out:
# 12130

# %% [markdown]
# ### Draw the base-stations along with the groups they belong to on a map!

# %%
# http://matplotlib.org/basemap/users/merc.html

from mpl_toolkits.basemap import Basemap
import numpy as np
import matplotlib.pyplot as plt


longitudes=tempdf.ix[:,'longitude'].values
latitudes=tempdf.ix[:,'latitude'].values

lonmin=-180;lonmax=180;latsmin=-80;latsmax=80;
plt.figure(figsize=(15,10),dpi=300)
m = Basemap(projection='merc',llcrnrlat=latsmin,urcrnrlat=latsmax,\
            llcrnrlon=lonmin,urcrnrlon=lonmax,lat_ts=20,resolution='i')
m.drawcoastlines()
m.fillcontinents(color='coral',lake_color='aqua')

# draw parallels and meridians.
parallels = np.arange(-80,81,10.)
# labels = [left,right,top,bottom]
m.drawparallels(parallels,labels=[False,True,True,False])
meridians = np.arange(10.,351.,20.)
m.drawmeridians(meridians,labels=[True,False,False,True])

#m.drawparallels(np.arange(-90.,91.,30.))
#m.drawmeridians(np.arange(-180.,181.,60.))
m.drawmapboundary(fill_color='aqua')




def draw_screen_poly( lats, lons, m):
    x, y = m( lons, lats )
    xy = zip(x,y)
    poly = Polygon( xy, facecolor='red', edgecolor='white',linewidth=2,alpha=1 )
    plt.gca().add_patch(poly)
    #gca.fi
    
for i in range(len(lat1z)):

    lats = [ lat1z[i], lat2z[i], lat2z[i], lat1z[i] ]
    lons = [ lon1z[i], lon1z[i], lon2z[i], lon2z[i] ]
    draw_screen_poly( lats, lons, m )



# draw map with markers for locations
x, y = m(longitudes,latitudes)
m.plot(x,y,'g.', alpha=0.5)


plt.title('weather stations grouped into regions')
plt.show()

# %% [markdown]
# ### We need to send the information that represents the mappings between the base-stations and the groups to the map reduce job. We will use a dictionary to represent this information

# %%
import collections
d = collections.defaultdict(list)
for index, row in tempdf.iterrows():
    #print (row['latgroup'],row['longroup']),row['station']
    #d[str(row['latgroup'])+','+str(row['longroup'])].append(row['station'])
    d[row['station']].append(str(row['latgroup'])+','+str(row['longroup']))
    #d[str((row['latgroup']))].append(row['station'])

import json
with open('grouping.json', 'w') as outfile:
  json.dump(d, outfile)
    
import pickle
with open('grouping.pkl', 'w') as outfile:
  pickle.dump(d, outfile)

# %%
#need to check if the file is infact correct... 
# !head -c 300 grouping.json
# Out:
# {"CA004035200": ["(49, 51],(-105, -103]"], "USC00390043": ["(43, 45],(-101, -99]"], "SF000068438": ["(-29, -27],(23, 25]"], "USC00092485": ["(33, 35],(-85, -83]"], "JQW00021603": ["(15, 17],(-171, -169]"], "JQW00021601": ["(15, 17],(-171, -169]"], "USC00448938": ["(37, 39],(-79, -77]"], "USC00323686

# %% [markdown]
# #### Each group is identified by the region it covers <<| latitude range |>> , <<| longitude range |>>  (e.g ["(49, 51],(-105, -103]"])

# %%
agg_df = tempdf.groupby(['latgroup','longroup'])
agg_df.head()
# Out:
#                           latitude  longitude  elevation state  \
# latgroup   longroup
# (35, 37]   (3, 5]     0    36.7167     3.2500       24.0   NaN
# (27, 29]   (9, 11]    1    28.0500     9.6331      561.0   NaN
# (21, 23]   (5, 7]     2    22.8000     5.4331     1362.0   NaN
# (35, 37]   (-1, 1]    3    35.7297     0.6500       50.0   NaN
# (41, 43]   (45, 47]   4    41.5500    46.6670      490.0   NaN
#                       5    41.1330    45.4170      333.0   NaN
# (39, 41]   (45, 47]   6    40.7170    46.4170      311.0   NaN
#            (47, 49]   7    40.6500    47.7500       95.0   NaN
#                       8    40.5330    48.9330      755.0   NaN
#                       9    40.6330    48.6330      892.0   NaN
#                       10   40.3330    48.1670        4.0   NaN
#            (49, 51]   11   40.5330    50.0000       28.0   NaN
#                       12   40.4670    50.3170      -24.0   NaN
#            (45, 47]   13   39.9830    46.7500      828.0   NaN
#            (47, 49]   14   39.7670    47.7500       71.0   NaN
#            (49, 51]   15   39.4000    49.2500      -24.0   NaN
#            (45, 47]   16   39.2000    45.4170      885.0   NaN
# (37, 39]   (47, 49]   18   38.7670    48.4000     1113.0   NaN
#                       19   38.7500    48.8170      -12.0   NaN
#                       20   38.5000    48.9000      -22.0   NaN
# (39, 41]   (43, 45]   21   40.7830    43.8330     1512.0   NaN
#            (45, 47]   22   40.8670    45.1500      733.0   NaN
#                       23   40.6000    45.3500     1834.0   NaN
#            (43, 45]   24   40.3170    43.6670     1255.0   NaN
#                       25   40.5000    44.2000     3223.0   NaN
#                       26   40.1330    44.0500      865.0   NaN
#                       27   40.1330    44.4670     1140.0   NaN
# (37, 39]   (45, 47]   30   38.9000    46.2500      628.0   NaN
# (-13, -11] (15, 17]   32  -11.4170    15.1170     1304.0   NaN
# (-15, -13] (13, 15]   33  -14.9330    13.5670     1761.0   NaN
# (-17, -15] (11, 13]   34  -15.2000    12.1500       45.0   NaN
# (-23, -21] (-67, -65] 35  -22.1000   -65.6000     3479.0   NaN
# (-25, -23] (-61, -59] 36  -24.7000   -60.5830      130.0   NaN
# (-29, -27] (-65, -63] 37  -27.7670   -64.3000      200.0   NaN
#            (-61, -59] 38  -27.4500   -59.0500       53.0   NaN
# (-31, -29] (-67, -65] 39  -29.3830   -66.8170      438.0   NaN
#            (-63, -61] 40  -29.8830   -61.9500       88.0   NaN
#            (-61, -59] 41  -29.1830   -59.7000       53.0   NaN
# (-33, -31] (-65, -63] 42  -31.3170   -64.2170      489.0   NaN
#            (-69, -67] 43  -32.8330   -68.7830      704.0   NaN
# (-35, -33] (-65, -63] 44  -34.1330   -63.3670      137.0   NaN
# (-37, -35] (-65, -63] 45  -36.5670   -64.2660      192.0   NaN
# (-39, -37] (-59, -57] 46  -37.9330   -57.5830       22.0   NaN
#            (-69, -67] 47  -38.9500   -68.1330      273.0   NaN
# (-43, -41] (-73, -71] 48  -42.9330   -71.1500      799.0   NaN
# (-45, -43] (-67, -65] 49  -43.2000   -65.2660       43.0   NaN
# (-53, -51] (-71, -69] 50  -51.6170   -69.2830       19.0   NaN
# (-31, -29] (-69, -67] 51  -30.2500   -68.7500     1175.0   NaN
# (-37, -35] (-63, -61] 52  -35.8670   -61.9000       85.0   NaN
# (-35, -33] (-59, -57] 53  -34.5830   -58.4830       25.0   NaN
# (-39, -37] (-63, -61] 54  -38.7330   -62.1670       75.0   NaN
# (-15, -13] (125, 127] 55  -13.7542   126.1485        6.0   NaN
# (-17, -15] (123, 125] 56  -15.4875   124.5222       12.0   NaN
#            (127, 129] 57  -15.4872   128.1247       11.0   NaN
# (-15, -13] (125, 127] 58  -14.2961   126.6431       23.0   NaN
# (-19, -17] (127, 129] 59  -18.2292   127.6636      422.0   NaN
# (-17, -15] (127, 129] 60  -15.7814   128.7100       44.0   NaN
#                       61  -16.6381   128.4517      164.0   NaN
# (-19, -17] (121, 123] 62  -17.9475   122.2353        7.4   NaN
# (-17, -15] (121, 123] 63  -16.3961   122.9278       25.0   NaN
#                                ...        ...        ...   ...
#
#                                             name GSNFLAG HCNFLAG  WMOID  \
# latgroup   longroup
# (35, 37]   (3, 5]     0       ALGER-DAR EL BEIDA     GSN     NaN  60390
# (27, 29]   (9, 11]    1                IN-AMENAS     GSN     NaN  60611
# (21, 23]   (5, 7]     2              TAMANRASSET     GSN     NaN  60680
# (35, 37]   (-1, 1]    3   ORAN-HOPITAL MILITAIRE     NaN     NaN    NaN
# (41, 43]   (45, 47]   4                 ZAKATALA     NaN     NaN  37575
#                       5         AGSTAPHA AIRPORT     NaN     NaN  37639
# (39, 41]   (45, 47]   6                   GANDJA     NaN     NaN  37735
#            (47, 49]   7                  GOYCHAY     NaN     NaN  37749
#                       8                   MARAZA     NaN     NaN  37756
#                       9                 SHAMAKHY     NaN     NaN  37759
#                       10                KURDAMIR     NaN     NaN  37844
#            (49, 51]   11                MASHTAGA     NaN     NaN  37860
#                       12               PIRALLAHI     NaN     NaN  37866
#            (45, 47]   13               KHANKANDY     NaN     NaN  37895
#            (47, 49]   14      BEYLAGAN AERODROME     NaN     NaN  37905
#            (49, 51]   15               NEFTCHALA     NaN     NaN  37925
#            (45, 47]   16                NAXCIVAN     NaN     NaN  37936
# (37, 39]   (47, 49]   18                   LERIK     NaN     NaN  37984
#                       19                LANKARAN     NaN     NaN  37985
#                       20                  ASTARA     GSN     NaN  37989
# (39, 41]   (43, 45]   21                   GUMRI     NaN     NaN  37686
#            (45, 47]   22                 IDJEVAN     NaN     NaN  37711
#                       23               CHAMBARAK     NaN     NaN  37719
#            (43, 45]   24                 ARAGATS     NaN     NaN  37774
#                       25    ARAGAC VISOKOGORNAYA     GSN     NaN  37781
#                       26                 ARMAVIR     NaN     NaN  37787
#                       27     YEREVAN/YEREVAN-ARA     NaN     NaN  37789
# (37, 39]   (45, 47]   30                   MEGRI     NaN     NaN  37958
# (-13, -11] (15, 17]   32       WAKU KUNGU (CELA)     GSN     NaN  66270
# (-15, -13] (13, 15]   33     LUBANGO (SA DA BAND     GSN     NaN  66390
# (-17, -15] (11, 13]   34               MOCAMEDES     GSN     NaN  66422
# (-23, -21] (-67, -65] 35     LA QUIACA OBSERVATO     GSN     NaN  87007
# (-25, -23] (-61, -59] 36             LAS LOMITAS     GSN     NaN  87078
# (-29, -27] (-65, -63] 37     SANTIAGO DEL ESTERO     GSN     NaN  87129
#            (-61, -59] 38        RESISTENCIA AERO     GSN     NaN  87155
# (-31, -29] (-67, -65] 39          LA RIOJA AERO.     GSN     NaN  87217
#            (-63, -61] 40              CERES AERO     GSN     NaN  87257
#            (-61, -59] 41        RECONQUISTA AERO     GSN     NaN  87270
# (-33, -31] (-65, -63] 42            CORDOBA AERO     GSN     NaN  87344
#            (-69, -67] 43            MENDOZA AERO     GSN     NaN  87418
# (-35, -33] (-65, -63] 44          LABOULAYE AERO     GSN     NaN  87534
# (-37, -35] (-65, -63] 45         SANTA ROSA AERO     GSN     NaN  87623
# (-39, -37] (-59, -57] 46      MAR DEL PLATA AERO     GSN     NaN  87692
#            (-69, -67] 47            NEUQUEN AERO     GSN     NaN  87715
# (-43, -41] (-73, -71] 48             ESQUEL AERO     GSN     NaN  87803
# (-45, -43] (-67, -65] 49             TRELEW AERO     GSN     NaN  87828
# (-53, -51] (-71, -69] 50       RIO GALLEGOS AERO     GSN     NaN  87925
# (-31, -29] (-69, -67] 51                  JACHAL     GSN     NaN  87305
# (-37, -35] (-63, -61] 52            PEHUAJO AERO     GSN     NaN  87544
# (-35, -33] (-59, -57] 53     BUENOS AIRES OBSERV     NaN     NaN  87585
# (-39, -37] (-63, -61] 54       BAHIA BLANCA AERO     GSN     NaN  87750
# (-15, -13] (125, 127] 55        TROUGHTON ISLAND     NaN     NaN  94102
# (-17, -15] (123, 125] 56                KURI BAY     NaN     NaN  94208
#            (127, 129] 57                 WYNDHAM     NaN     NaN  94214
# (-15, -13] (125, 127] 58       KALUMBURU MISSION     NaN     NaN    NaN
# (-19, -17] (127, 129] 59     HALLS CREEK AIRPORT     GSN     NaN  94212
# (-17, -15] (127, 129] 60          KUNUNURRA AERO     NaN     NaN  94216
#                       61        ARGYLE AERODROME     NaN     NaN  94217
# (-19, -17] (121, 123] 62          BROOME AIRPORT     GSN     NaN  94203
# (-17, -15] (121, 123] 63            CAPE LEVEQUE     NaN     NaN    NaN
#                                              ...     ...     ...    ...
#
#                               station  maxcount  mincount    latgroup  \
# latgroup   longroup
# (35, 37]   (3, 5]     0   AG000060390       365         0    (35, 37]
# (27, 29]   (9, 11]    1   AG000060611       730         0    (27, 29]
# (21, 23]   (5, 7]     2   AG000060680       365         0    (21, 23]
# (35, 37]   (-1, 1]    3   AGE00135039        26         0    (35, 37]
# (41, 43]   (45, 47]   4   AJ000037575       209         0    (41, 43]
#                       5   AJ000037639        37         0    (41, 43]
# (39, 41]   (45, 47]   6   AJ000037735        90         0    (39, 41]
#            (47, 49]   7   AJ000037749        83         0    (39, 41]
#                       8   AJ000037756        81         0    (39, 41]
#                       9   AJ000037759       100         0    (39, 41]
#                       10  AJ000037844        13         0    (39, 41]
#            (49, 51]   11  AJ000037860        20         0    (39, 41]
#                       12  AJ000037866       126         0    (39, 41]
#            (45, 47]   13  AJ000037895        33         0    (39, 41]
#            (47, 49]   14  AJ000037905       241         0    (39, 41]
#            (49, 51]   15  AJ000037925        13         0    (39, 41]
#            (45, 47]   16  AJ000037936       144         0    (39, 41]
# (37, 39]   (47, 49]   18  AJ000037984        30         0    (37, 39]
#                       19  AJ000037985       588         0    (37, 39]
#                       20  AJ000037989       365         0    (37, 39]
# (39, 41]   (43, 45]   21  AM000037686      1095         0    (39, 41]
#            (45, 47]   22  AM000037711        78         0    (39, 41]
#                       23  AM000037719        63         0    (39, 41]
#            (43, 45]   24  AM000037774        10         0    (39, 41]
#                       25  AM000037781      1126         0    (39, 41]
#                       26  AM000037787        80         0    (39, 41]
#                       27  AM000037789       730         0    (39, 41]
# (37, 39]   (45, 47]   30  AM000037958        77         0    (37, 39]
# (-13, -11] (15, 17]   32  AO000066270        25         0  (-13, -11]
# (-15, -13] (13, 15]   33  AO000066390         1         0  (-15, -13]
# (-17, -15] (11, 13]   34  AO000066422         1         0  (-17, -15]
# (-23, -21] (-67, -65] 35  AR000087007         7         0  (-23, -21]
# (-25, -23] (-61, -59] 36  AR000087078       729         0  (-25, -23]
# (-29, -27] (-65, -63] 37  AR000087129      1422         0  (-29, -27]
#            (-61, -59] 38  AR000087155       166         0  (-29, -27]
# (-31, -29] (-67, -65] 39  AR000087217       365         0  (-31, -29]
#            (-63, -61] 40  AR000087257       967         0  (-31, -29]
#            (-61, -59] 41  AR000087270       365         0  (-31, -29]
# (-33, -31] (-65, -63] 42  AR000087344      1186         0  (-33, -31]
#            (-69, -67] 43  AR000087418       421         0  (-33, -31]
# (-35, -33] (-65, -63] 44  AR000087534       534         0  (-35, -33]
# (-37, -35] (-65, -63] 45  AR000087623       727         0  (-37, -35]
# (-39, -37] (-59, -57] 46  AR000087692       363         0  (-39, -37]
#            (-69, -67] 47  AR000087715       530         0  (-39, -37]
# (-43, -41] (-73, -71] 48  AR000087803       217         0  (-43, -41]
# (-45, -43] (-67, -65] 49  AR000087828       729         0  (-45, -43]
# (-53, -51] (-71, -69] 50  AR000087925         5         0  (-53, -51]
# (-31, -29] (-69, -67] 51  AR000873050       364         0  (-31, -29]
# (-37, -35] (-63, -61] 52  AR000875440       148         0  (-37, -35]
# (-35, -33] (-59, -57] 53  AR000875850       730         0  (-35, -33]
# (-39, -37] (-63, -61] 54  AR000877500       365         0  (-39, -37]
# (-15, -13] (125, 127] 55  ASN00001007       730         0  (-15, -13]
# (-17, -15] (123, 125] 56  ASN00001009       364         0  (-17, -15]
#            (127, 129] 57  ASN00001013      1059         0  (-17, -15]
# (-15, -13] (125, 127] 58  ASN00001021       685         0  (-15, -13]
# (-19, -17] (127, 129] 59  ASN00002012       365         0  (-19, -17]
# (-17, -15] (127, 129] 60  ASN00002056       351         0  (-17, -15]
#                       61  ASN00002064       363         0  (-17, -15]
# (-19, -17] (121, 123] 62  ASN00003003      1095         0  (-19, -17]
# (-17, -15] (121, 123] 63  ASN00003004       729         0  (-17, -15]
#                                   ...       ...       ...         ...
#
#                             longroup
# latgroup   longroup
# (35, 37]   (3, 5]     0       (3, 5]
# (27, 29]   (9, 11]    1      (9, 11]
# (21, 23]   (5, 7]     2       (5, 7]
# (35, 37]   (-1, 1]    3      (-1, 1]
# (41, 43]   (45, 47]   4     (45, 47]
#                       5     (45, 47]
# (39, 41]   (45, 47]   6     (45, 47]
#            (47, 49]   7     (47, 49]
#                       8     (47, 49]
#                       9     (47, 49]
#                       10    (47, 49]
#            (49, 51]   11    (49, 51]
#                       12    (49, 51]
#            (45, 47]   13    (45, 47]
#            (47, 49]   14    (47, 49]
#            (49, 51]   15    (49, 51]
#            (45, 47]   16    (45, 47]
# (37, 39]   (47, 49]   18    (47, 49]
#                       19    (47, 49]
#                       20    (47, 49]
# (39, 41]   (43, 45]   21    (43, 45]
#            (45, 47]   22    (45, 47]
#                       23    (45, 47]
#            (43, 45]   24    (43, 45]
#                       25    (43, 45]
#                       26    (43, 45]
#                       27    (43, 45]
# (37, 39]   (45, 47]   30    (45, 47]
# (-13, -11] (15, 17]   32    (15, 17]
# (-15, -13] (13, 15]   33    (13, 15]
# (-17, -15] (11, 13]   34    (11, 13]
# (-23, -21] (-67, -65] 35  (-67, -65]
# (-25, -23] (-61, -59] 36  (-61, -59]
# (-29, -27] (-65, -63] 37  (-65, -63]
#            (-61, -59] 38  (-61, -59]
# (-31, -29] (-67, -65] 39  (-67, -65]
#            (-63, -61] 40  (-63, -61]
#            (-61, -59] 41  (-61, -59]
# (-33, -31] (-65, -63] 42  (-65, -63]
#            (-69, -67] 43  (-69, -67]
# (-35, -33] (-65, -63] 44  (-65, -63]
# (-37, -35] (-65, -63] 45  (-65, -63]
# (-39, -37] (-59, -57] 46  (-59, -57]
#            (-69, -67] 47  (-69, -67]
# (-43, -41] (-73, -71] 48  (-73, -71]
# (-45, -43] (-67, -65] 49  (-67, -65]
# (-53, -51] (-71, -69] 50  (-71, -69]
# (-31, -29] (-69, -67] 51  (-69, -67]
# (-37, -35] (-63, -61] 52  (-63, -61]
# (-35, -33] (-59, -57] 53  (-59, -57]
# (-39, -37] (-63, -61] 54  (-63, -61]
# (-15, -13] (125, 127] 55  (125, 127]
# (-17, -15] (123, 125] 56  (123, 125]
#            (127, 129] 57  (127, 129]
# (-15, -13] (125, 127] 58  (125, 127]
# (-19, -17] (127, 129] 59  (127, 129]
# (-17, -15] (127, 129] 60  (127, 129]
#                       61  (127, 129]
# (-19, -17] (121, 123] 62  (121, 123]
# (-17, -15] (121, 123] 63  (121, 123]
#                                  ...
#
# [4567 rows x 13 columns]

# %% [markdown]
# #### Great let's build the map/reduce job that computes the PCA for each group!

# %% [markdown]
# ### NOTE! Since I could not run the HWPART1 step on the cluster I run it locally and used a smaller dataset instead. But since the basestations included in the ALL.head and the SAMPLE_TMAX are not the same, the map/reduce might crush... Just use the same file for both Part1 and Part 2

# %%
# %%writefile pcagroubedby.py
#!/usr/bin/python
"""
count the number of measurements for each base-station
"""
import sys
import pandas as pd
import numpy as np
import sklearn as sk
sys.path.append('/usr/lib/python2.6/dist-packages')
from mrjob.job import MRJob
from mrjob.step import MRStep
import re
from sys import stderr
import json

class pcagroubedby(MRJob):
    
    def __init__(self, *args, **kwargs):
        super(pcagroubedby, self).__init__(*args, **kwargs)
        self.data = {}
        
    

    def configure_options(self):
        super(pcagroubedby, self).configure_options()
        self.add_file_option('--hashmap')
        self.add_file_option('--usemeasurement')

    def mapper_init(self):
        json_data=open(self.options.hashmap)
        self.meas = self.options.usemeasurement
        self.data = json.load(json_data)
        #sys.stderr.write('loaded: '+str(self.meas))
        #sys.stderr.write(str(data))
        json_data.close()
        # make dictionary available to mapper
        #sys.stderr.write('MAPPER_INIT!!')
        #sys.stderr.write(str(self.options.hashmap))
        
        #self.sqlite_conn = sqlite3.connect(self.options.database)
    def mapper(self, _, line):
#         for key in self.data:
#             sys.stderr.write( key + ' corresponds to'+ str(self.data[key])+'\n')

        try:
            self.increment_counter('MrJob Counters','mapper-all',1)
            elements=line.split(',')
            if elements[0]=='station':
                
                # if the header is spotted add it, it's not going to matter
                # since no base-station with name: 'header' exists, so when we do the
                # inner join this will be pruned
                
                out=('header','0~0')
                #yield out
            else:
                if elements[1]==self.meas:
                    #sys.stderr.write('YOLO')
                    
                    # Uncomment that to get measurements from a specific year.
                    #if elements[2]=='1973':
                        
                        # Use the following instead if you want to avoid null values
                        #out=(str(self.data[elements[0]]),str(filter(None,elements[3:])))#+'~'+str(0))
                        
                        out=(str(self.data[elements[0]]),(elements[3:]))#+'~'+str(0))
                        #sys.stderr.write(str(out))
                        yield out
#                 elif elements[1]=='TMAX':
                    
#                     # Uncomment that to get measurements from a specific year.
#                     #if elements[2]=='1973':
                        
                        
#                         out=(str(self.data[elements[0]]),'TMAX'+(elements[3:]))#+'~'+str(0))
#                         sys.stderr.write(str(out))
#                         yield out
        except Exception, e:

            self.increment_counter('MrJob Counters','mapper-error',1)
            
            # Again... This would be pruned when we would do the inner join later so let's ommit it right away...
            
            
            ################################################################################################################
            # NOTE! Since I could not run the HWPART1 step on the cluster I run it locally and used a smaller dataset      #
            # with TMAX measurements instead. So the basestations included in the ALL.head and the SAMPLE_TMAX are not     #
            # the same... Just use the same file for both Part1 and Part 2                                                 #
            ################################################################################################################
        #   out=('error','0~0')
            #yield out

        
#     def combiner(self, station, vals):
#         yield (0,0)
        
    def reducer(self, group, vals):

        self.increment_counter('MrJob Counters','reducer',1)
        #sys.stderr.write('group range is: '+str(group)+'\n')
        valArr = []
        
        for val in vals:
            #sys.stderr.write(str(val)+'\n')
            valArr.append(val)



        # Awesome! Let's use a Dataframe!
        ddtf = pd.DataFrame(valArr,columns = range(1,366))
        
        # Since we have a lot of empty values replace them with np.nan 
        # this is gonna make the processing easier
        
        ddtf = ddtf.replace('', np.nan)
        
        # Let's check out the measurements
        #sys.stderr.write(str(ddtf.head()))  # Checked!
        

        
        # switch the type of every element in the dataframe from an object to a float
        for listElem in list(ddtf.columns.values):
            #sys.stderr.write(str(listElem))
            ddtf[listElem] = ddtf[listElem].astype(float)#.fillna(0.0)
        
        
        # It should be float now
        # sys.stderr.write('\nddtf types: '+str(ddtf.dtypes))   # Yes it is!

        
        M=ddtf.loc[:,:].transpose()
        
        # check the shape of M
        #sys.stderr.write('\nM shape is: '+str(M.shape))
        
        M=M.dropna(axis=1)
        
        # check again after dropping the nan values
        #sys.stderr.write('\n M shape after droping NaNs is: '+str(np.shape(M)))
        
        (columns,rows)=np.shape(M)
        
        
        # Let's compute the covariance, (We could use np.cov instead...)
        if rows !=0:
            Mean=np.mean(M, axis=1).values


            C=np.zeros([columns,columns])   # Sum
            N=np.zeros([columns,columns])   # Counter of non-nan entries

            for i in range(rows):
                row=M.iloc[:,i]-Mean;
                outer=np.outer(row,row)
                valid=np.isnan(outer)==False
                C[valid]=C[valid]+outer[valid]  # update C with the valid location in outer
                N[valid]=N[valid]+1
            valid_outer=np.multiply(1-np.isnan(N),N>0)
            cov=np.divide(C,N)
#             cov2 = np.cov(M)
#             sys.stderr.write('\ncov is: \n'+str(cov)+'\ncov2 is: \n'+str(cov2))
#             for elem in cov:
#                 sys.stderr.write('\ncov is: \n'+str(elem))
#            sys.stderr.write('\nnp.sum(cov) : '+str(np.sum(cov)))
            summation = np.sum(cov)
            if summation!=0:
                U,D,V=np.linalg.svd(cov)
                #sys.stderr.write('\nyielding D')
                yield (group+str(rows),str(D))

                
        #else:
        #    sys.stderr.write('nothing to do here')

if __name__ == '__main__':
    pcagroubedby.run()
# Out:
# Overwriting pcagroubedby.py

# %% [markdown]
# #### Great! Let's test it locally!
#
# The command shown below specifically defines which data we'll take into account by specifying which attribute we'll use for our analysis  (e.g: --usemeasurement='TMAX') we did that because the dataset we used locally didn't have a TMIN value so it would be inefficient to have TMIN values equal to 0. If we want to do this analysis for both TMIN and TMAX we can run it twice and parse the data as shown next...

# %%
#local_data='/home/ubuntu/UCSD_BigData/data/weather/ALL.head.csv'
local_data='/home/ubuntu/UCSD_BigData/data/weather/SAMPLE_TMAX.csv'
# !python pcagroubedby.py -r local --hashmap=grouping.json --usemeasurement='TMAX' $local_data > counts.out
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/pcagroubedby.ubuntu.20140602.030019.544527
# writing to /tmp/pcagroubedby.ubuntu.20140602.030019.544527/step-0-mapper_part-00000
# > /home/ubuntu/anaconda/bin/python pcagroubedby.py --step-num=0 --mapper --hashmap grouping.json --usemeasurement TMAX /tmp/pcagroubedby.ubuntu.20140602.030019.544527/input_part-00000 > /tmp/pcagroubedby.ubuntu.20140602.030019.544527/step-0-mapper_part-00000
# writing to /tmp/pcagroubedby.ubuntu.20140602.030019.544527/step-0-mapper_part-00001
# > /home/ubuntu/anaconda/bin/python pcagroubedby.py --step-num=0 --mapper --hashmap grouping.json --usemeasurement TMAX /tmp/pcagroubedby.ubuntu.20140602.030019.544527/input_part-00001 > /tmp/pcagroubedby.ubuntu.20140602.030019.544527/step-0-mapper_part-00001
# Counters from step 1:
#   MrJob Counters:
#     mapper-all: 20000
# writing to /tmp/pcagroubedby.ubuntu.20140602.030019.544527/step-0-mapper-sorted
# > sort /tmp/pcagroubedby.ubuntu.20140602.030019.544527/step-0-mapper_part-00000 /tmp/pcagroubedby.ubuntu.20140602.030019.544527/step-0-mapper_part-00001
# writing to /tmp/pcagroubedby.ubuntu.20140602.030019.544527/step-0-reducer_part-00000
# > /home/ubuntu/anaconda/bin/python pcagroubedby.py --step-num=0 --reducer --hashmap grouping.json --usemeasurement TMAX /tmp/pcagroubedby.ubuntu.20140602.030019.544527/input_part-00000 > /tmp/pcagroubedby.ubuntu.20140602.030019.544527/step-0-reducer_part-00000
# writing to /tmp/pcagroubedby.ubuntu.20140602.030019.544527/step-0-reducer_part-00001
# > /home/ubuntu/anaconda/bin/python pcagroubedby.py --step-num=0 --reducer --hashmap grouping.json --usemeasurement TMAX /tmp/pcagroubedby.ubuntu.20140602.030019.544527/input_part-00001 > /tmp/pcagroubedby.ubuntu.20140602.030019.544527/step-0-reducer_part-00001
# Counters from step 1:
#   MrJob Counters:
#     mapper-all: 20000
#     reducer: 2019
# Moving /tmp/pcagroubedby.ubuntu.20140602.030019.544527/step-0-reducer_part-00000 -> /tmp/pcagroubedby.ubuntu.20140602.030019.544527/output/part-00000
# Moving /tmp/pcagroubedby.ubuntu.20140602.030019.544527/step-0-reducer_part-00001 -> /tmp/pcagroubedby.ubuntu.20140602.030019.544527/output/part-00001
# Streaming final output from /tmp/pcagroubedby.ubuntu.20140602.030019.544527/output
# removing tmp directory /tmp/pcagroubedby.ubuntu.20140602.030019.544527

# %%
# !head -c2000 counts.out
# Out:
# "[u'(41, 43],(-115, -113]']14"	"[  1.83836482e+05   1.37256203e+05   1.12355845e+05   9.68965861e+04\n   7.18748398e+04   6.59156354e+04   6.03591174e+04   5.60690648e+04\n   4.74693668e+04   4.31126685e+04   4.13725033e+04   2.25221789e+04\n   8.30425440e+03   1.65446903e-10   1.63279596e-10   1.63279596e-10\n   1.44523940e-10   1.24494976e-10   1.16113947e-10   1.10292571e-10\n   1.03463533e-10   1.02691067e-10   9.71584916e-11   9.27480245e-11\n   8.90230858e-11   7.07085710e-11   6.13411651e-11   6.10091409e-11\n   5.85797249e-11   5.02388220e-11   4.75930154e-11   4.68547080e-11\n   4.67981663e-11   4.39251879e-11   4.22671075e-11   4.01760836e-11\n   3.92523699e-11   3.67805568e-11   3.65516619e-11   3.48336755e-11\n   3.32619731e-11   3.05789421e-11   2.84481216e-11   2.75596740e-11\n   2.66600398e-11   2.58576493e-11   2.50091826e-11   2.32661313e-11\n   1.98720250e-11   1.71557101e-11   1.56204249e-11   1.56204249e-11\n   1.56204249e-11   1.56204249e-11   1.56204249e-11   1.56204249e-11\n   1.56204249e-11   1.56204249e-11   1.56204249e-11   1.56204249e-11\n   1.56204249e-11   1.56204249e-11   1.56204249e-11   1.56204249e-11\n   1.56204249e-11   1.56204249e-11   1.56204249e-11   1.56204249e-11\n   1.56204249e-11   1.56204249e-11   1.56204249e-11   1.56204249e-11\n   1.56204249e-11   1.56204249e-11   1.56204249e-11   1.56204249e-11\n   1.56204249e-11   1.56204249e-11   1.56204249e-11   1.56204249e-11\n   1.56204249e-11   1.56204249e-11   1.56204249e-11   1.56204249e-11\n   1.56204249e-11   1.56204249e-11   1.56204249e-11   1.56204249e-11\n   1.56204249e-11   1.56204249e-11   1.56204249e-11   1.56204249e-11\n   1.56204249e-11   1.56204249e-11   1.56204249e-11   1.56204249e-11\n   1.56204249e-11   1.56204249e-11   1.56204249e-11   1.56204249e-11\n   1.56204249e-11   1.56204249e-11   1.56204249e-11   1.56204249e-11\n   1.56204249e-11   1.56204249e-11   1.56204249e-11   1.56204249e-11\n   1.56204249e-11   1.56204249e-11   1.56204249e-11   1.56204249e-11\n   1.562

# %% [markdown]
# #### It works! Let's try to run it on the cluster with the full dataset!
#
# Again... We couldn't really run this on the cluster due to the reasons we mentioned...

# %%
import pickle
try:
    Creds= pickle.load(open('/home/ubuntu/Vault/Creds.pkl','rb'))
    #print Creds.keys()
    #print Creds['mrjob'].keys()
    pair=Creds['mrjob']
    key_id=pair['key_id']
    secret_key=pair['secret_key']
    ID=pair['ID']
    if ID is not None:
        print 'done!'
    else:
        print 'hmm! Something went wrong!'
        
except:
    print 'hmm! Something went wrong!'
    print sys.exc_info()[0]
#print ID,key_id
# Out:
# done!

# %%
import sys
home_dir='/home/ubuntu/UCSD_BigData'
sys.path.append(home_dir+'/utils')
from find_waiting_flow import *
from AWS_keypair_management import *

# %%
job_flow_id=find_waiting_flow(key_id,secret_key)
#job_flow_id = 'j-262J0JTFJIRLO'
job_flow_id
# Out:
# 'NONE'

# %%
# !python pcagroubedby.py -r emr --emr-job-flow-id $job_flow_id --hashmap=grouping.json --usemeasurement='TMAX' hdfs:/weather/weather.csv > countsEMR
#!python pcatogroups.py -r local --hashmap=grouping.json $local_data > counts
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/pcatogroups.ubuntu.20140525.095456.253183
# Copying non-input files into s3://costaszarifisbucket/scratch/pcatogroups.ubuntu.20140525.095456.253183/files/
# Adding our job to existing job flow j-262J0JTFJIRLO
# Attempting to terminate job...
# Traceback (most recent call last):
#   File "pcatogroups.py", line 169, in <module>
#     SqliteJob.run()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/job.py", line 494, in run
#     mr_job.execute()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/job.py", line 512, in execute
#     super(MRJob, self).execute()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/launch.py", line 147, in execute
#     self.run_job()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/launch.py", line 213, in run_job
#     self.stdout.flush()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/runner.py", line 614, in __exit__
#     self.cleanup()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/emr.py", line 1010, in cleanup
#     super(EMRJobRunner, self).cleanup(mode=mode)
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/runner.py", line 560, in cleanup
#     self._cleanup_job()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/emr.py", line 1084, in _cleanup_job
#     self._opts['ec2_key_pair_file'])
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/ssh.py", line 200, in ssh_terminate_single_job
#     ssh_bin, address, ec2_key_pair_file, ['hadoop', 'job', '-list']))
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/ssh.py", line 82, in ssh_run
#     p = Popen(args, stdout=PIPE, stderr=PIPE, stdin=PIPE)
#   File "/home/ubuntu/anaconda/lib/python2.7/subprocess.py", line 709, in __init__
#     errread, errwrite)
#   File "/home/ubuntu/anaconda/lib/python2.7/subprocess.py", line 1326, in _execute_child
#     raise child_exception
# TypeError: execv() arg 2 must contain only strings

# %%
# !head -n15 counts

# %%
def find_between( s, first, last ):
    ss = []
    try:
        start = s.index( first ) + len( first )
        end = s.index( last, start )
        return s[start:end]
#         start = s.rindex( first ) + len( first )
#         end = s.rindex( last, start )
#         ss.append(s[start:end])
#         return ss
    except ValueError:
        return ""
    
def find_between_r( s, first, last ):
    try:
        start = s.rindex( first ) + len( first )
        end = s.rindex( last, start )
        return s[start:end]
    except ValueError:
        return ""

# %%
'''
This is a parser that transforms our output to a dictionary so that we can plot the eigen vectors

source: the source file (e.g counts)
dest: the destination file(e.g dest.csv)
'''
from collections import defaultdict


def generateDict(source):
    import csv
    d = defaultdict(list)
    numOfMeasd = {}
    myrow = []
    with open(source, 'rb') as csvfile:
        spamreader = csv.reader(csvfile, delimiter='\n')
        for row in spamreader:
            
            for k in row:
                #print k
                elements=k.split('\t')
                basestation= elements[0]
                
                numOfM = find_between_r(str(basestation), '\']','')
                basestation = basestation.replace(numOfM, '')
                #print basestation
                vals=elements[1].split('   ')
                numOfMeasd[basestation] = int(numOfM)
                for val in vals:
                    #tmpstr = val.replace(']"','').replace('"[','').rstrip('\\n')
                    d[basestation].append(float(val.replace(']"','').replace('"[','').rstrip('\\n')))
                    #print float(val.replace(']"','').replace('"[','').rstrip('\\n'))
                    #a.replace('\n','').replace(']"','').
                                                     

    return (d,numOfMeasd)

# %%
(d,NumD) = generateDict('counts.out')

# %%
def example_plot(ax, x):
#     ax.plot(x)
#     ax.locator_params(nbins=3)
    #    D = d[key]
    ax.plot(cumsum(x[:])/sum(x))
    
    ax.set_xlim([0,10])
    ax.set_ylim([0,2])
    grid()

# %%
valzz = []
counter = 0
for key in d:
    if counter == 7:
        break
    valzz.append(d[key])
plt.close('all')
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2)
example_plot(ax1, valzz[0])
example_plot(ax2, valzz[1])
example_plot(ax3, valzz[5])
example_plot(ax4, valzz[6])

#plt.tight_layout()

# %%
# for key in d:
#     #print key
#     D = d[key]
#     plot(cumsum(D[:])/sum(D))
#     cnt = 0
#     for kkk in cumsum(D[:])/sum(D):
#         print kkk, cnt
#         cnt+=1
#     xlim([0,30])
#     grid()

# %%
indx=[]
for key in d:
    #print key
    D = d[key]
    cnt = 0
    for kkk in cumsum(D[:])/sum(D):
        if kkk>0.99:
            indx.append(cnt)
            break
        cnt+=1
#     plot(cumsum(D[:])/sum(D))
#     xlim([0,365])
#     grid()

# %%
counter = 0
for key in d:
    D = d[key]
    plot(cumsum(D[:indx[counter]])/sum(D))
    counter+=1
    xlim([0,100])
    grid()

# %%
def find_between( s, first, last ):
    ss = []
    try:
        start = s.index( first ) + len( first )
        end = s.index( last, start )
        return s[start:end]
#         start = s.rindex( first ) + len( first )
#         end = s.rindex( last, start )
#         ss.append(s[start:end])
#         return ss
    except ValueError:
        return ""
    
def find_between_r( s, first, last ):
    try:
        start = s.rindex( first ) + len( first )
        end = s.rindex( last, start )
        return s[start:end]
    except ValueError:
        return ""

# %% [markdown]
# #### Now, we will try to figure out if by merging together neighbours we can explain the same percentage of the variance using less eigen vectors
#
# Since we only have rectangles representing the groups we can use the central point of the geometry and the kdtree implementation to query geometries that are nearby and try to group them together.

# %%
centerpoints = []
initlats = []
initlongs = []
for key in d:
    kk = key
    #print key    
    ll = find_between(key,'(', ']')
    lr = find_between_r(key,'(', ']\'')#.replace("]","")
    #print ll, lr

    vals1=ll.split(',')
    #print mean([float(vals[0]),float(vals[1])], dtype=np.float64)
    vals2=lr.split(',')
    #print ((mean([float(vals1[0]),float(vals1[1])], dtype=np.float64)),mean([float(vals2[0]),float(vals2[1])], dtype=np.float64))
    centerpoints.append(((mean([float(vals1[0]),float(vals1[1])], dtype=np.float64)),mean([float(vals2[0]),float(vals2[1])], dtype=np.float64)))
    initlats.append((float(vals1[0]),float(vals1[1])))
    initlongs.append((float(vals2[0]),float(vals2[1])))

# %%
from scipy import spatial

tree = spatial.KDTree(centerpoints)
j = tree.query_ball_point(centerpoints[1], 2)
centerpoints[1]
# Out:
# (38.0, -82.0)

# %%
j
print tree.data[j]
for jj in j:
    #print centerpoints[jj]
    print initlats[jj]
    print initlongs[jj]
    print
# Out:
# [[ 38. -82.]
#  [ 36. -82.]
#  [ 38. -84.]
#  [ 38. -80.]
#  [ 40. -82.]]
# (37.0, 39.0)
# (-83.0, -81.0)
#
# (35.0, 37.0)
# (-83.0, -81.0)
#
# (37.0, 39.0)
# (-85.0, -83.0)
#
# (37.0, 39.0)
# (-81.0, -79.0)
#
# (39.0, 41.0)
# (-83.0, -81.0)

# %% [markdown]
# The Idea for the iteration is that we will keep increasing the radius thus including merging groups into a hypergroup until the relation shown [here](http://seed.ucsd.edu/mediawiki/index.php/BigDataHW2#Suggested_Steps "Title") is satisfied. The problem is that this iteration at each steps requires the re-computation of the PCA with a map reduce job and it is impossible to run it again and again.
#
# Is there another way? Am I missing something?
#
#
# Let's assume that we have two areas  A_1 and A_2. For A_1 we need k_1 eigenvectors to explain 99% of the variance while for A_2 we need k_2. We want to compute how many eigenvectors (k_3) are needed to explain 99% of the variance for A_3 = A_1\cup A_2 . Since we are talking about a new area the old eigenvectors are useless right? We need a new set of independent vectors to represent the new information. Is there a way to combine the two sets of eigenvectors so that we could generate the ones for A_3?
