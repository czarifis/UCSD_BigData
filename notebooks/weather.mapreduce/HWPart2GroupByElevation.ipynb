# %% [markdown]
# ### Part 2.c. Group together base-stations based on their elevation level.
#
#
# We expect base-stations that have a similar elevation to provide similar measurements... Let's find out if that holds!

# %% [markdown]
# #### Let's import the required libs

# %%
import pandas as pd
import numpy as np
import sklearn as sk
print 'pandas version: ',pd.__version__
print 'numpy version:',np.__version__
print 'sklearn version:',sk.__version__
# Out:
# pandas version:  0.13.1
# numpy version: 1.8.1
# sklearn version: 0.14.1

# %% [markdown]
# #### Let's load the data from the csv file we created on the last part... We only care about the TMAX and the TMIN values (check previous notebook for details)

# %%
header_row=['station','maxcount','mincount'] # note the header has duplicate column values
maxmindf = pd.read_csv('basestationmaxmin.csv', names=header_row)
maxmindf.head()
# Out:
#        station  maxcount  mincount
# 0  AG000060390       365         0
# 1  AG000060611       730         0
# 2  AG000060680       365         0
# 3  AGE00135039        26         0
# 4  AJ000037575       209         0
#
# [5 rows x 3 columns]

# %%
#!gunzip stations.pkl.gz
import pickle
# !gunzip -c stations.pkl.gz > stations.pkl  # This command also keeps the initial gz file....
stations=pickle.load(open('stations.pkl', 'rb'))
df = pd.read_pickle('stations.pkl')
df['station'] = df.index # let's create a column with the indexes (base-station names)
df.head()
# Out:
#              latitude  longitude  elevation state                   name  \
# ACW00011604   17.1167   -61.7833       10.1   NaN  ST JOHNS COOLIDGE FLD
# ACW00011647   17.1333   -61.7833       19.2   NaN               ST JOHNS
# AE000041196   25.3330    55.5170       34.0   NaN    SHARJAH INTER. AIRP
# AF000040930   35.3170    69.0170     3366.0   NaN           NORTH-SALANG
# AG000060390   36.7167     3.2500       24.0   NaN     ALGER-DAR EL BEIDA
#
#             GSNFLAG HCNFLAG  WMOID      station
# ACW00011604     NaN     NaN    NaN  ACW00011604
# ACW00011647     NaN     NaN    NaN  ACW00011647
# AE000041196     GSN     NaN  41196  AE000041196
# AF000040930     GSN     NaN  40930  AF000040930
# AG000060390     GSN     NaN  60390  AG000060390
#
# [5 rows x 9 columns]

# %%
stationNames = df["station"].tolist()  # keeping a list with all the names of the base-stations for future reference

# %%
## Ignore me! House keeping purposes
def isBaseStationPresent(sname,listOfStations):
    for stName in listOfStations:
        if stName==sname:
            print 'found: ', stName
            return
    print 'Nope! ',sname,' Not found!'

# %%
print 'number of base-stations',shape(df)[0]
print 'number of base-stations with measurements',shape(maxmindf)[0]
# Out:
# number of base-stations 85284
# number of base-stations with measurements 12130

# %% [markdown]
# ####Apparently there are base-stations that have no TMAX-TMIN measurements at all, since the number of base station in the two dataframes vary. We chose to do an inner join in order to prune these base-stations

# %%
res = pd.merge(df, maxmindf, on='station', how='inner')
res.head()
# Out:
#    latitude  longitude  elevation state                    name GSNFLAG  \
# 0   36.7167     3.2500         24   NaN      ALGER-DAR EL BEIDA     GSN
# 1   28.0500     9.6331        561   NaN               IN-AMENAS     GSN
# 2   22.8000     5.4331       1362   NaN             TAMANRASSET     GSN
# 3   35.7297     0.6500         50   NaN  ORAN-HOPITAL MILITAIRE     NaN
# 4   41.5500    46.6670        490   NaN                ZAKATALA     NaN
#
#   HCNFLAG  WMOID      station  maxcount  mincount
# 0     NaN  60390  AG000060390       365         0
# 1     NaN  60611  AG000060611       730         0
# 2     NaN  60680  AG000060680       365         0
# 3     NaN    NaN  AGE00135039        26         0
# 4     NaN  37575  AJ000037575       209         0
#
# [5 rows x 11 columns]

# %%
stationNames2 = res["station"].tolist()
isBaseStationPresent('USC00211063',stationNames2)
isBaseStationPresent('AG000060680',stationNames2)
# Out:
# Nope!  USC00211063  Not found!
# found:  AG000060680

# %%
res['elevation'].hist(bins=5)

# %% [markdown]
# ####There are obviously a lot of base-stations with elevation less than 1000 so we will create a lot of groups for base-stations less than 1000 and less in number groups for base-stations higher than 1000...

# %%
#a = array([1,2,3])
#ba = array([4,5,6])
a = np.arange(0, 1000, 0.2)
b = np.arange(1001, 2000, 1)
c= np.arange(2001,5000, 10)
elegroup = numpy.concatenate((a,b,c))

# %% [markdown]
# ####Using geographical data to partition base-stations

# %%
#tempdf = res.groupby(pd.cut(res["latitude"], np.arange(-90, 90, 10)))#.head()#.sum()  #np.arange(0, 1.0+0.155, 0.155)
tempdf = res.copy()
tempdf['elevationgroup'] = pd.cut(res["elevation"], elegroup)#.head()#.sum()  #np.arange(0, 1.0+0.155, 0.155)
#tempdf['longroup'] = pd.cut(res["longitude"], np.arange(-185, 185, 2))#.head()#.sum()  #np.arange(0, 1.0+0.155, 0.155)
#tempdf.reset_index()

#tempdf['status'] = pd.cut(df['Days Late'], bins=[-1, 14, 35, 56, 365])

# Droping nan values
tempdf.dropna() 
tempdf.head()
# Out:
#    latitude  longitude  elevation state                    name GSNFLAG  \
# 0   36.7167     3.2500         24   NaN      ALGER-DAR EL BEIDA     GSN
# 1   28.0500     9.6331        561   NaN               IN-AMENAS     GSN
# 2   22.8000     5.4331       1362   NaN             TAMANRASSET     GSN
# 3   35.7297     0.6500         50   NaN  ORAN-HOPITAL MILITAIRE     NaN
# 4   41.5500    46.6670        490   NaN                ZAKATALA     NaN
#
#   HCNFLAG  WMOID      station  maxcount  mincount elevationgroup
# 0     NaN  60390  AG000060390       365         0     (23.8, 24]
# 1     NaN  60611  AG000060611       730         0   (560.8, 561]
# 2     NaN  60680  AG000060680       365         0   (1361, 1362]
# 3     NaN    NaN  AGE00135039        26         0     (49.8, 50]
# 4     NaN  37575  AJ000037575       209         0   (489.8, 490]
#
# [5 rows x 12 columns]

# %%
print 'number of base-stations with measurements',shape(tempdf)[0]
# Out:
# number of base-stations with measurements 12130

# %% [markdown]
# ###Checking if every base-station is assigned to a group successfully!

# %%
# Checking if every base-station is assigned to a group successfully!

elev1z=[]


lon1z=[]
lat1z=[]
countnans=0

    
for index, row in tempdf.iterrows():
    elements=str(row['elevationgroup']).split(',')
    latit = row['latitude']
    longit = row['longitude']
    #elements2=str(row['longroup']).split(',')
    if not((str(elements) == "['nan']")): 
        #if not ((str(elements2) == "['nan']")):
            #print str(elements2)
            x1 = float(elements[0].translate(None, '(').translate(None, ']'))
            x2 = float(elements[1].translate(None, '(').translate(None, ']'))


            #print str(row)
            #y1 = float(elements2[0].translate(None, '(').translate(None, ']'))
            #y2 = int(elements2[1].translate(None, '(').translate(None, ']'))

            elev1z.append(x1)
            #elev2z.append(x2)
            
            #lat1z.append(x1)
            #lat2z.append(x2)
            #lon1z.append(y1)
            #lon2z.append(y2)
            #print 'printing...',str(row['latgroup'])+','+str(row['longroup'])
        #else:
        #    print 'nan found on longroup', str(row['latgroup']),(row['latitude']),str(row['longroup']),(row['longitude'])
        #    countnans+=1
    else:
        #print 'nan found on elevationgroup', str(row['latgroup']),(row['latitude']),str(row['longroup']),(row['longitude'])
        countnans+=1
    #print x1,y1,x2,y2
#     for elem in elements:
#         print int(elem.translate(None, '(').translate(None, ']'))
    
    #print 'yolo',str(row['latgroup'])+','+str(row['longroup'])

if countnans==0:
    print 'Every base-station is grouped to a region. We can proceed!'
else:
    print 'Oh, ', countnans, 'basestations had a negative elevation so we are discarding them'
# Out:
# Oh,  118 basestations had a negative elevation so we are discarding them

# %%
len(elev1z)
# Out:
# 12012

# %% [markdown]
# ### We need to send the information that represents the mappings between the base-stations and the groups to the map reduce job. We will use a dictionary to represent this information

# %%
import collections
d = collections.defaultdict(list)
for index, row in tempdf.iterrows():
    #print (row['latgroup'],row['longroup']),row['station']
    #d[str(row['latgroup'])+','+str(row['longroup'])].append(row['station'])
    d[row['station']].append(str(row['elevationgroup']))
    #d[str((row['latgroup']))].append(row['station'])

import json
with open('groupingelevation.json', 'w') as outfile:
  json.dump(d, outfile)
    
import pickle
with open('groupingelevation.pkl', 'w') as outfile:
  pickle.dump(d, outfile)

# %%
#need to check if the file is infact correct... 
# !head -c 300 groupingelevation.json
# Out:
# {"CA004035200": ["(694.8, 695]"], "USC00390043": ["(512, 512.2]"], "SF000068438": ["(1195, 1196]"], "USC00092485": ["(335.2, 335.4]"], "JQW00021603": ["(2.8, 3]"], "JQW00021601": ["(5, 5.2]"], "USC00448938": ["(103.8, 104]"], "USC00323686": ["(460, 460.2]"], "USC00095917": ["(528, 528.2]"], "USC0009

# %% [markdown]
# #### Each group is identified by the elevation it covers <<| elevation range |>>   (e.g ["(694.8, 695]"])

# %%
agg_df = tempdf.groupby('elevationgroup')
agg_df.head()



#lhead = agg_df.aggregate(np.sum)
#print lhead
# print tempdf.groupby('elevationgroup').size()
# print tempdf.groupby('elevationgroup').sum()
# print tempdf.groupby('elevationgroup').head()
# Out:
#                    latitude  longitude  elevation state  \
# elevationgroup
# (23.8, 24]     0    36.7167     3.2500         24   NaN
# (560.8, 561]   1    28.0500     9.6331        561   NaN
# (1361, 1362]   2    22.8000     5.4331       1362   NaN
# (49.8, 50]     3    35.7297     0.6500         50   NaN
# (489.8, 490]   4    41.5500    46.6670        490   NaN
# (332.8, 333]   5    41.1330    45.4170        333   NaN
# (310.8, 311]   6    40.7170    46.4170        311   NaN
# (94.8, 95]     7    40.6500    47.7500         95   NaN
# (754.8, 755]   8    40.5330    48.9330        755   NaN
# (891.8, 892]   9    40.6330    48.6330        892   NaN
# (3.8, 4]       10   40.3330    48.1670          4   NaN
# (27.8, 28]     11   40.5330    50.0000         28   NaN
# (999.8, 1001]  12   40.4670    50.3170        -24   NaN
# (827.8, 828]   13   39.9830    46.7500        828   NaN
# (70.8, 71]     14   39.7670    47.7500         71   NaN
# (999.8, 1001]  15   39.4000    49.2500        -24   NaN
# (884.8, 885]   16   39.2000    45.4170        885   NaN
# (1.8, 2]       17   39.7000    48.6000          2   NaN
# (1112, 1113]   18   38.7670    48.4000       1113   NaN
# (999.8, 1001]  19   38.7500    48.8170        -12   NaN
#                20   38.5000    48.9000        -22   NaN
# (1511, 1512]   21   40.7830    43.8330       1512   NaN
# (732.8, 733]   22   40.8670    45.1500        733   NaN
# (1833, 1834]   23   40.6000    45.3500       1834   NaN
# (1254, 1255]   24   40.3170    43.6670       1255   NaN
# (3221, 3231]   25   40.5000    44.2000       3223   NaN
# (864.8, 865]   26   40.1330    44.0500        865   NaN
# (1139, 1140]   27   40.1330    44.4670       1140   NaN
# (1960, 1961]   28   40.3500    45.1331       1961   NaN
# (1939, 1940]   29   40.2000    45.7500       1940   NaN
# (627.8, 628]   30   38.9000    46.2500        628   NaN
# (705.8, 706]   31   39.2000    46.4330        706   NaN
# (1303, 1304]   32  -11.4170    15.1170       1304   NaN
# (1760, 1761]   33  -14.9330    13.5670       1761   NaN
# (44.8, 45]     34  -15.2000    12.1500         45   NaN
# (3471, 3481]   35  -22.1000   -65.6000       3479   NaN
# (129.8, 130]   36  -24.7000   -60.5830        130   NaN
# (199.8, 200]   37  -27.7670   -64.3000        200   NaN
# (52.8, 53]     38  -27.4500   -59.0500         53   NaN
# (437.8, 438]   39  -29.3830   -66.8170        438   NaN
# (87.8, 88]     40  -29.8830   -61.9500         88   NaN
# (52.8, 53]     41  -29.1830   -59.7000         53   NaN
# (488.8, 489]   42  -31.3170   -64.2170        489   NaN
# (703.8, 704]   43  -32.8330   -68.7830        704   NaN
# (136.8, 137]   44  -34.1330   -63.3670        137   NaN
# (191.8, 192]   45  -36.5670   -64.2660        192   NaN
# (21.8, 22]     46  -37.9330   -57.5830         22   NaN
# (272.8, 273]   47  -38.9500   -68.1330        273   NaN
# (798.8, 799]   48  -42.9330   -71.1500        799   NaN
# (42.8, 43]     49  -43.2000   -65.2660         43   NaN
# (18.8, 19]     50  -51.6170   -69.2830         19   NaN
# (1174, 1175]   51  -30.2500   -68.7500       1175   NaN
# (84.8, 85]     52  -35.8670   -61.9000         85   NaN
# (24.8, 25]     53  -34.5830   -58.4830         25   NaN
# (74.8, 75]     54  -38.7330   -62.1670         75   NaN
# (5.8, 6]       55  -13.7542   126.1485          6   NaN
# (11.8, 12]     56  -15.4875   124.5222         12   NaN
# (10.8, 11]     57  -15.4872   128.1247         11   NaN
# (22.8, 23]     58  -14.2961   126.6431         23   NaN
# (421.8, 422]   59  -18.2292   127.6636        422   NaN
#                         ...        ...        ...   ...
#
#                                      name GSNFLAG HCNFLAG  WMOID      station  \
# elevationgroup
# (23.8, 24]     0       ALGER-DAR EL BEIDA     GSN     NaN  60390  AG000060390
# (560.8, 561]   1                IN-AMENAS     GSN     NaN  60611  AG000060611
# (1361, 1362]   2              TAMANRASSET     GSN     NaN  60680  AG000060680
# (49.8, 50]     3   ORAN-HOPITAL MILITAIRE     NaN     NaN    NaN  AGE00135039
# (489.8, 490]   4                 ZAKATALA     NaN     NaN  37575  AJ000037575
# (332.8, 333]   5         AGSTAPHA AIRPORT     NaN     NaN  37639  AJ000037639
# (310.8, 311]   6                   GANDJA     NaN     NaN  37735  AJ000037735
# (94.8, 95]     7                  GOYCHAY     NaN     NaN  37749  AJ000037749
# (754.8, 755]   8                   MARAZA     NaN     NaN  37756  AJ000037756
# (891.8, 892]   9                 SHAMAKHY     NaN     NaN  37759  AJ000037759
# (3.8, 4]       10                KURDAMIR     NaN     NaN  37844  AJ000037844
# (27.8, 28]     11                MASHTAGA     NaN     NaN  37860  AJ000037860
# (999.8, 1001]  12               PIRALLAHI     NaN     NaN  37866  AJ000037866
# (827.8, 828]   13               KHANKANDY     NaN     NaN  37895  AJ000037895
# (70.8, 71]     14      BEYLAGAN AERODROME     NaN     NaN  37905  AJ000037905
# (999.8, 1001]  15               NEFTCHALA     NaN     NaN  37925  AJ000037925
# (884.8, 885]   16                NAXCIVAN     NaN     NaN  37936  AJ000037936
# (1.8, 2]       17                GYOYTAPA     NaN     NaN  37978  AJ000037978
# (1112, 1113]   18                   LERIK     NaN     NaN  37984  AJ000037984
# (999.8, 1001]  19                LANKARAN     NaN     NaN  37985  AJ000037985
#                20                  ASTARA     GSN     NaN  37989  AJ000037989
# (1511, 1512]   21                   GUMRI     NaN     NaN  37686  AM000037686
# (732.8, 733]   22                 IDJEVAN     NaN     NaN  37711  AM000037711
# (1833, 1834]   23               CHAMBARAK     NaN     NaN  37719  AM000037719
# (1254, 1255]   24                 ARAGATS     NaN     NaN  37774  AM000037774
# (3221, 3231]   25    ARAGAC VISOKOGORNAYA     GSN     NaN  37781  AM000037781
# (864.8, 865]   26                 ARMAVIR     NaN     NaN  37787  AM000037787
# (1139, 1140]   27     YEREVAN/YEREVAN-ARA     NaN     NaN  37789  AM000037789
# (1960, 1961]   28                   GAVAR     NaN     NaN  37801  AM000037801
# (1939, 1940]   29                  MASRIK     NaN     NaN  37815  AM000037815
# (627.8, 628]   30                   MEGRI     NaN     NaN  37958  AM000037958
# (705.8, 706]   31                   KAPAN     NaN     NaN  37959  AM000037959
# (1303, 1304]   32       WAKU KUNGU (CELA)     GSN     NaN  66270  AO000066270
# (1760, 1761]   33     LUBANGO (SA DA BAND     GSN     NaN  66390  AO000066390
# (44.8, 45]     34               MOCAMEDES     GSN     NaN  66422  AO000066422
# (3471, 3481]   35     LA QUIACA OBSERVATO     GSN     NaN  87007  AR000087007
# (129.8, 130]   36             LAS LOMITAS     GSN     NaN  87078  AR000087078
# (199.8, 200]   37     SANTIAGO DEL ESTERO     GSN     NaN  87129  AR000087129
# (52.8, 53]     38        RESISTENCIA AERO     GSN     NaN  87155  AR000087155
# (437.8, 438]   39          LA RIOJA AERO.     GSN     NaN  87217  AR000087217
# (87.8, 88]     40              CERES AERO     GSN     NaN  87257  AR000087257
# (52.8, 53]     41        RECONQUISTA AERO     GSN     NaN  87270  AR000087270
# (488.8, 489]   42            CORDOBA AERO     GSN     NaN  87344  AR000087344
# (703.8, 704]   43            MENDOZA AERO     GSN     NaN  87418  AR000087418
# (136.8, 137]   44          LABOULAYE AERO     GSN     NaN  87534  AR000087534
# (191.8, 192]   45         SANTA ROSA AERO     GSN     NaN  87623  AR000087623
# (21.8, 22]     46      MAR DEL PLATA AERO     GSN     NaN  87692  AR000087692
# (272.8, 273]   47            NEUQUEN AERO     GSN     NaN  87715  AR000087715
# (798.8, 799]   48             ESQUEL AERO     GSN     NaN  87803  AR000087803
# (42.8, 43]     49             TRELEW AERO     GSN     NaN  87828  AR000087828
# (18.8, 19]     50       RIO GALLEGOS AERO     GSN     NaN  87925  AR000087925
# (1174, 1175]   51                  JACHAL     GSN     NaN  87305  AR000873050
# (84.8, 85]     52            PEHUAJO AERO     GSN     NaN  87544  AR000875440
# (24.8, 25]     53     BUENOS AIRES OBSERV     NaN     NaN  87585  AR000875850
# (74.8, 75]     54       BAHIA BLANCA AERO     GSN     NaN  87750  AR000877500
# (5.8, 6]       55        TROUGHTON ISLAND     NaN     NaN  94102  ASN00001007
# (11.8, 12]     56                KURI BAY     NaN     NaN  94208  ASN00001009
# (10.8, 11]     57                 WYNDHAM     NaN     NaN  94214  ASN00001013
# (22.8, 23]     58       KALUMBURU MISSION     NaN     NaN    NaN  ASN00001021
# (421.8, 422]   59     HALLS CREEK AIRPORT     GSN     NaN  94212  ASN00002012
#                                       ...     ...     ...    ...          ...
#
#                    maxcount  mincount elevationgroup
# elevationgroup
# (23.8, 24]     0        365         0     (23.8, 24]
# (560.8, 561]   1        730         0   (560.8, 561]
# (1361, 1362]   2        365         0   (1361, 1362]
# (49.8, 50]     3         26         0     (49.8, 50]
# (489.8, 490]   4        209         0   (489.8, 490]
# (332.8, 333]   5         37         0   (332.8, 333]
# (310.8, 311]   6         90         0   (310.8, 311]
# (94.8, 95]     7         83         0     (94.8, 95]
# (754.8, 755]   8         81         0   (754.8, 755]
# (891.8, 892]   9        100         0   (891.8, 892]
# (3.8, 4]       10        13         0       (3.8, 4]
# (27.8, 28]     11        20         0     (27.8, 28]
# (999.8, 1001]  12       126         0            NaN
# (827.8, 828]   13        33         0   (827.8, 828]
# (70.8, 71]     14       241         0     (70.8, 71]
# (999.8, 1001]  15        13         0            NaN
# (884.8, 885]   16       144         0   (884.8, 885]
# (1.8, 2]       17        12         0       (1.8, 2]
# (1112, 1113]   18        30         0   (1112, 1113]
# (999.8, 1001]  19       588         0            NaN
#                20       365         0            NaN
# (1511, 1512]   21      1095         0   (1511, 1512]
# (732.8, 733]   22        78         0   (732.8, 733]
# (1833, 1834]   23        63         0   (1833, 1834]
# (1254, 1255]   24        10         0   (1254, 1255]
# (3221, 3231]   25      1126         0   (3221, 3231]
# (864.8, 865]   26        80         0   (864.8, 865]
# (1139, 1140]   27       730         0   (1139, 1140]
# (1960, 1961]   28      1095         0   (1960, 1961]
# (1939, 1940]   29        38         0   (1939, 1940]
# (627.8, 628]   30        77         0   (627.8, 628]
# (705.8, 706]   31        46         0   (705.8, 706]
# (1303, 1304]   32        25         0   (1303, 1304]
# (1760, 1761]   33         1         0   (1760, 1761]
# (44.8, 45]     34         1         0     (44.8, 45]
# (3471, 3481]   35         7         0   (3471, 3481]
# (129.8, 130]   36       729         0   (129.8, 130]
# (199.8, 200]   37      1422         0   (199.8, 200]
# (52.8, 53]     38       166         0     (52.8, 53]
# (437.8, 438]   39       365         0   (437.8, 438]
# (87.8, 88]     40       967         0     (87.8, 88]
# (52.8, 53]     41       365         0     (52.8, 53]
# (488.8, 489]   42      1186         0   (488.8, 489]
# (703.8, 704]   43       421         0   (703.8, 704]
# (136.8, 137]   44       534         0   (136.8, 137]
# (191.8, 192]   45       727         0   (191.8, 192]
# (21.8, 22]     46       363         0     (21.8, 22]
# (272.8, 273]   47       530         0   (272.8, 273]
# (798.8, 799]   48       217         0   (798.8, 799]
# (42.8, 43]     49       729         0     (42.8, 43]
# (18.8, 19]     50         5         0     (18.8, 19]
# (1174, 1175]   51       364         0   (1174, 1175]
# (84.8, 85]     52       148         0     (84.8, 85]
# (24.8, 25]     53       730         0     (24.8, 25]
# (74.8, 75]     54       365         0     (74.8, 75]
# (5.8, 6]       55       730         0       (5.8, 6]
# (11.8, 12]     56       364         0     (11.8, 12]
# (10.8, 11]     57      1059         0     (10.8, 11]
# (22.8, 23]     58       685         0     (22.8, 23]
# (421.8, 422]   59       365         0   (421.8, 422]
#                         ...       ...            ...
#
# [8092 rows x 12 columns]

# %% [markdown]
# #### Great let's build the map/reduce job that computes the PCA for each group!

# %% [markdown]
# ### NOTE! Since I could not run the HWPART1 step on the cluster I run it locally and used a smaller dataset instead. But since the basestations included in the ALL.head and the SAMPLE_TMAX are not the same, the map/reduce might crush... Just use the same file for both Part1 and Part 2

# %%
# %%writefile pcagroubedby.py
#!/usr/bin/python
"""
count the number of measurements for each base-station
"""
import sys
import pandas as pd
import numpy as np
import sklearn as sk
sys.path.append('/usr/lib/python2.6/dist-packages')
from mrjob.job import MRJob
from mrjob.step import MRStep
import re
from sys import stderr
import json

class pcagroubedby(MRJob):
    
    def __init__(self, *args, **kwargs):
        super(pcagroubedby, self).__init__(*args, **kwargs)
        self.data = {}
        
    

    def configure_options(self):
        super(pcagroubedby, self).configure_options()
        self.add_file_option('--hashmap')
        self.add_file_option('--usemeasurement')

    def mapper_init(self):
        json_data=open(self.options.hashmap)
        self.meas = self.options.usemeasurement
        self.data = json.load(json_data)
        #sys.stderr.write('loaded: '+str(self.meas))
        #sys.stderr.write(str(data))
        json_data.close()
        # make dictionary available to mapper
        #sys.stderr.write('MAPPER_INIT!!')
        #sys.stderr.write(str(self.options.hashmap))
        
        #self.sqlite_conn = sqlite3.connect(self.options.database)
    def mapper(self, _, line):
#         for key in self.data:
#             sys.stderr.write( key + ' corresponds to'+ str(self.data[key])+'\n')

        try:
            self.increment_counter('MrJob Counters','mapper-all',1)
            elements=line.split(',')
            if elements[0]=='station':
                
                # if the header is spotted add it, it's not going to matter
                # since no base-station with name: 'header' exists, so when we do the
                # inner join this will be pruned
                
                out=('header','0~0')
                #yield out
            else:
                if elements[1]==self.meas:
                    #sys.stderr.write('YOLO')
                    
                    # Uncomment that to get measurements from a specific year.
                    #if elements[2]=='1973':
                        
                        # Use the following instead if you want to avoid null values
                        #out=(str(self.data[elements[0]]),str(filter(None,elements[3:])))#+'~'+str(0))
                        
                        out=(str(self.data[elements[0]]),(elements[3:]))#+'~'+str(0))
                        #sys.stderr.write(str(out))
                        yield out
#                 elif elements[1]=='TMAX':
                    
#                     # Uncomment that to get measurements from a specific year.
#                     #if elements[2]=='1973':
                        
                        
#                         out=(str(self.data[elements[0]]),'TMAX'+(elements[3:]))#+'~'+str(0))
#                         sys.stderr.write(str(out))
#                         yield out
        except Exception, e:

            self.increment_counter('MrJob Counters','mapper-error',1)
            
            # Again... This would be pruned when we would do the inner join later so let's ommit it right away...
            
            
            ################################################################################################################
            # NOTE! Since I could not run the HWPART1 step on the cluster I run it locally and used a smaller dataset      #
            # with TMAX measurements instead. So the basestations included in the ALL.head and the SAMPLE_TMAX are not     #
            # the same... Just use the same file for both Part1 and Part 2                                                 #
            ################################################################################################################
        #   out=('error','0~0')
            #yield out

        
#     def combiner(self, station, vals):
#         yield (0,0)
        
    def reducer(self, group, vals):

        self.increment_counter('MrJob Counters','reducer',1)
        #sys.stderr.write('group range is: '+str(group)+'\n')
        valArr = []
        
        for val in vals:
            #sys.stderr.write(str(val)+'\n')
            valArr.append(val)



        # Awesome! Let's use a Dataframe!
        ddtf = pd.DataFrame(valArr,columns = range(1,366))
        
        # Since we have a lot of empty values replace them with np.nan 
        # this is gonna make the processing easier
        
        ddtf = ddtf.replace('', np.nan)
        
        # Let's check out the measurements
        #sys.stderr.write(str(ddtf.head()))  # Checked!
        

        
        # switch the type of every element in the dataframe from an object to a float
        for listElem in list(ddtf.columns.values):
            #sys.stderr.write(str(listElem))
            ddtf[listElem] = ddtf[listElem].astype(float)#.fillna(0.0)
        
        
        # It should be float now
        # sys.stderr.write('\nddtf types: '+str(ddtf.dtypes))   # Yes it is!

        
        M=ddtf.loc[:,:].transpose()
        
        # check the shape of M
        #sys.stderr.write('\nM shape is: '+str(M.shape))
        
        M=M.dropna(axis=1)
        
        # check again after dropping the nan values
        #sys.stderr.write('\n M shape after droping NaNs is: '+str(np.shape(M)))
        
        (columns,rows)=np.shape(M)
        
        
        # Let's compute the covariance, (We could use np.cov instead...)
        if rows !=0:
            Mean=np.mean(M, axis=1).values


            C=np.zeros([columns,columns])   # Sum
            N=np.zeros([columns,columns])   # Counter of non-nan entries

            for i in range(rows):
                row=M.iloc[:,i]-Mean;
                outer=np.outer(row,row)
                valid=np.isnan(outer)==False
                C[valid]=C[valid]+outer[valid]  # update C with the valid location in outer
                N[valid]=N[valid]+1
            valid_outer=np.multiply(1-np.isnan(N),N>0)
            cov=np.divide(C,N)
#             cov2 = np.cov(M)
#             sys.stderr.write('\ncov is: \n'+str(cov)+'\ncov2 is: \n'+str(cov2))
#             for elem in cov:
#                 sys.stderr.write('\ncov is: \n'+str(elem))
#            sys.stderr.write('\nnp.sum(cov) : '+str(np.sum(cov)))
            summation = np.sum(cov)
            if summation!=0:
                U,D,V=np.linalg.svd(cov)
                #sys.stderr.write('\nyielding D')
                yield (group+str(rows),str(D))

                
        #else:
        #    sys.stderr.write('nothing to do here')

if __name__ == '__main__':
    pcagroubedby.run()
# Out:
# Overwriting pcagroubedby.py

# %% [markdown]
# #### Great! Let's test it locally!
#
# The command shown below specifically defines which data we'll take into account by specifying which attribute we'll use for our analysis  (e.g: --usemeasurement='TMAX') we did that because the dataset we used locally didn't have a TMIN value so it would be inefficient to have TMIN values equal to 0. If we want to do this analysis for both TMIN and TMAX we can run it twice and parse the data as shown next...

# %%
#local_data='/home/ubuntu/UCSD_BigData/data/weather/ALL.head.csv'
local_data='/home/ubuntu/UCSD_BigData/data/weather/SAMPLE_TMAX.csv'
# !python pcagroubedby.py -r local --hashmap=groupingelevation.json --usemeasurement='TMAX' $local_data > elevationcounts.out
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/pcagroubedby.ubuntu.20140527.071928.028484
# writing to /tmp/pcagroubedby.ubuntu.20140527.071928.028484/step-0-mapper_part-00000
# > /home/ubuntu/anaconda/bin/python pcagroubedby.py --step-num=0 --mapper --hashmap groupingelevation.json --usemeasurement TMAX /tmp/pcagroubedby.ubuntu.20140527.071928.028484/input_part-00000 > /tmp/pcagroubedby.ubuntu.20140527.071928.028484/step-0-mapper_part-00000
# writing to /tmp/pcagroubedby.ubuntu.20140527.071928.028484/step-0-mapper_part-00001
# > /home/ubuntu/anaconda/bin/python pcagroubedby.py --step-num=0 --mapper --hashmap groupingelevation.json --usemeasurement TMAX /tmp/pcagroubedby.ubuntu.20140527.071928.028484/input_part-00001 > /tmp/pcagroubedby.ubuntu.20140527.071928.028484/step-0-mapper_part-00001
# Counters from step 1:
#   MrJob Counters:
#     mapper-all: 20000
# writing to /tmp/pcagroubedby.ubuntu.20140527.071928.028484/step-0-mapper-sorted
# > sort /tmp/pcagroubedby.ubuntu.20140527.071928.028484/step-0-mapper_part-00000 /tmp/pcagroubedby.ubuntu.20140527.071928.028484/step-0-mapper_part-00001
# writing to /tmp/pcagroubedby.ubuntu.20140527.071928.028484/step-0-reducer_part-00000
# > /home/ubuntu/anaconda/bin/python pcagroubedby.py --step-num=0 --reducer --hashmap groupingelevation.json --usemeasurement TMAX /tmp/pcagroubedby.ubuntu.20140527.071928.028484/input_part-00000 > /tmp/pcagroubedby.ubuntu.20140527.071928.028484/step-0-reducer_part-00000
# writing to /tmp/pcagroubedby.ubuntu.20140527.071928.028484/step-0-reducer_part-00001
# > /home/ubuntu/anaconda/bin/python pcagroubedby.py --step-num=0 --reducer --hashmap groupingelevation.json --usemeasurement TMAX /tmp/pcagroubedby.ubuntu.20140527.071928.028484/input_part-00001 > /tmp/pcagroubedby.ubuntu.20140527.071928.028484/step-0-reducer_part-00001
# Counters from step 1:
#   MrJob Counters:
#     mapper-all: 20000
#     reducer: 3086
# Moving /tmp/pcagroubedby.ubuntu.20140527.071928.028484/step-0-reducer_part-00000 -> /tmp/pcagroubedby.ubuntu.20140527.071928.028484/output/part-00000
# Moving /tmp/pcagroubedby.ubuntu.20140527.071928.028484/step-0-reducer_part-00001 -> /tmp/pcagroubedby.ubuntu.20140527.071928.028484/output/part-00001
# Streaming final output from /tmp/pcagroubedby.ubuntu.20140527.071928.028484/output
# removing tmp directory /tmp/pcagroubedby.ubuntu.20140527.071928.028484

# %%
# !head -c2000 elevationcounts.out
# Out:
# "[u'(283.4, 283.6]']11"	"[  1.01068654e+06   1.18569667e+05   1.15222589e+05   9.69172015e+04\n   9.55248060e+04   8.08623309e+04   7.62062286e+04   5.68013822e+04\n   4.66918889e+04   3.98330860e+04   1.41574282e-09   1.20239130e-09\n   8.97669972e-10   8.75450513e-10   8.33928751e-10   7.89193604e-10\n   7.35024772e-10   6.96958104e-10   5.74875864e-10   5.67983259e-10\n   4.87655392e-10   4.78306435e-10   4.69028517e-10   4.11472055e-10\n   3.63669377e-10   3.05925623e-10   2.81369341e-10   2.67998143e-10\n   2.51169018e-10   2.33130133e-10   1.93435112e-10   1.66745354e-10\n   1.35685771e-10   1.11082145e-10   9.75981059e-11   9.75981059e-11\n   9.75981059e-11   9.75981059e-11   9.75981059e-11   9.75981059e-11\n   9.75981059e-11   9.75981059e-11   9.75981059e-11   9.75981059e-11\n   9.75981059e-11   9.75981059e-11   9.75981059e-11   9.75981059e-11\n   9.75981059e-11   9.75981059e-11   9.75981059e-11   9.75981059e-11\n   9.75981059e-11   9.75981059e-11   9.75981059e-11   9.75981059e-11\n   9.75981059e-11   9.75981059e-11   9.75981059e-11   9.75981059e-11\n   9.75981059e-11   9.75981059e-11   9.75981059e-11   9.75981059e-11\n   9.75981059e-11   9.75981059e-11   9.75981059e-11   9.75981059e-11\n   9.75981059e-11   9.75981059e-11   9.75981059e-11   9.75981059e-11\n   9.75981059e-11   9.75981059e-11   9.75981059e-11   9.75981059e-11\n   9.75981059e-11   9.75981059e-11   9.75981059e-11   9.75981059e-11\n   9.75981059e-11   9.75981059e-11   9.75981059e-11   9.75981059e-11\n   9.75981059e-11   9.75981059e-11   9.75981059e-11   9.75981059e-11\n   9.75981059e-11   9.75981059e-11   9.75981059e-11   9.75981059e-11\n   9.75981059e-11   9.75981059e-11   9.75981059e-11   9.75981059e-11\n   9.75981059e-11   9.75981059e-11   9.75981059e-11   9.75981059e-11\n   9.75981059e-11   9.75981059e-11   9.75981059e-11   9.75981059e-11\n   9.75981059e-11   9.75981059e-11   9.75981059e-11   9.75981059e-11\n   9.75981059e-11   9.75981059e-11   9.75981059e-11   9.75981059e-11\n   9.75981059e-

# %% [markdown]
# #### It works! Let's try to run it on the cluster with the full dataset!
#
# Again... We couldn't really run this on the cluster due to the reasons we mentioned...

# %%
import pickle
try:
    Creds= pickle.load(open('/home/ubuntu/Vault/Creds.pkl','rb'))
    #print Creds.keys()
    #print Creds['mrjob'].keys()
    pair=Creds['mrjob']
    key_id=pair['key_id']
    secret_key=pair['secret_key']
    ID=pair['ID']
    if ID is not None:
        print 'done!'
    else:
        print 'hmm! Something went wrong!'
        
except:
    print 'hmm! Something went wrong!'
    print sys.exc_info()[0]
#print ID,key_id
# Out:
# done!

# %%
import sys
home_dir='/home/ubuntu/UCSD_BigData'
sys.path.append(home_dir+'/utils')
from find_waiting_flow import *
from AWS_keypair_management import *

# %%
job_flow_id=find_waiting_flow(key_id,secret_key)
#job_flow_id = 'j-262J0JTFJIRLO'
job_flow_id
# Out:
# <boto.emr.emrobject.JobFlow object at 0xb802490> no_script.yoavfreund.20140516.040032.370095 j-262J0JTFJIRLO WAITING
# u'j-262J0JTFJIRLO'

# %%
# !python pcagroubedby.py -r emr --emr-job-flow-id $job_flow_id --hashmap=grouping.json --usemeasurement='TMAX' hdfs:/weather/weather.csv > elevationcountsEMR
#!python pcatogroups.py -r local --hashmap=grouping.json $local_data > counts
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/pcatogroups.ubuntu.20140525.095456.253183
# Copying non-input files into s3://costaszarifisbucket/scratch/pcatogroups.ubuntu.20140525.095456.253183/files/
# Adding our job to existing job flow j-262J0JTFJIRLO
# Attempting to terminate job...
# Traceback (most recent call last):
#   File "pcatogroups.py", line 169, in <module>
#     SqliteJob.run()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/job.py", line 494, in run
#     mr_job.execute()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/job.py", line 512, in execute
#     super(MRJob, self).execute()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/launch.py", line 147, in execute
#     self.run_job()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/launch.py", line 213, in run_job
#     self.stdout.flush()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/runner.py", line 614, in __exit__
#     self.cleanup()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/emr.py", line 1010, in cleanup
#     super(EMRJobRunner, self).cleanup(mode=mode)
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/runner.py", line 560, in cleanup
#     self._cleanup_job()
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/emr.py", line 1084, in _cleanup_job
#     self._opts['ec2_key_pair_file'])
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/ssh.py", line 200, in ssh_terminate_single_job
#     ssh_bin, address, ec2_key_pair_file, ['hadoop', 'job', '-list']))
#   File "/usr/local/lib/python2.7/dist-packages/mrjob/ssh.py", line 82, in ssh_run
#     p = Popen(args, stdout=PIPE, stderr=PIPE, stdin=PIPE)
#   File "/home/ubuntu/anaconda/lib/python2.7/subprocess.py", line 709, in __init__
#     errread, errwrite)
#   File "/home/ubuntu/anaconda/lib/python2.7/subprocess.py", line 1326, in _execute_child
#     raise child_exception
# TypeError: execv() arg 2 must contain only strings

# %%
# !head -n15 elevationcountsEMR

# %%
def find_between( s, first, last ):
    ss = []
    try:
        start = s.index( first ) + len( first )
        end = s.index( last, start )
        return s[start:end]
#         start = s.rindex( first ) + len( first )
#         end = s.rindex( last, start )
#         ss.append(s[start:end])
#         return ss
    except ValueError:
        return ""
    
def find_between_r( s, first, last ):
    try:
        start = s.rindex( first ) + len( first )
        end = s.rindex( last, start )
        return s[start:end]
    except ValueError:
        return ""

# %%
'''
This is a parser that transforms our output to a dictionary so that we can plot the eigen vectors

source: the source file (e.g counts)
dest: the destination file(e.g dest.csv)
'''
from collections import defaultdict


def generateDict(source):
    import csv
    d = defaultdict(list)
    numOfMeasd = {}
    myrow = []
    with open(source, 'rb') as csvfile:
        spamreader = csv.reader(csvfile, delimiter='\n')
        for row in spamreader:
            
            for k in row:
                #print k
                elements=k.split('\t')
                basestation= elements[0]
                
                numOfM = find_between_r(str(basestation), '\']','')
                basestation = basestation.replace(numOfM, '')
                #print basestation
                vals=elements[1].split('   ')
                numOfMeasd[basestation] = int(numOfM)
                for val in vals:
                    #tmpstr = val.replace(']"','').replace('"[','').rstrip('\\n')
                    d[basestation].append(float(val.replace(']"','').replace('"[','').rstrip('\\n')))
                    #print float(val.replace(']"','').replace('"[','').rstrip('\\n'))
                    #a.replace('\n','').replace(']"','').
                                                     

    return (d,numOfMeasd)

# %%
(d,NumD) = generateDict('elevationcounts.out')

# %%
#NumD

# %%
def example_plot(ax, x):
#     ax.plot(x)
#     ax.locator_params(nbins=3)
    #    D = d[key]
    ax.plot(cumsum(x[:])/sum(x))
    
    ax.set_xlim([0,10])
    ax.set_ylim([0,2])
    grid()

# %%
valzz = []
counter = 0
for key in d:
    if counter == 7:
        break
    valzz.append(d[key])
plt.close('all')
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2)
example_plot(ax1, valzz[0])
example_plot(ax2, valzz[1])
example_plot(ax3, valzz[5])
example_plot(ax4, valzz[6])

#plt.tight_layout()

# %%
# for key in d:
#     #print key
#     D = d[key]
#     plot(cumsum(D[:])/sum(D))
#     cnt = 0
#     for kkk in cumsum(D[:])/sum(D):
#         print kkk, cnt
#         cnt+=1
#     xlim([0,30])
#     grid()

# %%
indx=[]
for key in d:
    #print key
    D = d[key]
    cnt = 0
    for kkk in cumsum(D[:])/sum(D):
        if kkk>0.99:
            indx.append(cnt)
            break
        cnt+=1
#     plot(cumsum(D[:])/sum(D))
#     xlim([0,365])
#     grid()

# %%
counter = 0
for key in d:
    D = d[key]
    plot(cumsum(D[:indx[counter]])/sum(D))
    counter+=1
    #xlim([0,1000])
    grid()

# %%
def find_between( s, first, last ):
    ss = []
    try:
        start = s.index( first ) + len( first )
        end = s.index( last, start )
        return s[start:end]
#         start = s.rindex( first ) + len( first )
#         end = s.rindex( last, start )
#         ss.append(s[start:end])
#         return ss
    except ValueError:
        return ""
    
def find_between_r( s, first, last ):
    try:
        start = s.rindex( first ) + len( first )
        end = s.rindex( last, start )
        return s[start:end]
    except ValueError:
        return ""

# %% [markdown]
# #### Now, we will try to figure out if by merging together neighbours we can explain the same percentage of the variance using less eigen vectors
#
# Since we only have rectangles representing the groups we can use the central point of the geometry and the kdtree implementation to query geometries that are nearby and try to group them together.

# %%
centerpoints = []
initlats = []
initlongs = []
for key in d:
    kk = key
    #print key    
    ll = find_between(key,'(', ']')
    lr = find_between_r(key,'(', ']\'')#.replace("]","")
    #print ll, lr

    vals1=ll.split(',')
    #print mean([float(vals[0]),float(vals[1])], dtype=np.float64)
    vals2=lr.split(',')
    #print ((mean([float(vals1[0]),float(vals1[1])], dtype=np.float64)),mean([float(vals2[0]),float(vals2[1])], dtype=np.float64))
    centerpoints.append(((mean([float(vals1[0]),float(vals1[1])], dtype=np.float64)),mean([float(vals2[0]),float(vals2[1])], dtype=np.float64)))
    initlats.append((float(vals1[0]),float(vals1[1])))
    initlongs.append((float(vals2[0]),float(vals2[1])))

# %%
from scipy import spatial

tree = spatial.KDTree(centerpoints)
j = tree.query_ball_point(centerpoints[1], 2)
centerpoints[1]
# Out:
# (38.0, -82.0)

# %%
j
print tree.data[j]
for jj in j:
    #print centerpoints[jj]
    print initlats[jj]
    print initlongs[jj]
    print
# Out:
# [[ 38. -82.]
#  [ 36. -82.]
#  [ 38. -84.]
#  [ 38. -80.]
#  [ 40. -82.]]
# (37.0, 39.0)
# (-83.0, -81.0)
#
# (35.0, 37.0)
# (-83.0, -81.0)
#
# (37.0, 39.0)
# (-85.0, -83.0)
#
# (37.0, 39.0)
# (-81.0, -79.0)
#
# (39.0, 41.0)
# (-83.0, -81.0)

# %% [markdown]
# The Idea for the iteration is that we will keep increasing the radius thus including merging groups until the relation shown [here](http://seed.ucsd.edu/mediawiki/index.php/BigDataHW2#Suggested_Steps "Title") is satisfied for each group. The problem is that this iteration at each steps requires the recomputing of PCA with a map reduce job.
